# %% [markdown]
# # Model Build V1

# %% [markdown]
# ## Import Library

# %%
import cv2
import os
import json
import numpy as np
import subprocess
from datetime import datetime
import csv
import pandas as pd
import itertools
import random
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import cv2
#       2 import os
#       3 import json
#
# ModuleNotFoundError: No module named 'cv2'

# %% [markdown]
# ## Frame Sampling

# %%
def get_video_info(video_path):
    cap = cv2.VideoCapture(video_path)
    
    if not cap.isOpened():
        print(f"Error: Tidak dapat membuka file video {video_path}.")
        return None, None, None
    
    fps = cap.get(cv2.CAP_PROP_FPS)  # Frame per detik
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))  # Total frame
    duration = frame_count / fps if fps > 0 else 0  # Durasi dalam detik
    
    cap.release()
    
    print(f"\n[INFO] Video: {video_path}")
    print(f"Durasi Video: {duration:.2f} detik")
    print(f"Frame Per Detik (FPS): {fps:.2f}")
    
    return fps, duration, frame_count

video_rotations = {
    "20250317_152346.mp4": 180,
    "VID_20241001_014146_00_033.mp4": 90,
    "VID_20241001_021251_00_034.mp4": 90,
    "VID_20241001_024253_00_035.mp4": 90,
    "VID_20241001_215144_00_036.mp4": 90,
    "VID_20241001_222146_00_037.mp4": 90,
    "VID_20241001_225148_00_038.mp4": 90,
}

def extract_frames(video_path, output_folder, frames_per_second):
    fps, duration, frame_count = get_video_info(video_path)
    if fps is None:
        return
    
    total_frames_to_capture = int(duration * frames_per_second)
    step_size = max(1, frame_count // total_frames_to_capture)

    os.makedirs(output_folder, exist_ok=True)

    cap = cv2.VideoCapture(video_path)
    count = 0
    frame_index = 0

    video_name = os.path.splitext(os.path.basename(video_path))[0]
    file_name = os.path.basename(video_path)

    rotation = video_rotations.get(file_name, 0)

    # Tentukan kode rotasi OpenCV
    if rotation == 90:
        rotate_code = cv2.ROTATE_90_CLOCKWISE
    elif rotation == 180:
        rotate_code = cv2.ROTATE_180
    elif rotation == 270:
        rotate_code = cv2.ROTATE_90_COUNTERCLOCKWISE
    else:
        rotate_code = None

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        
        if frame_index % step_size == 0 and count < total_frames_to_capture:
            if (rotate_code != None):
                frame = cv2.rotate(frame, rotate_code)
            frame_filename = os.path.join(output_folder, f"{video_name}_frame_{count:04d}.jpg")
            cv2.imwrite(frame_filename, frame)
            print(f"Frame {count+1} disimpan: {frame_filename}")
            count += 1
        
        frame_index += 1

    cap.release()
    print(f"Total {count} frame berhasil disimpan di {output_folder}")

def process_all_videos(video_folder, frames_per_second):
    # Mendapatkan daftar semua file video dalam folder
    video_extensions = (".mp4", ".avi", ".mov", ".mkv")
    video_files = [f for f in os.listdir(video_folder) if f.lower().endswith(video_extensions)]
    
    if not video_files:
        print("Tidak ada file video yang ditemukan di folder videos.")
        return

    output_folder = "images"  # Output DIR
    for video_file in video_files:
        video_path = os.path.join(video_folder, video_file)
        print(f"\n=== Memproses: {video_file} ===")
        extract_frames(video_path, output_folder, frames_per_second)

# EXEC
video_folder = "videos"  # Input DIR
frames_per_second = 1  # Banyak Frame per Detik yang diambil sebagai sample

process_all_videos(video_folder, frames_per_second)
# Frame Per Detik (FPS): 59.94
# Frame 1 disimpan: images\VID_20241018_164338_00_032_frame_0000.jpg
# Frame 2 disimpan: images\VID_20241018_164338_00_032_frame_0001.jpg
# Frame 3 disimpan: images\VID_20241018_164338_00_032_frame_0002.jpg
# Frame 4 disimpan: images\VID_20241018_164338_00_032_frame_0003.jpg
# Frame 5 disimpan: images\VID_20241018_164338_00_032_frame_0004.jpg
# Frame 6 disimpan: images\VID_20241018_164338_00_032_frame_0005.jpg
# Frame 7 disimpan: images\VID_20241018_164338_00_032_frame_0006.jpg
# Frame 8 disimpan: images\VID_20241018_164338_00_032_frame_0007.jpg
# Frame 9 disimpan: images\VID_20241018_164338_00_032_frame_0008.jpg
# Frame 10 disimpan: images\VID_20241018_164338_00_032_frame_0009.jpg
# Frame 11 disimpan: images\VID_20241018_164338_00_032_frame_0010.jpg
# Frame 12 disimpan: images\VID_20241018_164338_00_032_frame_0011.jpg
# Frame 13 disimpan: images\VID_20241018_164338_00_032_frame_0012.jpg
# Frame 14 disimpan: images\VID_20241018_164338_00_032_frame_0013.jpg
# Frame 15 disimpan: images\VID_20241018_164338_00_032_frame_0014.jpg
# Frame 16 disimpan: images\VID_20241018_164338_00_032_frame_0015.jpg
# Frame 17 disimpan: images\VID_20241018_164338_00_032_frame_0016.jpg
# Frame 18 disimpan: images\VID_20241018_164338_00_032_frame_0017.jpg
# Frame 19 disimpan: images\VID_20241018_164338_00_032_frame_0018.jpg
# Frame 20 disimpan: images\VID_20241018_164338_00_032_frame_0019.jpg
# Frame 21 disimpan: images\VID_20241018_164338_00_032_frame_0020.jpg
# Frame 22 disimpan: images\VID_20241018_164338_00_032_frame_0021.jpg
# Total 22 frame berhasil disimpan di images

# %% [markdown]
# ## PreProcessing Image

# %%
# Path utama untuk OpenPose dan direktori gambar
openpose_path = os.path.abspath("openpose")  # Path ke OpenPose
image_dir = os.path.abspath("../images")  # Folder gambar input
json_output_dir = os.path.abspath("../output_json")  # Folder JSON hasil OpenPose
preprocessing_dir = os.path.abspath("../preprocessing_images")  # Folder hasil crop
log_dir = os.path.abspath("../log_preprocessing")

# Tambahkan timestamp pada nama file log
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
log_file_path = os.path.join(log_dir, f"error_log_preprocessing_{timestamp}.txt")

# Buat folder jika belum ada
os.makedirs(image_dir, exist_ok=True)
os.makedirs(json_output_dir, exist_ok=True)
os.makedirs(preprocessing_dir, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)

# Ambil file gambar dari folder `images/`
image_files = [f for f in os.listdir(image_dir) if f.lower().endswith((".jpg", ".jpeg", ".png"))]

if not image_files:
    print("Tidak ada gambar yang valid di folder `images/`. Silakan unggah file JPG atau PNG!")
    exit()

# hitung jumlah gambar
total_images = len(image_files)
print(f"Preprocessing of {total_images} images!, please wait...")

# Jalankan OpenPose dengan `cwd=openpose_path`
cmd = [
    "bin\\OpenPoseDemo.exe",
    "--image_dir", image_dir,
    "--write_json", json_output_dir,
    "--display", "0",
    "--render_pose", "0",
    "--model_pose", "BODY_25",
    "--number_people_max", "1"
]

result = subprocess.run(cmd, shell=True, capture_output=True, text=True, cwd=openpose_path)

# **Periksa apakah OpenPose berjalan dengan sukses**
if result.returncode != 0:
    error_msg = "OpenPose gagal dijalankan! Periksa konfigurasi atau file gambar."
    print(error_msg)
    log_file.write(error_msg)
    exit()

# **Periksa apakah ada JSON hasil OpenPose**
json_files = [f for f in os.listdir(json_output_dir) if f.endswith(".json")]
if not json_files:
    error_msg = "Tidak ada JSON yang dihasilkan oleh OpenPose! Pastikan gambar terdeteksi dengan benar."
    print(error_msg)
    log_file.write(error_msg)
    exit()

# Buka file log untuk mencatat error
with open(log_file_path, "w") as log_file:
    for index, image_file in enumerate(image_files, start=1):
        input_image_path = os.path.join(image_dir, image_file)
        file_name, file_ext = os.path.splitext(image_file)

        output_json_path = os.path.join(json_output_dir, file_name + '_keypoints.json')

        # Tampilkan progress
        print(f"Memproses ({index}/{total_images}): {image_file} ...")

        if result.returncode != 0:
            error_msg = f"Gagal memproses {image_file} dengan OpenPose!\n"
            print(error_msg)
            log_file.write(error_msg)
            continue

        # Baca hasil JSON dari OpenPose
        if not os.path.exists(output_json_path):
            error_msg = f"JSON hasil deteksi tidak ditemukan untuk {image_file}!\n"
            print(error_msg)
            log_file.write(error_msg)
            continue

        with open(output_json_path, 'r') as f:
            pose_data = json.load(f)
            if not pose_data['people']:
                error_msg = f"Tidak ada orang terdeteksi pada {image_file}.\n"
                print(error_msg)
                log_file.write(error_msg)
                continue
            keypoints = pose_data['people'][0]['pose_keypoints_2d']

        # Ambil koordinat x, y untuk semua keypoints
        def get_coords(index):
            x = keypoints[index * 3]
            y = keypoints[index * 3 + 1]
            confidence = keypoints[index * 3 + 2]
            return (int(x), int(y)) if confidence > 0 else None

        def get_coords_flip(index):
            return (keypoints[index * 3], keypoints[index * 3 + 1]) if keypoints and keypoints[index * 3 + 2] > 0 else None

        body_points = [get_coords(i) for i in range(25)]
        valid_points = [p for p in body_points if p is not None]

        if not valid_points:
            error_msg = f"Tidak ada titik tubuh yang valid pada {image_file}.\n"
            print(error_msg)
            log_file.write(error_msg)
            continue

        # Cari bounding box (xmin, ymin, xmax, ymax)
        x_coords, y_coords = zip(*valid_points)
        xmin, xmax = min(x_coords), max(x_coords)
        ymin, ymax = min(y_coords), max(y_coords)

        # Tambahkan margin ekstra (10% dari bounding box)
        margin_x = int((xmax - xmin) * 0.1)
        margin_y = int((ymax - ymin) * 0.1)

        xmin, ymin = max(0, xmin - margin_x), max(0, ymin - margin_y)
        xmax, ymax = min(xmax + margin_x, 9999), min(ymax + margin_y, 9999)  # 9999 untuk menjaga batas atas

        # Tentukan ukuran bounding box agar tetap 1:1
        box_size = max(xmax - xmin, ymax - ymin)

        # Hitung posisi baru agar tetap dalam batas gambar
        x_center, y_center = (xmin + xmax) // 2, (ymin + ymax) // 2
        xmin, ymin = x_center - box_size // 2, y_center - box_size // 2
        xmax, ymax = x_center + box_size // 2, y_center + box_size // 2

        # Pastikan bounding box tetap dalam ukuran gambar
        img = cv2.imread(input_image_path)
        h, w, _ = img.shape

        # Hitung padding yang diperlukan
        pad_top, pad_bottom, pad_left, pad_right = 0, 0, 0, 0

        if xmin < 0:
            pad_left = abs(xmin)
            xmin = 0
        if xmax > w:
            pad_right = xmax - w
            xmax = w
        if ymin < 0:
            pad_top = abs(ymin)
            ymin = 0
        if ymax > h:
            pad_bottom = ymax - h
            ymax = h

        # Crop gambar sesuai bounding box yang diperbaiki
        cropped_img = img[ymin:ymax, xmin:xmax]

        # Tambahkan padding abu-abu agar tetap 1:1 dan objek di tengah
        cropped_img = cv2.copyMakeBorder(
            cropped_img, pad_top, pad_bottom, pad_left, pad_right,
            cv2.BORDER_CONSTANT, value=(128, 128, 128)  # Warna abu-abu
        )

        # Resize gambar ke ukuran standar 256x256
        final_size = (256, 256)
        resized_img = cv2.resize(cropped_img, final_size)

        # Simpan hasil crop
        preprocessing_image_path = os.path.join(preprocessing_dir, f"{file_name}_preproc{file_ext}")

        # Ambil titik hidung dan bahu
        nose = get_coords(0)  # Hidung
        left_shoulder = get_coords(5)  # Bahu kiri
        left_elbow = get_coords(6)  # Siku kiri
        left_wrist = get_coords(7)  # Pergelangan tangan kiri
        left_knee = get_coords(13)  # Lutut kiri

        score = 0

        if nose and left_shoulder:
            if nose[0] < left_shoulder[0]:  
                score += 1  # Menghadap kiri
            else:
                score -= 1  # Menghadap kanan
        
        if left_shoulder and left_wrist:
            if left_shoulder[0] > left_wrist[0]:  
                score += 1  # Menghadap kiri
            else:
                score -= 1  # Menghadap kanan
        
        if left_shoulder and left_knee:
            if left_shoulder[0] > left_knee[0]:  
                score += 1  # Menghadap kiri
            else:
                score -= 1  # Menghadap kanan
        
        if left_shoulder and left_elbow:
            if left_shoulder[0] > left_elbow[0]:  
                score += 1  # Menghadap kiri
            else:
                score -= 1  # Menghadap kanan

        if score > 0:
            print("Menghadap kiri → Flip ke kanan")
            img = resized_img
            flipped_img = cv2.flip(img, 1)  # Flip horizontal
            cv2.imwrite(preprocessing_image_path, flipped_img)
        elif score < 0:
            cv2.imwrite(preprocessing_image_path, resized_img)
        else:
            error_msg = f"Skor netral, tidak bisa menentukan arah hadap pada {image_file}.\n"
            print(error_msg)
            log_file.write(error_msg)
            continue

# Ambil file gambar dari folder `preprocessing_images/`
image_files_output = [f for f in os.listdir(preprocessing_dir) if f.lower().endswith((".jpg", ".jpeg", ".png"))]
total_images_output = len(image_files_output)
failed_image_process = total_images - total_images_output
print(f"\nTotal file berhasil diproses = {total_images_output}")
print(f"Total file gagal diproses = {failed_image_process}")

print(f"\nSemua gambar berhasil diproses. Hasil disimpan di folder `preprocessing_images/`.\n")
print(f"Log error tersimpan di: {log_file_path}")
# Out:
# Preprocessing of 10895 images!, please wait...
# Memproses (1/10895): 20250317_152346_frame_0000.jpg ...
# Memproses (2/10895): 20250317_152346_frame_0001.jpg ...
# Memproses (3/10895): 20250317_152346_frame_0002.jpg ...
# Memproses (4/10895): 20250317_152346_frame_0003.jpg ...
# Memproses (5/10895): 20250317_152346_frame_0004.jpg ...
# Memproses (10860/10895): VID_20241001_225148_00_038_frame_1135.jpg ...
# Memproses (10861/10895): VID_20241001_225148_00_038_frame_1136.jpg ...
# Memproses (10862/10895): VID_20241001_225148_00_038_frame_1137.jpg ...
# Memproses (10863/10895): VID_20241001_225148_00_038_frame_1138.jpg ...
# Memproses (10864/10895): VID_20241001_225148_00_038_frame_1139.jpg ...
# Memproses (10865/10895): VID_20241001_225148_00_038_frame_1140.jpg ...
# Memproses (10866/10895): VID_20241001_225148_00_038_frame_1141.jpg ...
# Memproses (10867/10895): VID_20241001_225148_00_038_frame_1142.jpg ...
# Memproses (10868/10895): VID_20241001_225148_00_038_frame_1143.jpg ...
# Memproses (10869/10895): VID_20241001_225148_00_038_frame_1144.jpg ...
# Memproses (10870/10895): VID_20241001_225148_00_038_frame_1145.jpg ...
# Memproses (10871/10895): VID_20241001_225148_00_038_frame_1146.jpg ...
# Memproses (10872/10895): VID_20241001_225148_00_038_frame_1147.jpg ...
# Memproses (10873/10895): VID_20241001_225148_00_038_frame_1148.jpg ...
# Memproses (10874/10895): VID_20241018_164338_00_032_frame_0000.jpg ...
# Menghadap kiri → Flip ke kanan
# Memproses (10875/10895): VID_20241018_164338_00_032_frame_0001.jpg ...
# Menghadap kiri → Flip ke kanan
# Memproses (10876/10895): VID_20241018_164338_00_032_frame_0002.jpg ...
# Menghadap kiri → Flip ke kanan
# Memproses (10877/10895): VID_20241018_164338_00_032_frame_0003.jpg ...
# Menghadap kiri → Flip ke kanan
# Memproses (10878/10895): VID_20241018_164338_00_032_frame_0004.jpg ...
# Menghadap kiri → Flip ke kanan
# Memproses (10879/10895): VID_20241018_164338_00_032_frame_0005.jpg ...
# Menghadap kiri → Flip ke kanan
# Memproses (10880/10895): VID_20241018_164338_00_032_frame_0006.jpg ...
# Menghadap kiri → Flip ke kanan
# Memproses (10881/10895): VID_20241018_164338_00_032_frame_0007.jpg ...
# Menghadap kiri → Flip ke kanan
# Memproses (10882/10895): VID_20241018_164338_00_032_frame_0008.jpg ...
# Menghadap kiri → Flip ke kanan
# Memproses (10883/10895): VID_20241018_164338_00_032_frame_0009.jpg ...
# Menghadap kiri → Flip ke kanan
# Memproses (10884/10895): VID_20241018_164338_00_032_frame_0010.jpg ...
# Menghadap kiri → Flip ke kanan
# Memproses (10885/10895): VID_20241018_164338_00_032_frame_0011.jpg ...
# Menghadap kiri → Flip ke kanan
# Memproses (10886/10895): VID_20241018_164338_00_032_frame_0012.jpg ...
# Menghadap kiri → Flip ke kanan
# Memproses (10887/10895): VID_20241018_164338_00_032_frame_0013.jpg ...
# Menghadap kiri → Flip ke kanan
# Memproses (10888/10895): VID_20241018_164338_00_032_frame_0014.jpg ...
# Menghadap kiri → Flip ke kanan
# Memproses (10889/10895): VID_20241018_164338_00_032_frame_0015.jpg ...
# Menghadap kiri → Flip ke kanan
# Memproses (10890/10895): VID_20241018_164338_00_032_frame_0016.jpg ...
# Menghadap kiri → Flip ke kanan
# Memproses (10891/10895): VID_20241018_164338_00_032_frame_0017.jpg ...
# Menghadap kiri → Flip ke kanan
# Memproses (10892/10895): VID_20241018_164338_00_032_frame_0018.jpg ...
# Menghadap kiri → Flip ke kanan
# Memproses (10893/10895): VID_20241018_164338_00_032_frame_0019.jpg ...
# Menghadap kiri → Flip ke kanan
# Memproses (10894/10895): VID_20241018_164338_00_032_frame_0020.jpg ...
# Menghadap kiri → Flip ke kanan
# Memproses (10895/10895): VID_20241018_164338_00_032_frame_0021.jpg ...
# Menghadap kiri → Flip ke kanan
#
# Total file berhasil diproses = 10763
# Total file gagal diproses = 132
#
# Semua gambar berhasil diproses. Hasil disimpan di folder `preprocessing_images/`.
#
# Log error tersimpan di: F:\log_preprocessing\error_log_preprocessing_20250525_185749.txt

# %% [markdown]
# ## Ekstraksi Fitur

# %%
def calculate_angle(a, b, c):
    a = np.array(a)
    b = np.array(b)
    c = np.array(c)
    v1 = a - b
    v2 = c - b
    cosine_angle = np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))
    angle = np.arccos(np.clip(cosine_angle, -1.0, 1.0))
    return np.degrees(angle)

def calculate_wrist_bending(elbow, wrist, hand_middle):
    # vektor lengan bawah
    forearm_vec = np.array(wrist) - np.array(elbow)
    # vektor arah tangan
    hand_vec = np.array(hand_middle) - np.array(wrist)
    # hitung sudut antar dua vektor
    cosine = np.dot(forearm_vec, hand_vec) / (np.linalg.norm(forearm_vec) * np.linalg.norm(hand_vec))
    angle = np.arccos(np.clip(cosine, -1, 1))
    return np.degrees(angle)

def calculate_neck_angle(back, neck, head):
    back = np.array(back)
    neck = np.array(neck)
    head = np.array(head)

    vertical_vec = neck - back     # vektor tubuh (vertikal)
    neck_vec = head - neck         # vektor arah leher

    cosine = np.dot(vertical_vec, neck_vec) / (np.linalg.norm(vertical_vec) * np.linalg.norm(neck_vec))
    angle = np.arccos(np.clip(cosine, -1.0, 1.0))
    return np.degrees(angle)

def calculate_trunk_deviation(hip, neck):
    """
    Mengukur deviasi trunk (badan) terhadap garis vertikal dari hip ke atas.
    hip: (x, y) titik mid-hip (BODY_25 keypoint 8)
    neck: (x, y) titik neck (BODY_25 keypoint 1)
    """
    hip = np.array(hip)
    neck = np.array(neck)
    
    # Buat garis (vertikal ke atas dari hip, sejajar sumbu Y)
    ideal_neck = np.array([hip[0], neck[1]])

    # Vektor ideal (vertikal lurus)
    vertical_vec = hip - ideal_neck
    # Vektor tubuh aktual
    trunk_vec = hip - neck

    # Sudut antara keduanya
    cosine = np.dot(vertical_vec, trunk_vec) / (np.linalg.norm(vertical_vec) * np.linalg.norm(trunk_vec))
    angle = np.arccos(np.clip(cosine, -1.0, 1.0))
    return np.degrees(angle)

def shoulder_is_raised(shoulder, neck, conf_shoulder, conf_neck, threshold=0.3):
    """
    Mengembalikan True jika shoulder lebih tinggi dari back (Y lebih kecil),
    dan confidence keduanya memadai.
    """
    if conf_shoulder > threshold and conf_neck > threshold:
        return shoulder[1] < neck[1]
    return False

def arm_is_supported():
    """
    Diasumsikan duduk di kursi/meja → arm selalu disupport.
    """
    return True

def is_neck_twisted(neck, nose, conf_neck, conf_nose, threshold=0.3):
    """
    Mengembalikan True jika posisi nose(0) di kiri neck(1) leher sedang twist
    """
    if conf_neck > threshold and conf_nose > threshold:
        return nose[0] < neck[0]
    elif conf_nose < 0.1:
        return True
    return False

def is_trunk_twisted_by_elbow_rule(
    elbow_r, elbow_l,
    shoulder_r, shoulder_l,
    conf_er, conf_el,
    conf_sr, conf_sl,
    threshold=0.3
):
    if conf_er > threshold and conf_el > threshold and conf_sr > threshold and conf_sl > threshold:
        twist_kiri = elbow_r[0] < shoulder_l[0]  # Twist ke kiri / frontal
        twist_kanan = elbow_l[0] < shoulder_r[0]  # Twist ke kanan berlebihan
        return twist_kiri or twist_kanan
    return False

# Path setup
openpose_path = os.path.abspath("openpose")
image_dir = os.path.abspath("../preprocessing_images")
output_dir = os.path.abspath("../output_images")
json_output_dir = os.path.abspath("../output_estimation_json")
csv_output_dir = os.path.abspath("../output_csv")
csv_output_path = os.path.abspath("../output_csv/output_angles.csv")

os.makedirs(image_dir, exist_ok=True)
os.makedirs(output_dir, exist_ok=True)
os.makedirs(json_output_dir, exist_ok=True)
os.makedirs(csv_output_dir, exist_ok=True)

image_files = [f for f in os.listdir(image_dir) if f.lower().endswith((".jpg", ".jpeg", ".png"))]

if not image_files:
    print("Tidak ada gambar yang valid di folder `preprocessing_images/`. Silakan unggah file JPG atau PNG!")
    exit()

# Jalankan OpenPose sekali untuk seluruh gambar
cmd = [
    "bin\\OpenPoseDemo.exe",
    "--image_dir", image_dir,
    "--write_images", output_dir,
    "--write_json", json_output_dir,
    "--display", "0",
    "--render_pose", "1",
    "--model_pose", "BODY_25",
    "--hand",
    "--number_people_max", "1"
]

print("Memproses seluruh gambar dengan OpenPose...")

result = subprocess.run(cmd, shell=True, capture_output=True, text=True, cwd=openpose_path)

if result.returncode != 0:
    print("Terjadi kesalahan saat menjalankan OpenPose!")
    print("Error Log:", result.stderr)
    exit()
else:
    print("Proses OpenPose selesai!")

# Siapkan CSV
csv_header = [
    "nama_gambar",
    "sudut_lutut",
    "sudut_siku",
    "sudut_leher",
    "sudut_punggung",
    "sudut_pergelangan",
    "sudut_bahu",

    # Confidence
    "conf_hip",
    "conf_knee",
    "conf_ankle",
    "conf_shoulder",
    "conf_shoulder_left",
    "conf_elbow",
    "conf_elbow_left",
    "conf_wrist",
    "conf_neck",
    "conf_head",
    "conf_back",
    "conf_hand_middle",

    # sub step poin
    "adjust_shoulder_raised",
    "adjust_arm_supported",
    "adjust_wrist_twist",
    "adjust_neck_twist",
    "adjust_trunk_twist",
    "adjust_legs_feet"
]
csv_rows = []

# Proses hasil JSON dari output
json_files = [f for f in os.listdir(json_output_dir) if f.endswith('_keypoints.json')]

for json_file in json_files:
    file_name = os.path.splitext(json_file)[0].replace('_keypoints', '')
    json_path = os.path.join(json_output_dir, json_file)

    with open(json_path, 'r') as f:
        pose_data = json.load(f)
        if not pose_data['people']:
            print(f"Tidak terdeteksi orang dalam gambar {file_name}")
            continue
        keypoints = pose_data['people'][0]['pose_keypoints_2d']
        hand_keypoints = pose_data['people'][0].get('hand_right_keypoints_2d', [])

    def get_coords(index):
        return (keypoints[index * 3], keypoints[index * 3 + 1]) if keypoints[index * 3 + 2] > 0 else None

    def get_hand_coords(index):
        return (hand_keypoints[index * 3], hand_keypoints[index * 3 + 1]) if hand_keypoints and len(hand_keypoints) > index * 3 + 2 and hand_keypoints[index * 3 + 2] > 0 else None

    def get_conf_body(index):
        return keypoints[index * 3 + 2] if len(keypoints) > index * 3 + 2 else 0
        
    def get_conf_hand(index):
        return hand_keypoints[index * 3 + 2] if len(hand_keypoints) > index * 3 + 2 else 0

    hip = get_coords(9)
    knee = get_coords(10)
    ankle = get_coords(11)
    shoulder = get_coords(2)
    shoulder_left = get_coords(5)
    elbow = get_coords(3)
    elbow_left = get_coords(6)
    wrist = get_coords(4)
    neck = get_coords(1)
    head = get_coords(17)
    back = get_coords(8)
    nose = get_coords(0)

    hand_middle = get_hand_coords(12)

    conf_hip = get_conf_body(9)
    conf_knee = get_conf_body(10)
    conf_ankle = get_conf_body(11)
    conf_shoulder = get_conf_body(2)
    conf_shoulder_left = get_conf_body(5)
    conf_elbow = get_conf_body(3)
    conf_elbow_left = get_conf_body(6)
    conf_wrist = get_conf_body(4)
    conf_neck = get_conf_body(1)
    conf_head = get_conf_body(17)
    conf_back = get_conf_body(8)
    conf_nose = get_conf_body(0)

    conf_hand_middle = get_conf_hand(12)

    print(f"\nGambar: {file_name}")
    row = [file_name]
    
    elbow_angle = None
    knee_angle = None
    neck_angle = None
    trunk_angle = None
    wrist_angle = None
    shoulder_angle = None

    if hip and knee and ankle:
        knee_angle = calculate_angle(hip, knee, ankle)
        print(f"Sudut Lutut: {knee_angle:.2f}°")
        row.append(knee_angle)
    else:
        row.append(None)

    if shoulder and elbow and wrist:
        elbow_angle = abs(180 - calculate_angle(shoulder, elbow, wrist))
        print(f"Sudut Siku: {elbow_angle:.2f}°")
        row.append(elbow_angle)
    else:
        row.append(None)

    if back and neck and head:
        neck_angle = calculate_neck_angle(back, neck, head)
        print(f"Sudut Leher: {neck_angle:.2f}°")
        row.append(neck_angle)
    else:
        row.append(None)

    if hip and neck:
        trunk_angle = calculate_trunk_deviation(hip, neck)
        print(f"Sudut Trunk: {trunk_angle:.2f}°")
        row.append(trunk_angle)
    else:
        row.append(None)

    if elbow and wrist and hand_middle:
        wrist_angle = calculate_wrist_bending(elbow, wrist, hand_middle)
        print(f"Sudut Pergelangan Tangan: {wrist_angle:.2f}°")
        row.append(wrist_angle)
    else:
        row.append(None)

    if back and shoulder and elbow:
        shoulder_angle = calculate_angle(back, shoulder, elbow)
        print(f"Sudut Fleksi/Ekstensi Bahu: {shoulder_angle:.2f}°")
        row.append(shoulder_angle)
    else:
        row.append(None)

    # Sub Step Point RULA/REBA
    # 1a
    adjust_shoulder = 1 if shoulder_is_raised(shoulder, neck, conf_shoulder, conf_neck) else 0
    adjust_supported = -1 if arm_is_supported() else 0

    # 4 (di set ke 1 karena normal dan ada batasan mapping)
    adjust_wrist_twist = 1

    # 9a (hanya untuk twist)
    adjust_neck_twist = 1 if is_neck_twisted(neck, nose, conf_neck, conf_nose) else 0

    # 10a (hanya untuk twist)
    adjust_trunk_twist = 1 if is_trunk_twisted_by_elbow_rule(
        elbow, elbow_left,
        shoulder, shoulder_left,
        conf_elbow, conf_elbow_left,
        conf_shoulder, conf_shoulder_left
    ) else 0

    # 11 (set ke 1 karena tidak ada sudut pasti untuk kaki)
    adjust_legs_feet = 1

    row.extend([
        conf_hip,
        conf_knee,
        conf_ankle,
        conf_shoulder,
        conf_shoulder_left,
        conf_elbow,
        conf_elbow_left,
        conf_wrist,
        conf_neck,
        conf_head,
        conf_back,
        conf_hand_middle,
        adjust_shoulder,
        adjust_supported,
        adjust_wrist_twist,
        adjust_neck_twist,
        adjust_trunk_twist,
        adjust_legs_feet
    ])

    csv_rows.append(row)

with open(csv_output_path, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(csv_header)
    writer.writerows(csv_rows)
# Out:
# Memproses seluruh gambar dengan OpenPose...
#
# Gambar: 20250317_152346_frame_0000_preproc
# Sudut Lutut: 82.34°
# Sudut Siku: 32.82°
# Sudut Leher: 7.16°
# Sudut Trunk: 2.76°
# Sudut Pergelangan Tangan: 36.18°
# Sudut Fleksi/Ekstensi Bahu: 31.71°
#
# Gambar: 20250317_152346_frame_0001_preproc
# Sudut Lutut: 80.41°
# Sudut Siku: 31.06°
# Sudut Leher: 16.96°
# Sudut Trunk: 2.15°
# Sudut Pergelangan Tangan: 5.90°
# Sudut Fleksi/Ekstensi Bahu: 31.19°
#
# Gambar: 20250317_152346_frame_0002_preproc
# Sudut Lutut: 81.09°
# Sudut Siku: 28.14°
# Sudut Leher: 26.69°
# Sudut Trunk: 0.01°
# Sudut Pergelangan Tangan: 134.11°
# Sudut Fleksi/Ekstensi Bahu: 34.58°
#
# Gambar: 20250317_152346_frame_0003_preproc
# Sudut Lutut: 79.47°
# Sudut Siku: 24.64°
# Sudut Leher: 8.44°
# Sudut Trunk: 2.77°
# Sudut Pergelangan Tangan: 115.85°
# Sudut Fleksi/Ekstensi Bahu: 31.58°
#
# Gambar: 20250317_152346_frame_0004_preproc
# Sudut Lutut: 80.64°
# Sudut Siku: 27.24°
# Sudut Leher: 4.53°
# Sudut Trunk: 1.78°
# Sudut Pergelangan Tangan: 3.58°
# Sudut Fleksi/Ekstensi Bahu: 27.21°
#
# Gambar: 20250317_152346_frame_0005_preproc
# Sudut Lutut: 81.83°
# Sudut Siku: 35.17°
# Sudut Leher: 22.06°
# Sudut Trunk: 2.70°
# Sudut Pergelangan Tangan: 122.07°
# Sudut Fleksi/Ekstensi Bahu: 30.17°
#
# Gambar: 20250317_152346_frame_0006_preproc
# Sudut Lutut: 81.21°
# Sudut Siku: 26.92°
# Sudut Leher: 28.18°
# Sudut Trunk: 3.46°
# Sudut Pergelangan Tangan: 109.02°
# Sudut Fleksi/Ekstensi Bahu: 29.12°
#
# Gambar: 20250317_152346_frame_0007_preproc
# Sudut Lutut: 82.42°
# Sudut Siku: 34.01°
# Sudut Leher: 22.82°
# Sudut Trunk: 0.45°
# Sudut Pergelangan Tangan: 96.80°
# Sudut Fleksi/Ekstensi Bahu: 29.51°
#
# Gambar: 20250317_152346_frame_0008_preproc
# Sudut Lutut: 82.85°
# Sudut Siku: 70.46°
# Sudut Leher: 16.40°
# Sudut Trunk: 3.08°
# Sudut Pergelangan Tangan: 5.76°
# Sudut Fleksi/Ekstensi Bahu: 28.75°
#
# Gambar: 20250317_152346_frame_0009_preproc
# Sudut Lutut: 82.31°
# Sudut Siku: 112.87°
# Sudut Leher: 24.76°
# Sudut Trunk: 6.39°
# Sudut Pergelangan Tangan: 101.99°
# Sudut Fleksi/Ekstensi Bahu: 19.66°
#
# Gambar: 20250317_152346_frame_0010_preproc
# Sudut Lutut: 80.74°
# Sudut Siku: 110.54°
# Sudut Leher: 20.31°
# Sudut Trunk: 4.40°
# Sudut Pergelangan Tangan: 69.90°
# Sudut Fleksi/Ekstensi Bahu: 22.02°
#
# Gambar: 20250317_152346_frame_0011_preproc
# Sudut Lutut: 80.74°
# Sudut Siku: 106.41°
# Sudut Leher: 19.77°
# Sudut Trunk: 5.84°
# Sudut Pergelangan Tangan: 102.05°
# Sudut Fleksi/Ekstensi Bahu: 22.03°
#
# Gambar: 20250317_152346_frame_0012_preproc
# Sudut Lutut: 81.12°
# Sudut Siku: 108.61°
# Sudut Leher: 21.79°
# Sudut Trunk: 5.43°
# Sudut Pergelangan Tangan: 103.12°
# Sudut Fleksi/Ekstensi Bahu: 22.40°
#
# Gambar: 20250317_152346_frame_0013_preproc
# Sudut Lutut: 77.76°
# Sudut Siku: 111.54°
# Sudut Leher: 19.09°
# Sudut Trunk: 4.50°
# Sudut Pergelangan Tangan: 104.14°
# Sudut Fleksi/Ekstensi Bahu: 20.17°
#
# Gambar: 20250317_152346_frame_0014_preproc
# Sudut Lutut: 81.64°
# Sudut Siku: 109.70°
# Sudut Leher: 28.10°
# Sudut Trunk: 7.01°
# Sudut Pergelangan Tangan: 86.65°
# Sudut Fleksi/Ekstensi Bahu: 21.17°
#
# Gambar: 20250317_152346_frame_0015_preproc
# Sudut Lutut: 80.43°
# Sudut Siku: 109.43°
# Sudut Leher: 25.43°
# Sudut Trunk: 6.67°
# Sudut Pergelangan Tangan: 86.45°
# Sudut Fleksi/Ekstensi Bahu: 20.62°
#
# Gambar: 20250317_152346_frame_0016_preproc
# Sudut Lutut: 81.90°
# Sudut Siku: 109.39°
# Sudut Leher: 28.72°
# Sudut Trunk: 7.94°
# Sudut Pergelangan Tangan: 127.75°
# Sudut Fleksi/Ekstensi Bahu: 23.20°
#
# Gambar: 20250317_152346_frame_0017_preproc
# Sudut Lutut: 79.65°
# Sudut Siku: 108.74°
# Sudut Leher: 24.51°
# Sudut Trunk: 5.23°
# Sudut Pergelangan Tangan: 85.44°
# Sudut Fleksi/Ekstensi Bahu: 23.43°
#
# Gambar: 20250317_152346_frame_0018_preproc
# Sudut Lutut: 76.68°
# Sudut Siku: 110.37°
# Sudut Leher: 19.07°
# Sudut Trunk: 22.78°
# Sudut Pergelangan Tangan: 63.93°
# Sudut Fleksi/Ekstensi Bahu: 22.68°
#
# Gambar: 20250317_152346_frame_0019_preproc
# Sudut Lutut: 86.52°
# Sudut Siku: 112.56°
# Sudut Leher: 2.47°
# Sudut Trunk: 35.32°
# Sudut Pergelangan Tangan: 52.41°
# Sudut Fleksi/Ekstensi Bahu: 20.32°
#
# Gambar: 20250317_152346_frame_0020_preproc
# Sudut Lutut: 87.49°
# Sudut Siku: 97.92°
# Sudut Leher: 15.52°
# Sudut Trunk: 12.17°
# Sudut Pergelangan Tangan: 72.39°
# Sudut Fleksi/Ekstensi Bahu: 39.86°
#
# Gambar: 20250317_152346_frame_0021_preproc
# Sudut Lutut: 85.33°
# Sudut Leher: 2.02°
# Sudut Trunk: 32.94°
# Sudut Fleksi/Ekstensi Bahu: 28.23°
#
# Gambar: 20250317_152346_frame_0022_preproc
# Sudut Lutut: 82.47°
# Sudut Leher: 4.05°
# Sudut Trunk: 36.39°
# Sudut Fleksi/Ekstensi Bahu: 26.82°
#
# Gambar: 20250317_152346_frame_0023_preproc
# Sudut Lutut: 83.87°
# Sudut Leher: 0.16°
# Sudut Trunk: 37.93°
# Sudut Fleksi/Ekstensi Bahu: 28.24°
#
# Gambar: 20250317_152346_frame_0024_preproc
# Sudut Lutut: 85.99°
# Sudut Leher: 1.33°
# Sudut Trunk: 37.72°
# Sudut Fleksi/Ekstensi Bahu: 31.72°
#
# Gambar: 20250317_152346_frame_0025_preproc
# Sudut Lutut: 88.14°
# Sudut Leher: 0.44°
# Sudut Trunk: 35.02°
# Sudut Fleksi/Ekstensi Bahu: 32.72°
#
# Gambar: 20250317_152346_frame_0026_preproc
# Sudut Lutut: 85.94°
# Sudut Leher: 2.17°
# Sudut Trunk: 32.81°
# Sudut Fleksi/Ekstensi Bahu: 33.36°
#
# Gambar: 20250317_152346_frame_0027_preproc
# Sudut Lutut: 92.15°
# Sudut Leher: 3.08°
# Sudut Trunk: 36.31°
# Sudut Fleksi/Ekstensi Bahu: 31.18°
#
# Gambar: 20250317_152346_frame_0028_preproc
# Sudut Lutut: 88.50°
# Sudut Leher: 3.19°
# Sudut Trunk: 33.49°
# Sudut Fleksi/Ekstensi Bahu: 30.10°
#
# Gambar: 20250317_152346_frame_0029_preproc
# Sudut Lutut: 86.88°
# Sudut Siku: 116.14°
# Sudut Leher: 3.16°
# Sudut Trunk: 33.87°
# Sudut Pergelangan Tangan: 54.79°
# Sudut Fleksi/Ekstensi Bahu: 30.32°
#
# Gambar: 20250317_152346_frame_0030_preproc
# Sudut Lutut: 87.84°
# Sudut Siku: 109.50°
# Sudut Leher: 8.12°
# Sudut Trunk: 33.89°
# Sudut Pergelangan Tangan: 80.18°
# Sudut Fleksi/Ekstensi Bahu: 35.37°
#
# Gambar: 20250317_152346_frame_0031_preproc
# Sudut Lutut: 90.77°
# Sudut Siku: 105.69°
# Sudut Leher: 4.51°
# Sudut Trunk: 36.00°
# Sudut Pergelangan Tangan: 44.23°
# Sudut Fleksi/Ekstensi Bahu: 32.85°
#
# Gambar: 20250317_152346_frame_0032_preproc
# Sudut Lutut: 90.05°
# Sudut Siku: 106.35°
# Sudut Leher: 4.05°
# Sudut Trunk: 35.95°
# Sudut Pergelangan Tangan: 66.38°
# Sudut Fleksi/Ekstensi Bahu: 32.49°
#
# Gambar: 20250317_152346_frame_0033_preproc
# Sudut Lutut: 91.96°
# Sudut Siku: 105.28°
# Sudut Leher: 5.25°
# Sudut Trunk: 37.38°
# Sudut Pergelangan Tangan: 85.60°
# Sudut Fleksi/Ekstensi Bahu: 35.23°
#
# Gambar: 20250317_152346_frame_0034_preproc
# Sudut Lutut: 89.52°
# Sudut Siku: 119.53°
# Sudut Leher: 6.64°
# Sudut Trunk: 36.25°
# Sudut Pergelangan Tangan: 54.68°
# Sudut Fleksi/Ekstensi Bahu: 31.49°
#
# Gambar: 20250317_152346_frame_0035_preproc
# Sudut Lutut: 89.62°
# Sudut Siku: 113.78°
# Sudut Leher: 1.80°
# Sudut Trunk: 37.00°
# Sudut Pergelangan Tangan: 43.58°
# Sudut Fleksi/Ekstensi Bahu: 33.51°
#
# Gambar: 20250317_152346_frame_0036_preproc
# Sudut Lutut: 91.06°
# Sudut Siku: 115.99°
# Sudut Leher: 5.11°
# Sudut Trunk: 35.87°
# Sudut Pergelangan Tangan: 58.51°
# Sudut Fleksi/Ekstensi Bahu: 31.25°
#
# Gambar: 20250317_152346_frame_0037_preproc
# Sudut Lutut: 91.75°
# Sudut Siku: 109.13°
# Sudut Leher: 0.66°
# Sudut Trunk: 37.30°
# Sudut Pergelangan Tangan: 63.62°
# Sudut Fleksi/Ekstensi Bahu: 35.04°
#
# Gambar: 20250317_152346_frame_0038_preproc
# Sudut Lutut: 90.81°
# Sudut Siku: 110.37°
# Sudut Leher: 0.08°
# Sudut Trunk: 36.38°
# Sudut Pergelangan Tangan: 58.36°
# Sudut Fleksi/Ekstensi Bahu: 32.81°
#
# Gambar: 20250317_152346_frame_0039_preproc
# Sudut Lutut: 91.04°
# Sudut Siku: 117.22°
# Sudut Leher: 1.46°
# Sudut Trunk: 36.94°
# Sudut Pergelangan Tangan: 57.61°
# Sudut Fleksi/Ekstensi Bahu: 31.86°
#
# Gambar: 20250317_152346_frame_0040_preproc
# Sudut Lutut: 90.71°
# Sudut Siku: 114.68°
# Sudut Leher: 4.05°
# Sudut Trunk: 37.45°
# Sudut Pergelangan Tangan: 59.77°
# Sudut Fleksi/Ekstensi Bahu: 34.45°
#
# Gambar: 20250317_152346_frame_0041_preproc
# Sudut Lutut: 87.76°
# Sudut Siku: 108.68°
# Sudut Leher: 5.23°
# Sudut Trunk: 34.48°
# Sudut Pergelangan Tangan: 41.99°
# Sudut Fleksi/Ekstensi Bahu: 35.85°
#
# Gambar: 20250317_152346_frame_0042_preproc
# Sudut Lutut: 87.07°
# Sudut Siku: 110.98°
# Sudut Leher: 8.75°
# Sudut Trunk: 33.02°
# Sudut Pergelangan Tangan: 57.53°
# Sudut Fleksi/Ekstensi Bahu: 31.12°
#
# Gambar: 20250317_152346_frame_0043_preproc
# Sudut Lutut: 87.81°
# Sudut Siku: 106.79°
# Sudut Leher: 6.20°
# Sudut Trunk: 33.39°
# Sudut Pergelangan Tangan: 49.36°
# Sudut Fleksi/Ekstensi Bahu: 33.38°
#
# Gambar: 20250317_152346_frame_0044_preproc
# Sudut Lutut: 89.10°
# Sudut Siku: 114.90°
# Sudut Leher: 3.63°
# Sudut Trunk: 35.90°
# Sudut Pergelangan Tangan: 63.52°
# Sudut Fleksi/Ekstensi Bahu: 34.75°
#
# Gambar: 20250317_152346_frame_0045_preproc
# Sudut Lutut: 86.69°
# Sudut Siku: 113.99°
# Sudut Leher: 8.28°
# Sudut Trunk: 32.70°
# Sudut Pergelangan Tangan: 44.18°
# Sudut Fleksi/Ekstensi Bahu: 33.96°
#
# Gambar: 20250317_152346_frame_0046_preproc
# Sudut Lutut: 90.48°
# Sudut Siku: 113.98°
# Sudut Leher: 3.72°
# Sudut Trunk: 36.30°
# Sudut Pergelangan Tangan: 62.78°
# Sudut Fleksi/Ekstensi Bahu: 35.22°
#
# Gambar: 20250317_152346_frame_0047_preproc
# Sudut Lutut: 88.79°
# Sudut Siku: 119.06°
# Sudut Leher: 4.01°
# Sudut Trunk: 33.59°
# Sudut Pergelangan Tangan: 56.00°
# Sudut Fleksi/Ekstensi Bahu: 34.61°
#
# Gambar: 20250317_152346_frame_0048_preproc
# Sudut Lutut: 90.57°
# Sudut Siku: 120.10°
# Sudut Leher: 0.69°
# Sudut Trunk: 35.95°
# Sudut Pergelangan Tangan: 54.77°
# Sudut Fleksi/Ekstensi Bahu: 36.01°
#
# Gambar: 20250317_152346_frame_0049_preproc
# Sudut Lutut: 92.25°
# Sudut Siku: 120.47°
# Sudut Leher: 1.59°
# Sudut Trunk: 37.91°
# Sudut Pergelangan Tangan: 49.01°
# Sudut Fleksi/Ekstensi Bahu: 34.90°
#
# Gambar: 20250317_152346_frame_0050_preproc
# Sudut Lutut: 88.35°
# Sudut Leher: 1.95°
# Sudut Trunk: 34.69°
# Sudut Fleksi/Ekstensi Bahu: 36.49°
#
# Gambar: 20250317_152346_frame_0051_preproc
# Sudut Lutut: 89.03°
# Sudut Leher: 0.29°
# Sudut Trunk: 34.48°
# Sudut Fleksi/Ekstensi Bahu: 34.90°
#
# Gambar: 20250317_152346_frame_0052_preproc
# Sudut Lutut: 91.95°
# Sudut Leher: 2.16°
# Sudut Trunk: 35.71°
# Sudut Fleksi/Ekstensi Bahu: 34.33°
#
# Gambar: 20250317_152346_frame_0053_preproc
# Sudut Lutut: 91.52°
# Sudut Leher: 1.61°
# Sudut Trunk: 35.32°
# Sudut Fleksi/Ekstensi Bahu: 34.02°
#
# Gambar: 20250317_152346_frame_0054_preproc
# Sudut Lutut: 91.39°
# Sudut Leher: 2.26°
# Sudut Trunk: 35.62°
# Sudut Fleksi/Ekstensi Bahu: 33.18°
#
# Gambar: 20250317_152346_frame_0055_preproc
# Sudut Lutut: 91.57°
# Sudut Leher: 2.15°
# Sudut Trunk: 35.42°
# Sudut Fleksi/Ekstensi Bahu: 34.14°
#
# Gambar: 20250317_152346_frame_0056_preproc
# Sudut Lutut: 88.65°
# Sudut Leher: 1.53°
# Sudut Trunk: 35.33°
# Sudut Fleksi/Ekstensi Bahu: 33.96°
#
# Gambar: 20250317_152346_frame_0057_preproc
# Sudut Lutut: 89.97°
# Sudut Siku: 118.25°
# Sudut Leher: 2.31°
# Sudut Trunk: 35.39°
# Sudut Pergelangan Tangan: 56.76°
# Sudut Fleksi/Ekstensi Bahu: 33.18°
#
# Gambar: 20250317_152346_frame_0058_preproc
# Sudut Lutut: 91.09°
# Sudut Siku: 117.44°
# Sudut Leher: 4.07°
# Sudut Trunk: 34.31°
# Sudut Pergelangan Tangan: 58.75°
# Sudut Fleksi/Ekstensi Bahu: 34.97°
#
# Gambar: 20250317_152346_frame_0059_preproc
# Sudut Lutut: 90.35°
# Sudut Leher: 2.27°
# Sudut Trunk: 35.74°
# Sudut Fleksi/Ekstensi Bahu: 33.41°
#
# Gambar: 20250317_152346_frame_0060_preproc
# Sudut Lutut: 91.44°
# Sudut Siku: 118.27°
# Sudut Leher: 3.62°
# Sudut Trunk: 35.16°
# Sudut Pergelangan Tangan: 55.09°
# Sudut Fleksi/Ekstensi Bahu: 32.39°
#
# Gambar: 20250317_152346_frame_0061_preproc
# Sudut Lutut: 88.49°
# Sudut Leher: 1.03°
# Sudut Trunk: 33.90°
# Sudut Fleksi/Ekstensi Bahu: 34.29°
#
# Gambar: 20250317_152346_frame_0062_preproc
# Sudut Lutut: 89.34°
# Sudut Leher: 0.57°
# Sudut Trunk: 34.98°
# Sudut Fleksi/Ekstensi Bahu: 34.03°
#
# Gambar: 20250317_152346_frame_0063_preproc
# Sudut Lutut: 89.63°
# Sudut Leher: 1.60°
# Sudut Trunk: 34.83°
# Sudut Fleksi/Ekstensi Bahu: 34.94°
#
# Gambar: 20250317_152346_frame_0064_preproc
# Sudut Lutut: 92.03°
# Sudut Leher: 0.16°
# Sudut Trunk: 35.83°
# Sudut Fleksi/Ekstensi Bahu: 34.43°
#
# Gambar: 20250317_152346_frame_0065_preproc
# Sudut Lutut: 89.04°
# Sudut Leher: 0.09°
# Sudut Trunk: 35.24°
# Sudut Fleksi/Ekstensi Bahu: 33.13°
#
# Gambar: 20250317_152346_frame_0066_preproc
# Sudut Lutut: 89.58°
# Sudut Leher: 1.82°
# Sudut Trunk: 35.38°
# Sudut Fleksi/Ekstensi Bahu: 33.23°
#
# Gambar: 20250317_152346_frame_0067_preproc
# Sudut Lutut: 91.79°
# Sudut Siku: 118.00°
# Sudut Leher: 1.87°
# Sudut Trunk: 35.63°
# Sudut Pergelangan Tangan: 53.45°
# Sudut Fleksi/Ekstensi Bahu: 35.75°
#
# Gambar: 20250317_152346_frame_0068_preproc
# Sudut Lutut: 87.26°
# Sudut Siku: 116.26°
# Sudut Leher: 2.23°
# Sudut Trunk: 32.28°
# Sudut Pergelangan Tangan: 58.60°
# Sudut Fleksi/Ekstensi Bahu: 34.82°
#
# Gambar: 20250317_152346_frame_0069_preproc
# Sudut Lutut: 87.60°
# Sudut Siku: 119.37°
# Sudut Leher: 0.29°
# Sudut Trunk: 34.89°
# Sudut Pergelangan Tangan: 56.31°
# Sudut Fleksi/Ekstensi Bahu: 32.58°
#
# Gambar: 20250317_152346_frame_0070_preproc
# Sudut Lutut: 83.95°
# Sudut Siku: 117.94°
# Sudut Leher: 3.18°
# Sudut Trunk: 32.67°
# Sudut Pergelangan Tangan: 64.93°
# Sudut Fleksi/Ekstensi Bahu: 33.48°
#
# Gambar: 20250317_152346_frame_0071_preproc
# Sudut Lutut: 86.26°
# Sudut Siku: 117.42°
# Sudut Leher: 0.21°
# Sudut Trunk: 35.78°
# Sudut Pergelangan Tangan: 58.81°
# Sudut Fleksi/Ekstensi Bahu: 33.49°
#
# Gambar: 20250317_152346_frame_0072_preproc
# Sudut Lutut: 85.87°
# Sudut Leher: 0.41°
# Sudut Trunk: 36.05°
# Sudut Fleksi/Ekstensi Bahu: 33.85°
#
# Gambar: 20250317_152346_frame_0073_preproc
# Sudut Lutut: 86.48°
# Sudut Siku: 119.00°
# Sudut Leher: 2.05°
# Sudut Trunk: 35.91°
# Sudut Pergelangan Tangan: 65.38°
# Sudut Fleksi/Ekstensi Bahu: 33.65°
#
# Gambar: 20250317_152346_frame_0074_preproc
# Sudut Lutut: 88.18°
# Sudut Siku: 113.74°
# Sudut Leher: 0.35°
# Sudut Trunk: 35.05°
# Sudut Pergelangan Tangan: 44.35°
# Sudut Fleksi/Ekstensi Bahu: 33.87°
#
# Gambar: 20250317_152346_frame_0075_preproc
# Sudut Lutut: 90.86°
# Sudut Siku: 119.13°
# Sudut Leher: 2.92°
# Sudut Trunk: 34.51°
# Sudut Pergelangan Tangan: 60.33°
# Sudut Fleksi/Ekstensi Bahu: 33.76°
#
# Gambar: 20250317_152346_frame_0076_preproc
# Sudut Lutut: 88.73°
# Sudut Siku: 103.71°
# Sudut Leher: 1.58°
# Sudut Trunk: 31.45°
# Sudut Pergelangan Tangan: 12.81°
# Sudut Fleksi/Ekstensi Bahu: 32.51°
#
# Gambar: 20250317_152346_frame_0077_preproc
# Sudut Lutut: 83.79°
# Sudut Siku: 98.05°
# Sudut Leher: 13.97°
# Sudut Trunk: 28.38°
# Sudut Pergelangan Tangan: 8.52°
# Sudut Fleksi/Ekstensi Bahu: 22.43°
#
# Gambar: 20250317_152346_frame_0078_preproc
# Sudut Lutut: 89.77°
# Sudut Leher: 11.94°
# Sudut Trunk: 32.16°
# Sudut Fleksi/Ekstensi Bahu: 51.31°
#
# Gambar: 20250317_152346_frame_0079_preproc
# Sudut Lutut: 94.29°
# Sudut Siku: 57.19°
# Sudut Leher: 14.64°
# Sudut Trunk: 34.15°
# Sudut Pergelangan Tangan: 46.23°
# Sudut Fleksi/Ekstensi Bahu: 53.23°
#
# Gambar: 20250317_152346_frame_0080_preproc
# Sudut Lutut: 94.77°
# Sudut Siku: 54.54°
# Sudut Leher: 15.37°
# Sudut Trunk: 32.49°
# Sudut Pergelangan Tangan: 32.34°
# Sudut Fleksi/Ekstensi Bahu: 56.28°
#
# Gambar: 20250317_152346_frame_0081_preproc
# Sudut Lutut: 97.37°
# Sudut Siku: 51.79°
# Sudut Leher: 14.61°
# Sudut Trunk: 32.02°
# Sudut Pergelangan Tangan: 29.38°
# Sudut Fleksi/Ekstensi Bahu: 59.43°
#
# Gambar: 20250317_152346_frame_0082_preproc
# Sudut Lutut: 96.72°
# Sudut Siku: 54.38°
# Sudut Leher: 14.83°
# Sudut Trunk: 34.08°
# Sudut Pergelangan Tangan: 22.22°
# Sudut Fleksi/Ekstensi Bahu: 57.07°
#
# Gambar: 20250317_152346_frame_0083_preproc
# Sudut Lutut: 95.17°
# Sudut Siku: 52.51°
# Sudut Leher: 12.12°
# Sudut Trunk: 32.95°
# Sudut Pergelangan Tangan: 4.09°
# Sudut Fleksi/Ekstensi Bahu: 56.95°
#
# Gambar: 20250317_152346_frame_0084_preproc
# Sudut Lutut: 93.27°
# Sudut Siku: 52.41°
# Sudut Leher: 13.31°
# Sudut Trunk: 33.01°
# Sudut Pergelangan Tangan: 38.45°
# Sudut Fleksi/Ekstensi Bahu: 58.17°
#
# Gambar: 20250317_152346_frame_0085_preproc
# Sudut Lutut: 95.13°
# Sudut Siku: 52.79°
# Sudut Leher: 15.99°
# Sudut Trunk: 31.56°
# Sudut Pergelangan Tangan: 63.01°
# Sudut Fleksi/Ekstensi Bahu: 57.71°
#
# Gambar: 20250317_152346_frame_0086_preproc
# Sudut Lutut: 99.79°
# Sudut Siku: 53.66°
# Sudut Leher: 13.80°
# Sudut Trunk: 33.31°
# Sudut Pergelangan Tangan: 61.41°
# Sudut Fleksi/Ekstensi Bahu: 57.62°
#
# Gambar: 20250317_152346_frame_0087_preproc
# Sudut Lutut: 97.86°
# Sudut Siku: 53.18°
# Sudut Leher: 12.72°
# Sudut Trunk: 32.52°
# Sudut Pergelangan Tangan: 50.21°
# Sudut Fleksi/Ekstensi Bahu: 61.24°
#
# Gambar: 20250317_152346_frame_0088_preproc
# Sudut Lutut: 98.95°
# Sudut Siku: 54.81°
# Sudut Leher: 11.37°
# Sudut Trunk: 33.98°
# Sudut Pergelangan Tangan: 42.46°
# Sudut Fleksi/Ekstensi Bahu: 57.50°
#
# Gambar: 20250317_152346_frame_0089_preproc
# Sudut Lutut: 97.02°
# Sudut Siku: 54.93°
# Sudut Leher: 14.06°
# Sudut Trunk: 32.45°
# Sudut Pergelangan Tangan: 18.44°
# Sudut Fleksi/Ekstensi Bahu: 58.15°
#
# Gambar: 20250317_152346_frame_0090_preproc
# Sudut Lutut: 98.94°
# Sudut Siku: 55.64°
# Sudut Leher: 12.64°
# Sudut Trunk: 31.03°
# Sudut Pergelangan Tangan: 36.64°
# Sudut Fleksi/Ekstensi Bahu: 57.12°
#
# Gambar: 20250317_152346_frame_0091_preproc
# Sudut Lutut: 101.41°
# Sudut Siku: 56.33°
# Sudut Leher: 13.88°
# Sudut Trunk: 33.89°
# Sudut Pergelangan Tangan: 39.17°
# Sudut Fleksi/Ekstensi Bahu: 55.20°
#
# Gambar: 20250317_152346_frame_0092_preproc
# Sudut Lutut: 95.19°
# Sudut Siku: 54.96°
# Sudut Leher: 14.06°
# Sudut Trunk: 32.00°
# Sudut Pergelangan Tangan: 42.93°
# Sudut Fleksi/Ekstensi Bahu: 57.06°
#
# Gambar: 20250317_152346_frame_0093_preproc
# Sudut Lutut: 99.00°
# Sudut Siku: 56.64°
# Sudut Leher: 12.52°
# Sudut Trunk: 31.81°
# Sudut Pergelangan Tangan: 40.20°
# Sudut Fleksi/Ekstensi Bahu: 56.11°
#
# Gambar: 20250317_152346_frame_0094_preproc
# Sudut Lutut: 99.03°
# Sudut Siku: 55.77°
# Sudut Leher: 15.26°
# Sudut Trunk: 33.00°
# Sudut Pergelangan Tangan: 80.93°
# Sudut Fleksi/Ekstensi Bahu: 56.33°
#
# Gambar: 20250317_152346_frame_0095_preproc
# Sudut Lutut: 98.11°
# Sudut Siku: 53.80°
# Sudut Leher: 13.95°
# Sudut Trunk: 31.15°
# Sudut Pergelangan Tangan: 54.53°
# Sudut Fleksi/Ekstensi Bahu: 57.47°
#
# Gambar: 20250317_152346_frame_0096_preproc
# Sudut Lutut: 100.19°
# Sudut Siku: 58.22°
# Sudut Leher: 11.86°
# Sudut Trunk: 34.18°
# Sudut Pergelangan Tangan: 72.80°
# Sudut Fleksi/Ekstensi Bahu: 57.67°
#
# Gambar: 20250317_152346_frame_0097_preproc
# Sudut Lutut: 98.39°
# Sudut Siku: 54.68°
# Sudut Leher: 8.35°
# Sudut Trunk: 35.16°
# Sudut Pergelangan Tangan: 37.74°
# Sudut Fleksi/Ekstensi Bahu: 59.38°
#
# Gambar: 20250317_152346_frame_0098_preproc
# Sudut Lutut: 93.56°
# Sudut Siku: 55.76°
# Sudut Leher: 8.06°
# Sudut Trunk: 32.47°
# Sudut Pergelangan Tangan: 40.62°
# Sudut Fleksi/Ekstensi Bahu: 55.91°
#
# Gambar: 20250317_152346_frame_0099_preproc
# Sudut Lutut: 92.01°
# Sudut Siku: 49.83°
# Sudut Leher: 8.26°
# Sudut Trunk: 33.02°
# Sudut Pergelangan Tangan: 37.67°
# Sudut Fleksi/Ekstensi Bahu: 59.56°
#
# Gambar: 20250317_152346_frame_0100_preproc
# Sudut Lutut: 88.05°
# Sudut Siku: 48.89°
# Sudut Leher: 12.79°
# Sudut Trunk: 32.50°
# Sudut Pergelangan Tangan: 3.99°
# Sudut Fleksi/Ekstensi Bahu: 62.01°
#
# Gambar: 20250317_152346_frame_0101_preproc
# Sudut Lutut: 91.18°
# Sudut Siku: 49.46°
# Sudut Leher: 8.53°
# Sudut Trunk: 33.70°
# Sudut Pergelangan Tangan: 1.58°
# Sudut Fleksi/Ekstensi Bahu: 59.90°
#
# Gambar: 20250317_152346_frame_0102_preproc
# Sudut Lutut: 94.81°
# Sudut Siku: 51.42°
# Sudut Leher: 14.10°
# Sudut Trunk: 31.34°
# Sudut Pergelangan Tangan: 38.66°
# Sudut Fleksi/Ekstensi Bahu: 58.85°
#
# Gambar: 20250317_152346_frame_0103_preproc
# Sudut Lutut: 97.46°
# Sudut Siku: 53.56°
# Sudut Leher: 13.72°
# Sudut Trunk: 32.29°
# Sudut Pergelangan Tangan: 29.45°
# Sudut Fleksi/Ekstensi Bahu: 58.61°
#
# Gambar: 20250317_152346_frame_0104_preproc
# Sudut Lutut: 97.66°
# Sudut Siku: 53.44°
# Sudut Leher: 15.23°
# Sudut Trunk: 32.04°
# Sudut Pergelangan Tangan: 42.93°
# Sudut Fleksi/Ekstensi Bahu: 55.02°
#
# Gambar: 20250317_152346_frame_0105_preproc
# Sudut Lutut: 95.98°
# Sudut Siku: 51.40°
# Sudut Leher: 14.25°
# Sudut Trunk: 31.57°
# Sudut Pergelangan Tangan: 59.51°
# Sudut Fleksi/Ekstensi Bahu: 60.08°
#
# Gambar: 20250317_152346_frame_0106_preproc
# Sudut Lutut: 97.33°
# Sudut Siku: 52.47°
# Sudut Leher: 14.16°
# Sudut Trunk: 32.31°
# Sudut Pergelangan Tangan: 13.44°
# Sudut Fleksi/Ekstensi Bahu: 60.72°
#
# Gambar: 20250317_152346_frame_0107_preproc
# Sudut Lutut: 93.93°
# Sudut Siku: 53.98°
# Sudut Leher: 12.73°
# Sudut Trunk: 32.54°
# Sudut Pergelangan Tangan: 35.01°
# Sudut Fleksi/Ekstensi Bahu: 59.42°
#
# Gambar: 20250317_152346_frame_0108_preproc
# Sudut Lutut: 97.11°
# Sudut Siku: 54.28°
# Sudut Leher: 18.55°
# Sudut Trunk: 31.33°
# Sudut Pergelangan Tangan: 34.17°
# Sudut Fleksi/Ekstensi Bahu: 54.75°
#
# Gambar: 20250317_152346_frame_0109_preproc
# Sudut Lutut: 96.35°
# Sudut Siku: 51.95°
# Sudut Leher: 16.33°
# Sudut Trunk: 31.02°
# Sudut Pergelangan Tangan: 10.77°
# Sudut Fleksi/Ekstensi Bahu: 59.63°
#
# Gambar: 20250317_152346_frame_0110_preproc
# Sudut Lutut: 96.90°
# Sudut Siku: 53.40°
# Sudut Leher: 15.83°
# Sudut Trunk: 31.32°
# Sudut Pergelangan Tangan: 28.43°
# Sudut Fleksi/Ekstensi Bahu: 59.49°
#
# Gambar: 20250317_152346_frame_0111_preproc
# Sudut Lutut: 96.77°
# Sudut Siku: 50.15°
# Sudut Leher: 14.00°
# Sudut Trunk: 33.03°
# Sudut Pergelangan Tangan: 70.25°
# Sudut Fleksi/Ekstensi Bahu: 61.27°
#
# Gambar: 20250317_152346_frame_0112_preproc
# Sudut Lutut: 97.18°
# Sudut Siku: 52.58°
# Sudut Leher: 15.43°
# Sudut Trunk: 30.62°
# Sudut Pergelangan Tangan: 38.62°
# Sudut Fleksi/Ekstensi Bahu: 59.45°
#
# Gambar: 20250317_152346_frame_0113_preproc
# Sudut Lutut: 96.26°
# Sudut Siku: 52.58°
# Sudut Leher: 12.79°
# Sudut Trunk: 32.63°
# Sudut Pergelangan Tangan: 65.02°
# Sudut Fleksi/Ekstensi Bahu: 59.30°
#
# Gambar: 20250317_152346_frame_0114_preproc
# Sudut Lutut: 97.20°
# Sudut Siku: 51.55°
# Sudut Leher: 15.15°
# Sudut Trunk: 32.25°
# Sudut Pergelangan Tangan: 25.39°
# Sudut Fleksi/Ekstensi Bahu: 62.81°
#
# Gambar: 20250317_152346_frame_0115_preproc
# Sudut Lutut: 97.42°
# Sudut Siku: 53.65°
# Sudut Leher: 14.17°
# Sudut Trunk: 32.92°
# Sudut Pergelangan Tangan: 70.51°
# Sudut Fleksi/Ekstensi Bahu: 61.62°
#
# Gambar: 20250317_152346_frame_0116_preproc
# Sudut Lutut: 95.10°
# Sudut Siku: 51.55°
# Sudut Leher: 10.63°
# Sudut Trunk: 33.13°
# Sudut Pergelangan Tangan: 35.70°
# Sudut Fleksi/Ekstensi Bahu: 61.17°
#
# Gambar: 20250317_152346_frame_0117_preproc
# Sudut Lutut: 96.29°
# Sudut Siku: 53.80°
# Sudut Leher: 15.86°
# Sudut Trunk: 31.09°
# Sudut Pergelangan Tangan: 74.18°
# Sudut Fleksi/Ekstensi Bahu: 57.91°
#
# Gambar: 20250317_152346_frame_0118_preproc
# Sudut Lutut: 96.55°
# Sudut Siku: 49.57°
# Sudut Leher: 7.08°
# Sudut Trunk: 33.00°
# Sudut Pergelangan Tangan: 62.10°
# Sudut Fleksi/Ekstensi Bahu: 60.93°
#
# Gambar: 20250317_152346_frame_0119_preproc
# Sudut Lutut: 96.63°
# Sudut Siku: 38.02°
# Sudut Leher: 18.38°
# Sudut Trunk: 21.17°
# Sudut Pergelangan Tangan: 40.31°
# Sudut Fleksi/Ekstensi Bahu: 61.96°
#
# Gambar: 20250317_152346_frame_0120_preproc
# Sudut Lutut: 94.85°
# Sudut Siku: 39.26°
# Sudut Leher: 11.43°
# Sudut Trunk: 21.95°
# Sudut Pergelangan Tangan: 85.24°
# Sudut Fleksi/Ekstensi Bahu: 62.65°
#
# Gambar: 20250317_152346_frame_0121_preproc
# Sudut Lutut: 86.73°
# Sudut Siku: 40.41°
# Sudut Leher: 10.08°
# Sudut Trunk: 28.09°
# Sudut Pergelangan Tangan: 28.98°
# Sudut Fleksi/Ekstensi Bahu: 58.65°
#
# Gambar: 20250317_152346_frame_0122_preproc
# Sudut Lutut: 88.91°
# Sudut Siku: 47.38°
# Sudut Leher: 18.40°
# Sudut Trunk: 27.41°
# Sudut Pergelangan Tangan: 28.02°
# Sudut Fleksi/Ekstensi Bahu: 59.58°
#
# Gambar: 20250317_152346_frame_0123_preproc
# Sudut Lutut: 94.15°
# Sudut Siku: 48.15°
# Sudut Leher: 13.67°
# Sudut Trunk: 29.48°
# Sudut Pergelangan Tangan: 44.76°
# Sudut Fleksi/Ekstensi Bahu: 58.04°
#
# Gambar: 20250317_152346_frame_0124_preproc
# Sudut Lutut: 95.39°
# Sudut Siku: 43.10°
# Sudut Leher: 18.88°
# Sudut Trunk: 25.93°
# Sudut Pergelangan Tangan: 27.61°
# Sudut Fleksi/Ekstensi Bahu: 59.40°
#
# Gambar: 20250317_152346_frame_0125_preproc
# Sudut Lutut: 89.00°
# Sudut Siku: 45.31°
# Sudut Leher: 15.03°
# Sudut Trunk: 27.32°
# Sudut Pergelangan Tangan: 26.54°
# Sudut Fleksi/Ekstensi Bahu: 60.61°
#
# Gambar: 20250317_152346_frame_0126_preproc
# Sudut Lutut: 99.47°
# Sudut Siku: 47.72°
# Sudut Leher: 15.61°
# Sudut Trunk: 30.59°
# Sudut Pergelangan Tangan: 37.44°
# Sudut Fleksi/Ekstensi Bahu: 61.94°
#
# Gambar: 20250317_152346_frame_0127_preproc
# Sudut Lutut: 99.18°
# Sudut Siku: 47.07°
# Sudut Leher: 10.47°
# Sudut Trunk: 32.15°
# Sudut Pergelangan Tangan: 39.26°
# Sudut Fleksi/Ekstensi Bahu: 61.98°
#
# Gambar: 20250317_152346_frame_0128_preproc
# Sudut Lutut: 93.93°
# Sudut Siku: 47.98°
# Sudut Leher: 12.66°
# Sudut Trunk: 28.08°
# Sudut Pergelangan Tangan: 11.46°
# Sudut Fleksi/Ekstensi Bahu: 58.93°
#
# Gambar: 20250317_152346_frame_0129_preproc
# Sudut Lutut: 94.23°
# Sudut Siku: 45.67°
# Sudut Leher: 14.38°
# Sudut Trunk: 28.32°
# Sudut Pergelangan Tangan: 36.87°
# Sudut Fleksi/Ekstensi Bahu: 63.18°
#
# Gambar: 20250317_152346_frame_0130_preproc
# Sudut Lutut: 98.60°
# Sudut Siku: 47.43°
# Sudut Leher: 12.46°
# Sudut Trunk: 30.96°
# Sudut Pergelangan Tangan: 2.22°
# Sudut Fleksi/Ekstensi Bahu: 62.10°
#
# Gambar: 20250317_152346_frame_0131_preproc
# Sudut Lutut: 99.84°
# Sudut Siku: 49.43°
# Sudut Leher: 12.53°
# Sudut Trunk: 30.41°
# Sudut Pergelangan Tangan: 33.09°
# Sudut Fleksi/Ekstensi Bahu: 59.69°
#
# Gambar: 20250317_152346_frame_0132_preproc
# Sudut Lutut: 96.24°
# Sudut Siku: 46.88°
# Sudut Leher: 9.05°
# Sudut Trunk: 31.22°
# Sudut Pergelangan Tangan: 78.08°
# Sudut Fleksi/Ekstensi Bahu: 62.64°
#
# Gambar: 20250317_152346_frame_0133_preproc
# Sudut Lutut: 94.77°
# Sudut Siku: 43.03°
# Sudut Leher: 16.29°
# Sudut Trunk: 27.05°
# Sudut Pergelangan Tangan: 5.86°
# Sudut Fleksi/Ekstensi Bahu: 57.96°
#
# Gambar: 20250317_152346_frame_0134_preproc
# Sudut Lutut: 87.60°
# Sudut Siku: 42.45°
# Sudut Leher: 11.01°
# Sudut Trunk: 23.76°
# Sudut Pergelangan Tangan: 65.63°
# Sudut Fleksi/Ekstensi Bahu: 57.38°
#
# Gambar: 20250317_152346_frame_0135_preproc
# Sudut Lutut: 86.34°
# Sudut Siku: 63.63°
# Sudut Leher: 14.00°
# Sudut Trunk: 35.98°
# Sudut Pergelangan Tangan: 29.85°
# Sudut Fleksi/Ekstensi Bahu: 38.34°
#
# Gambar: 20250317_152346_frame_0136_preproc
# Sudut Lutut: 86.75°
# Sudut Siku: 58.76°
# Sudut Leher: 10.12°
# Sudut Trunk: 32.02°
# Sudut Pergelangan Tangan: 9.62°
# Sudut Fleksi/Ekstensi Bahu: 50.23°
#
# Gambar: 20250317_152346_frame_0137_preproc
# Sudut Lutut: 88.83°
# Sudut Siku: 57.53°
# Sudut Leher: 6.39°
# Sudut Trunk: 33.12°
# Sudut Pergelangan Tangan: 35.59°
# Sudut Fleksi/Ekstensi Bahu: 50.57°
#
# Gambar: 20250317_152346_frame_0138_preproc
# Sudut Lutut: 90.13°
# Sudut Siku: 58.70°
# Sudut Leher: 9.57°
# Sudut Trunk: 33.01°
# Sudut Pergelangan Tangan: 10.98°
# Sudut Fleksi/Ekstensi Bahu: 46.60°
#
# Gambar: 20250317_152346_frame_0139_preproc
# Sudut Lutut: 90.38°
# Sudut Siku: 55.15°
# Sudut Leher: 3.84°
# Sudut Trunk: 33.00°
# Sudut Pergelangan Tangan: 25.94°
# Sudut Fleksi/Ekstensi Bahu: 51.70°
#
# Gambar: 20250317_152346_frame_0140_preproc
# Sudut Lutut: 91.35°
# Sudut Siku: 57.86°
# Sudut Leher: 8.77°
# Sudut Trunk: 32.72°
# Sudut Pergelangan Tangan: 26.24°
# Sudut Fleksi/Ekstensi Bahu: 50.22°
#
# Gambar: 20250317_152346_frame_0141_preproc
# Sudut Lutut: 88.99°
# Sudut Siku: 64.93°
# Sudut Leher: 2.59°
# Sudut Trunk: 33.29°
# Sudut Pergelangan Tangan: 109.38°
# Sudut Fleksi/Ekstensi Bahu: 49.25°
#
# Gambar: 20250317_152346_frame_0142_preproc
# Sudut Lutut: 94.62°
# Sudut Leher: 10.92°
# Sudut Trunk: 34.83°
# Sudut Fleksi/Ekstensi Bahu: 52.38°
#
# Gambar: 20250317_152346_frame_0143_preproc
# Sudut Lutut: 92.22°
# Sudut Siku: 49.95°
# Sudut Leher: 2.22°
# Sudut Trunk: 35.87°
# Sudut Pergelangan Tangan: 34.48°
# Sudut Fleksi/Ekstensi Bahu: 46.69°
#
# Gambar: 20250317_152346_frame_0144_preproc
# Sudut Lutut: 88.62°
# Sudut Siku: 53.58°
# Sudut Leher: 6.17°
# Sudut Trunk: 33.87°
# Sudut Pergelangan Tangan: 8.31°
# Sudut Fleksi/Ekstensi Bahu: 50.87°
#
# Gambar: 20250317_152346_frame_0145_preproc
# Sudut Lutut: 93.25°
# Sudut Siku: 53.83°
# Sudut Leher: 7.27°
# Sudut Trunk: 32.32°
# Sudut Pergelangan Tangan: 35.99°
# Sudut Fleksi/Ekstensi Bahu: 54.37°
#
# Gambar: 20250317_152346_frame_0146_preproc
# Sudut Lutut: 92.07°
# Sudut Siku: 56.40°
# Sudut Leher: 5.51°
# Sudut Trunk: 32.51°
# Sudut Pergelangan Tangan: 26.77°
# Sudut Fleksi/Ekstensi Bahu: 49.66°
#
# Gambar: 20250317_152346_frame_0147_preproc
# Sudut Lutut: 93.57°
# Sudut Siku: 58.61°
# Sudut Leher: 3.50°
# Sudut Trunk: 33.89°
# Sudut Pergelangan Tangan: 3.31°
# Sudut Fleksi/Ekstensi Bahu: 49.21°
#
# Gambar: 20250317_152346_frame_0148_preproc
# Sudut Lutut: 95.18°
# Sudut Siku: 55.98°
# Sudut Leher: 3.76°
# Sudut Trunk: 33.88°
# Sudut Pergelangan Tangan: 24.51°
# Sudut Fleksi/Ekstensi Bahu: 51.81°
#
# Gambar: 20250317_152346_frame_0149_preproc
# Sudut Lutut: 94.84°
# Sudut Siku: 55.71°
# Sudut Leher: 6.87°
# Sudut Trunk: 33.99°
# Sudut Pergelangan Tangan: 32.75°
# Sudut Fleksi/Ekstensi Bahu: 50.93°
#
# Gambar: 20250317_152346_frame_0150_preproc
# Sudut Lutut: 89.81°
# Sudut Siku: 61.67°
# Sudut Leher: 7.09°
# Sudut Trunk: 33.90°
# Sudut Pergelangan Tangan: 13.13°
# Sudut Fleksi/Ekstensi Bahu: 45.60°
#
# Gambar: 20250317_152346_frame_0151_preproc
# Sudut Lutut: 89.78°
# Sudut Siku: 57.76°
# Sudut Leher: 2.85°
# Sudut Trunk: 34.78°
# Sudut Pergelangan Tangan: 32.02°
# Sudut Fleksi/Ekstensi Bahu: 52.78°
#
# Gambar: 20250317_152346_frame_0152_preproc
# Sudut Lutut: 92.83°
# Sudut Siku: 56.74°
# Sudut Leher: 2.71°
# Sudut Trunk: 36.58°
# Sudut Pergelangan Tangan: 23.39°
# Sudut Fleksi/Ekstensi Bahu: 48.79°
#
# Gambar: 20250317_152346_frame_0153_preproc
# Sudut Lutut: 88.95°
# Sudut Siku: 56.82°
# Sudut Leher: 2.86°
# Sudut Trunk: 32.91°
# Sudut Pergelangan Tangan: 31.99°
# Sudut Fleksi/Ekstensi Bahu: 50.21°
#
# Gambar: 20250317_152346_frame_0154_preproc
# Sudut Lutut: 92.15°
# Sudut Siku: 60.63°
# Sudut Leher: 1.73°
# Sudut Trunk: 31.87°
# Sudut Pergelangan Tangan: 137.40°
# Sudut Fleksi/Ekstensi Bahu: 52.94°
#
# Gambar: 20250317_152346_frame_0155_preproc
# Sudut Lutut: 93.99°
# Sudut Siku: 55.13°
# Sudut Leher: 2.22°
# Sudut Trunk: 32.96°
# Sudut Pergelangan Tangan: 31.37°
# Sudut Fleksi/Ekstensi Bahu: 51.94°
#
# Gambar: 20250317_152346_frame_0156_preproc
# Sudut Lutut: 90.85°
# Sudut Siku: 59.43°
# Sudut Leher: 4.33°
# Sudut Trunk: 34.50°
# Sudut Pergelangan Tangan: 4.76°
# Sudut Fleksi/Ekstensi Bahu: 49.82°
#
# Gambar: 20250317_152346_frame_0157_preproc
# Sudut Lutut: 93.31°
# Sudut Siku: 57.19°
# Sudut Leher: 1.30°
# Sudut Trunk: 33.80°
# Sudut Pergelangan Tangan: 22.66°
# Sudut Fleksi/Ekstensi Bahu: 49.31°
#
# Gambar: 20250317_152346_frame_0158_preproc
# Sudut Lutut: 98.30°
# Sudut Siku: 56.95°
# Sudut Leher: 10.12°
# Sudut Trunk: 33.26°
# Sudut Pergelangan Tangan: 32.95°
# Sudut Fleksi/Ekstensi Bahu: 51.01°
#
# Gambar: 20250317_152346_frame_0159_preproc
# Sudut Lutut: 95.88°
# Sudut Siku: 53.91°
# Sudut Leher: 8.12°
# Sudut Trunk: 32.13°
# Sudut Pergelangan Tangan: 27.36°
# Sudut Fleksi/Ekstensi Bahu: 51.21°
#
# Gambar: 20250317_152346_frame_0160_preproc
# Sudut Lutut: 92.49°
# Sudut Siku: 49.83°
# Sudut Leher: 7.76°
# Sudut Trunk: 29.56°
# Sudut Pergelangan Tangan: 12.44°
# Sudut Fleksi/Ekstensi Bahu: 56.15°
#
# Gambar: 20250317_152346_frame_0161_preproc
# Sudut Lutut: 82.54°
# Sudut Siku: 61.19°
# Sudut Leher: 13.78°
# Sudut Trunk: 26.24°
# Sudut Pergelangan Tangan: 21.32°
# Sudut Fleksi/Ekstensi Bahu: 49.77°
#
# Gambar: 20250317_152346_frame_0162_preproc
# Sudut Lutut: 88.76°
# Sudut Siku: 48.80°
# Sudut Leher: 12.14°
# Sudut Trunk: 26.06°
# Sudut Pergelangan Tangan: 5.30°
# Sudut Fleksi/Ekstensi Bahu: 55.30°
#
# Gambar: 20250317_152346_frame_0163_preproc
# Sudut Lutut: 91.08°
# Sudut Siku: 58.78°
# Sudut Leher: 12.30°
# Sudut Trunk: 28.84°
# Sudut Pergelangan Tangan: 14.00°
# Sudut Fleksi/Ekstensi Bahu: 54.50°
#
# Gambar: 20250317_152346_frame_0164_preproc
# Sudut Lutut: 90.80°
# Sudut Siku: 52.96°
# Sudut Leher: 12.61°
# Sudut Trunk: 28.11°
# Sudut Pergelangan Tangan: 7.21°
# Sudut Fleksi/Ekstensi Bahu: 57.40°
#
# Gambar: 20250317_152346_frame_0165_preproc
# Sudut Lutut: 94.10°
# Sudut Siku: 55.80°
# Sudut Leher: 19.84°
# Sudut Trunk: 27.61°
# Sudut Pergelangan Tangan: 0.73°
# Sudut Fleksi/Ekstensi Bahu: 52.31°
#
# Gambar: 20250317_152346_frame_0166_preproc
# Sudut Lutut: 91.46°
# Sudut Siku: 50.03°
# Sudut Leher: 15.28°
# Sudut Trunk: 28.64°
# Sudut Pergelangan Tangan: 16.58°
# Sudut Fleksi/Ekstensi Bahu: 53.78°
#
# Gambar: 20250317_152346_frame_0167_preproc
# Sudut Lutut: 91.17°
# Sudut Siku: 50.98°
# Sudut Leher: 14.78°
# Sudut Trunk: 29.35°
# Sudut Pergelangan Tangan: 7.16°
# Sudut Fleksi/Ekstensi Bahu: 54.45°
#
# Gambar: 20250317_152346_frame_0168_preproc
# Sudut Lutut: 88.04°
# Sudut Siku: 56.35°
# Sudut Leher: 15.02°
# Sudut Trunk: 26.91°
# Sudut Pergelangan Tangan: 0.59°
# Sudut Fleksi/Ekstensi Bahu: 51.04°
#
# Gambar: 20250317_152346_frame_0169_preproc
# Sudut Lutut: 85.90°
# Sudut Siku: 51.84°
# Sudut Leher: 15.46°
# Sudut Trunk: 28.26°
# Sudut Pergelangan Tangan: 0.78°
# Sudut Fleksi/Ekstensi Bahu: 54.18°
#
# Gambar: 20250317_152346_frame_0170_preproc
# Sudut Lutut: 85.48°
# Sudut Siku: 52.10°
# Sudut Leher: 14.80°
# Sudut Trunk: 25.22°
# Sudut Pergelangan Tangan: 2.39°
# Sudut Fleksi/Ekstensi Bahu: 54.30°
#
# Gambar: 20250317_152346_frame_0171_preproc
# Sudut Lutut: 91.97°
# Sudut Leher: 14.85°
# Sudut Trunk: 29.08°
# Sudut Fleksi/Ekstensi Bahu: 55.95°
#
# Gambar: 20250317_152346_frame_0172_preproc
# Sudut Lutut: 88.27°
# Sudut Siku: 70.51°
# Sudut Leher: 17.15°
# Sudut Trunk: 30.18°
# Sudut Pergelangan Tangan: 65.58°
# Sudut Fleksi/Ekstensi Bahu: 51.83°
#
# Gambar: 20250317_152346_frame_0173_preproc
# Sudut Lutut: 93.37°
# Sudut Siku: 66.91°
# Sudut Leher: 16.02°
# Sudut Trunk: 30.49°
# Sudut Pergelangan Tangan: 2.74°
# Sudut Fleksi/Ekstensi Bahu: 53.12°
#
# Gambar: 20250317_152346_frame_0174_preproc
# Sudut Lutut: 93.46°
# Sudut Siku: 40.09°
# Sudut Leher: 1.53°
# Sudut Trunk: 20.60°
# Sudut Pergelangan Tangan: 0.79°
# Sudut Fleksi/Ekstensi Bahu: 59.24°
#
# Gambar: 20250317_152346_frame_0175_preproc
# Sudut Lutut: 83.00°
# Sudut Siku: 86.45°
# Sudut Leher: 11.57°
# Sudut Trunk: 14.26°
# Sudut Pergelangan Tangan: 15.88°
# Sudut Fleksi/Ekstensi Bahu: 6.90°
#
# Gambar: 20250317_152346_frame_0176_preproc
# Sudut Lutut: 75.25°
# Sudut Siku: 82.24°
# Sudut Leher: 19.31°
# Sudut Trunk: 10.42°
# Sudut Pergelangan Tangan: 21.61°
# Sudut Fleksi/Ekstensi Bahu: 9.84°
#
# Gambar: 20250317_152346_frame_0177_preproc
# Sudut Lutut: 70.80°
# Sudut Siku: 73.88°
# Sudut Leher: 22.98°
# Sudut Trunk: 11.75°
# Sudut Pergelangan Tangan: 8.14°
# Sudut Fleksi/Ekstensi Bahu: 11.24°
#
# Gambar: 20250317_152346_frame_0178_preproc
# Sudut Lutut: 69.14°
# Sudut Siku: 71.31°
# Sudut Leher: 20.89°
# Sudut Trunk: 11.14°
# Sudut Pergelangan Tangan: 17.79°
# Sudut Fleksi/Ekstensi Bahu: 12.39°
#
# Gambar: 20250317_152346_frame_0179_preproc
# Sudut Lutut: 67.67°
# Sudut Siku: 77.73°
# Sudut Leher: 26.77°
# Sudut Trunk: 11.31°
# Sudut Pergelangan Tangan: 10.02°
# Sudut Fleksi/Ekstensi Bahu: 11.34°
#
# Gambar: 20250317_152346_frame_0180_preproc
# Sudut Lutut: 66.65°
# Sudut Siku: 73.00°
# Sudut Leher: 28.50°
# Sudut Trunk: 11.65°
# Sudut Pergelangan Tangan: 69.28°
# Sudut Fleksi/Ekstensi Bahu: 11.30°
#
# Gambar: 20250317_152346_frame_0181_preproc
# Sudut Lutut: 68.24°
# Sudut Siku: 68.90°
# Sudut Leher: 24.52°
# Sudut Trunk: 10.11°
# Sudut Pergelangan Tangan: 8.61°
# Sudut Fleksi/Ekstensi Bahu: 10.52°
#
# Gambar: 20250317_152346_frame_0182_preproc
# Sudut Lutut: 67.98°
# Sudut Siku: 72.09°
# Sudut Leher: 28.35°
# Sudut Trunk: 11.40°
# Sudut Pergelangan Tangan: 61.93°
# Sudut Fleksi/Ekstensi Bahu: 9.21°
#
# Gambar: 20250317_152346_frame_0183_preproc
# Sudut Lutut: 67.75°
# Sudut Siku: 72.32°
# Sudut Leher: 30.39°
# Sudut Trunk: 11.14°
# Sudut Pergelangan Tangan: 28.87°
# Sudut Fleksi/Ekstensi Bahu: 11.06°
#
# Gambar: 20250317_152346_frame_0184_preproc
# Sudut Lutut: 66.99°
# Sudut Siku: 69.81°
# Sudut Leher: 27.74°
# Sudut Trunk: 10.39°
# Sudut Pergelangan Tangan: 21.95°
# Sudut Fleksi/Ekstensi Bahu: 10.88°
#
# Gambar: 20250317_152346_frame_0185_preproc
# Sudut Lutut: 67.99°
# Sudut Siku: 73.90°
# Sudut Leher: 32.04°
# Sudut Trunk: 12.15°
# Sudut Pergelangan Tangan: 3.65°
# Sudut Fleksi/Ekstensi Bahu: 11.81°
#
# Gambar: 20250317_152346_frame_0186_preproc
# Sudut Lutut: 67.21°
# Sudut Siku: 71.20°
# Sudut Leher: 34.32°
# Sudut Trunk: 13.07°
# Sudut Pergelangan Tangan: 5.56°
# Sudut Fleksi/Ekstensi Bahu: 13.35°
#
# Gambar: 20250317_152346_frame_0187_preproc
# Sudut Lutut: 65.84°
# Sudut Siku: 72.10°
# Sudut Leher: 25.82°
# Sudut Trunk: 9.54°
# Sudut Pergelangan Tangan: 4.34°
# Sudut Fleksi/Ekstensi Bahu: 8.84°
#
# Gambar: 20250317_152346_frame_0188_preproc
# Sudut Lutut: 65.65°
# Sudut Siku: 72.95°
# Sudut Leher: 29.71°
# Sudut Trunk: 11.13°
# Sudut Pergelangan Tangan: 1.47°
# Sudut Fleksi/Ekstensi Bahu: 8.93°
#
# Gambar: 20250317_152346_frame_0189_preproc
# Sudut Lutut: 69.70°
# Sudut Siku: 70.20°
# Sudut Leher: 20.84°
# Sudut Trunk: 8.88°
# Sudut Pergelangan Tangan: 7.38°
# Sudut Fleksi/Ekstensi Bahu: 9.96°
#
# Gambar: 20250317_152346_frame_0190_preproc
# Sudut Lutut: 68.37°
# Sudut Siku: 70.92°
# Sudut Leher: 48.59°
# Sudut Trunk: 11.31°
# Sudut Pergelangan Tangan: 5.80°
# Sudut Fleksi/Ekstensi Bahu: 9.26°
#
# Gambar: 20250317_152346_frame_0191_preproc
# Sudut Siku: 74.26°
# Sudut Leher: 23.56°
# Sudut Trunk: 2.73°
# Sudut Pergelangan Tangan: 9.04°
# Sudut Fleksi/Ekstensi Bahu: 3.85°
#
# Gambar: 20250317_152346_frame_0192_preproc
# Sudut Siku: 70.45°
# Sudut Leher: 22.60°
# Sudut Trunk: 8.18°
# Sudut Pergelangan Tangan: 1.02°
# Sudut Fleksi/Ekstensi Bahu: 9.63°
#
# Gambar: 20250317_152346_frame_0193_preproc
# Sudut Siku: 69.43°
# Sudut Leher: 25.13°
# Sudut Trunk: 11.56°
# Sudut Pergelangan Tangan: 36.12°
# Sudut Fleksi/Ekstensi Bahu: 11.04°
#
# Gambar: 20250317_152346_frame_0194_preproc
# Sudut Siku: 66.45°
# Sudut Leher: 26.21°
# Sudut Trunk: 12.06°
# Sudut Pergelangan Tangan: 12.70°
# Sudut Fleksi/Ekstensi Bahu: 10.98°
#
# Gambar: 20250317_152346_frame_0195_preproc
# Sudut Siku: 65.49°
# Sudut Leher: 27.13°
# Sudut Trunk: 12.28°
# Sudut Pergelangan Tangan: 9.63°
# Sudut Fleksi/Ekstensi Bahu: 10.13°
#
# Gambar: 20250317_152346_frame_0196_preproc
# Sudut Siku: 66.34°
# Sudut Leher: 35.42°
# Sudut Trunk: 8.56°
# Sudut Pergelangan Tangan: 3.23°
# Sudut Fleksi/Ekstensi Bahu: 9.38°
#
# Gambar: 20250317_152346_frame_0197_preproc
# Sudut Siku: 66.57°
# Sudut Leher: 38.70°
# Sudut Trunk: 9.63°
# Sudut Pergelangan Tangan: 8.85°
# Sudut Fleksi/Ekstensi Bahu: 9.65°
#
# Gambar: 20250317_152346_frame_0198_preproc
# Sudut Siku: 66.21°
# Sudut Leher: 36.22°
# Sudut Trunk: 7.98°
# Sudut Pergelangan Tangan: 9.84°
# Sudut Fleksi/Ekstensi Bahu: 7.94°
#
# Gambar: 20250317_152346_frame_0199_preproc
# Sudut Siku: 67.07°
# Sudut Leher: 39.78°
# Sudut Trunk: 11.10°
# Sudut Pergelangan Tangan: 8.17°
# Sudut Fleksi/Ekstensi Bahu: 10.62°
#
# Gambar: 20250317_152346_frame_0200_preproc
# Sudut Siku: 66.57°
# Sudut Leher: 38.06°
# Sudut Trunk: 10.99°
# Sudut Pergelangan Tangan: 8.00°
# Sudut Fleksi/Ekstensi Bahu: 7.92°
#
# Gambar: 20250317_152346_frame_0201_preproc
# Sudut Siku: 67.44°
# Sudut Leher: 35.24°
# Sudut Trunk: 8.64°
# Sudut Pergelangan Tangan: 8.36°
# Sudut Fleksi/Ekstensi Bahu: 5.44°
#
# Gambar: 20250317_152346_frame_0202_preproc
# Sudut Siku: 66.92°
# Sudut Leher: 40.94°
# Sudut Trunk: 11.73°
# Sudut Pergelangan Tangan: 8.39°
# Sudut Fleksi/Ekstensi Bahu: 12.99°
#
# Gambar: 20250317_152346_frame_0203_preproc
# Sudut Siku: 66.74°
# Sudut Leher: 33.22°
# Sudut Trunk: 10.54°
# Sudut Pergelangan Tangan: 11.71°
# Sudut Fleksi/Ekstensi Bahu: 9.85°
#
# Gambar: 20250317_152346_frame_0204_preproc
# Sudut Siku: 66.77°
# Sudut Leher: 37.29°
# Sudut Trunk: 9.24°
# Sudut Pergelangan Tangan: 10.72°
# Sudut Fleksi/Ekstensi Bahu: 9.13°
#
# Gambar: 20250317_152346_frame_0205_preproc
# Sudut Siku: 66.24°
# Sudut Leher: 39.52°
# Sudut Trunk: 9.18°
# Sudut Pergelangan Tangan: 5.09°
# Sudut Fleksi/Ekstensi Bahu: 10.09°
#
# Gambar: 20250317_152346_frame_0206_preproc
# Sudut Siku: 66.39°
# Sudut Leher: 41.48°
# Sudut Trunk: 12.19°
# Sudut Pergelangan Tangan: 9.92°
# Sudut Fleksi/Ekstensi Bahu: 10.65°
#
# Gambar: 20250317_152346_frame_0207_preproc
# Sudut Siku: 65.88°
# Sudut Leher: 33.40°
# Sudut Trunk: 7.84°
# Sudut Pergelangan Tangan: 10.54°
# Sudut Fleksi/Ekstensi Bahu: 7.08°
#
# Gambar: 20250317_152346_frame_0208_preproc
# Sudut Siku: 67.26°
# Sudut Leher: 39.38°
# Sudut Trunk: 9.63°
# Sudut Pergelangan Tangan: 8.77°
# Sudut Fleksi/Ekstensi Bahu: 7.73°
#
# Gambar: 20250317_152346_frame_0209_preproc
# Sudut Siku: 66.01°
# Sudut Leher: 40.80°
# Sudut Trunk: 12.49°
# Sudut Pergelangan Tangan: 7.05°
# Sudut Fleksi/Ekstensi Bahu: 7.74°
#
# Gambar: 20250317_152346_frame_0210_preproc
# Sudut Siku: 67.23°
# Sudut Leher: 40.23°
# Sudut Trunk: 11.83°
# Sudut Pergelangan Tangan: 8.41°
# Sudut Fleksi/Ekstensi Bahu: 8.30°
#
# Gambar: 20250317_152346_frame_0211_preproc
# Sudut Siku: 65.99°
# Sudut Leher: 37.68°
# Sudut Trunk: 9.87°
# Sudut Pergelangan Tangan: 11.63°
# Sudut Fleksi/Ekstensi Bahu: 9.69°
#
# Gambar: 20250317_152346_frame_0212_preproc
# Sudut Siku: 66.13°
# Sudut Leher: 42.02°
# Sudut Trunk: 11.67°
# Sudut Pergelangan Tangan: 5.62°
# Sudut Fleksi/Ekstensi Bahu: 10.14°
#
# Gambar: 20250317_152346_frame_0213_preproc
# Sudut Siku: 66.16°
# Sudut Leher: 41.35°
# Sudut Trunk: 11.31°
# Sudut Pergelangan Tangan: 4.98°
# Sudut Fleksi/Ekstensi Bahu: 8.93°
#
# Gambar: 20250317_152346_frame_0214_preproc
# Sudut Siku: 66.60°
# Sudut Leher: 35.77°
# Sudut Trunk: 9.07°
# Sudut Pergelangan Tangan: 4.36°
# Sudut Fleksi/Ekstensi Bahu: 9.23°
#
# Gambar: 20250317_152346_frame_0215_preproc
# Sudut Siku: 67.19°
# Sudut Leher: 39.47°
# Sudut Trunk: 12.79°
# Sudut Pergelangan Tangan: 11.65°
# Sudut Fleksi/Ekstensi Bahu: 9.33°
#
# Gambar: 20250317_152346_frame_0216_preproc
# Sudut Siku: 65.37°
# Sudut Leher: 41.39°
# Sudut Trunk: 11.76°
# Sudut Pergelangan Tangan: 8.39°
# Sudut Fleksi/Ekstensi Bahu: 9.65°
#
# Gambar: 20250317_152346_frame_0217_preproc
# Sudut Siku: 67.31°
# Sudut Leher: 42.89°
# Sudut Trunk: 12.23°
# Sudut Pergelangan Tangan: 4.96°
# Sudut Fleksi/Ekstensi Bahu: 10.68°
#
# Gambar: 20250317_152346_frame_0218_preproc
# Sudut Siku: 67.53°
# Sudut Leher: 38.54°
# Sudut Trunk: 10.31°
# Sudut Pergelangan Tangan: 12.14°
# Sudut Fleksi/Ekstensi Bahu: 9.77°
#
# Gambar: 20250317_152346_frame_0219_preproc
# Sudut Siku: 66.26°
# Sudut Leher: 40.57°
# Sudut Trunk: 12.05°
# Sudut Pergelangan Tangan: 6.98°
# Sudut Fleksi/Ekstensi Bahu: 10.36°
#
# Gambar: 20250317_152346_frame_0220_preproc
# Sudut Siku: 67.59°
# Sudut Leher: 39.54°
# Sudut Trunk: 10.50°
# Sudut Pergelangan Tangan: 3.69°
# Sudut Fleksi/Ekstensi Bahu: 9.81°
#
# Gambar: 20250317_152346_frame_0221_preproc
# Sudut Siku: 67.76°
# Sudut Leher: 39.60°
# Sudut Trunk: 11.56°
# Sudut Pergelangan Tangan: 2.93°
# Sudut Fleksi/Ekstensi Bahu: 10.40°
#
# Gambar: 20250317_152346_frame_0222_preproc
# Sudut Siku: 67.90°
# Sudut Leher: 40.50°
# Sudut Trunk: 11.98°
# Sudut Pergelangan Tangan: 7.05°
# Sudut Fleksi/Ekstensi Bahu: 13.21°
#
# Gambar: 20250317_152346_frame_0223_preproc
# Sudut Siku: 66.83°
# Sudut Leher: 35.55°
# Sudut Trunk: 8.80°
# Sudut Pergelangan Tangan: 8.42°
# Sudut Fleksi/Ekstensi Bahu: 11.11°
#
# Gambar: 20250317_152346_frame_0224_preproc
# Sudut Siku: 66.61°
# Sudut Leher: 40.74°
# Sudut Trunk: 10.33°
# Sudut Pergelangan Tangan: 4.96°
# Sudut Fleksi/Ekstensi Bahu: 6.96°
#
# Gambar: 20250317_152346_frame_0225_preproc
# Sudut Siku: 66.45°
# Sudut Leher: 43.43°
# Sudut Trunk: 11.78°
# Sudut Pergelangan Tangan: 4.32°
# Sudut Fleksi/Ekstensi Bahu: 8.67°
#
# Gambar: 20250317_152346_frame_0226_preproc
# Sudut Siku: 67.34°
# Sudut Leher: 35.54°
# Sudut Trunk: 9.97°
# Sudut Pergelangan Tangan: 4.96°
# Sudut Fleksi/Ekstensi Bahu: 10.02°
#
# Gambar: 20250317_152346_frame_0227_preproc
# Sudut Siku: 66.79°
# Sudut Leher: 42.11°
# Sudut Trunk: 11.11°
# Sudut Pergelangan Tangan: 32.60°
# Sudut Fleksi/Ekstensi Bahu: 9.56°
#
# Gambar: 20250317_152346_frame_0228_preproc
# Sudut Siku: 67.40°
# Sudut Leher: 49.39°
# Sudut Trunk: 11.70°
# Sudut Pergelangan Tangan: 10.51°
# Sudut Fleksi/Ekstensi Bahu: 10.28°
#
# Gambar: 20250317_152346_frame_0229_preproc
# Sudut Siku: 67.40°
# Sudut Leher: 48.05°
# Sudut Trunk: 10.66°
# Sudut Pergelangan Tangan: 25.95°
# Sudut Fleksi/Ekstensi Bahu: 9.13°
#
# Gambar: 20250317_152346_frame_0230_preproc
# Sudut Siku: 68.77°
# Sudut Leher: 47.84°
# Sudut Trunk: 10.02°
# Sudut Pergelangan Tangan: 34.29°
# Sudut Fleksi/Ekstensi Bahu: 10.51°
#
# Gambar: 20250317_152346_frame_0231_preproc
# Sudut Siku: 68.58°
# Sudut Leher: 43.23°
# Sudut Trunk: 7.93°
# Sudut Pergelangan Tangan: 121.89°
# Sudut Fleksi/Ekstensi Bahu: 9.34°
#
# Gambar: 20250317_152346_frame_0232_preproc
# Sudut Siku: 66.34°
# Sudut Leher: 47.15°
# Sudut Trunk: 10.59°
# Sudut Pergelangan Tangan: 15.51°
# Sudut Fleksi/Ekstensi Bahu: 7.62°
#
# Gambar: 20250317_152346_frame_0233_preproc
# Sudut Siku: 68.11°
# Sudut Leher: 44.86°
# Sudut Trunk: 11.31°
# Sudut Pergelangan Tangan: 16.96°
# Sudut Fleksi/Ekstensi Bahu: 11.77°
#
# Gambar: 20250317_152346_frame_0234_preproc
# Sudut Siku: 66.56°
# Sudut Leher: 48.43°
# Sudut Trunk: 10.85°
# Sudut Pergelangan Tangan: 12.28°
# Sudut Fleksi/Ekstensi Bahu: 9.07°
#
# Gambar: 20250317_152346_frame_0235_preproc
# Sudut Siku: 66.51°
# Sudut Leher: 47.76°
# Sudut Trunk: 10.72°
# Sudut Pergelangan Tangan: 21.45°
# Sudut Fleksi/Ekstensi Bahu: 5.93°
#
# Gambar: 20250317_152346_frame_0236_preproc
# Sudut Siku: 67.43°
# Sudut Leher: 54.22°
# Sudut Trunk: 10.43°
# Sudut Pergelangan Tangan: 12.13°
# Sudut Fleksi/Ekstensi Bahu: 7.98°
#
# Gambar: 20250317_152346_frame_0237_preproc
# Sudut Siku: 69.03°
# Sudut Leher: 44.43°
# Sudut Trunk: 3.65°
# Sudut Pergelangan Tangan: 11.25°
# Sudut Fleksi/Ekstensi Bahu: 2.21°
#
# Gambar: 20250317_152346_frame_0238_preproc
# Sudut Siku: 66.41°
# Sudut Leher: 39.43°
# Sudut Trunk: 11.18°
# Sudut Pergelangan Tangan: 15.00°
# Sudut Fleksi/Ekstensi Bahu: 5.14°
#
# Gambar: 20250317_152346_frame_0239_preproc
# Sudut Siku: 68.52°
# Sudut Leher: 36.57°
# Sudut Trunk: 5.94°
# Sudut Pergelangan Tangan: 1.26°
# Sudut Fleksi/Ekstensi Bahu: 6.43°
#
# Gambar: 20250317_152346_frame_0240_preproc
# Sudut Siku: 67.05°
# Sudut Leher: 48.60°
# Sudut Trunk: 9.72°
# Sudut Pergelangan Tangan: 7.09°
# Sudut Fleksi/Ekstensi Bahu: 9.92°
#
# Gambar: 20250317_152346_frame_0241_preproc
# Sudut Siku: 68.01°
# Sudut Leher: 54.26°
# Sudut Trunk: 10.68°
# Sudut Pergelangan Tangan: 3.26°
# Sudut Fleksi/Ekstensi Bahu: 8.22°
#
# Gambar: 20250317_152346_frame_0242_preproc
# Sudut Siku: 67.36°
# Sudut Leher: 42.71°
# Sudut Trunk: 8.14°
# Sudut Pergelangan Tangan: 8.48°
# Sudut Fleksi/Ekstensi Bahu: 9.03°
#
# Gambar: 20250317_152346_frame_0243_preproc
# Sudut Lutut: 174.34°
# Sudut Siku: 67.46°
# Sudut Leher: 41.42°
# Sudut Trunk: 5.47°
# Sudut Pergelangan Tangan: 16.67°
# Sudut Fleksi/Ekstensi Bahu: 7.27°
#
# Gambar: 20250317_152346_frame_0244_preproc
# Sudut Siku: 67.62°
# Sudut Leher: 39.71°
# Sudut Trunk: 6.08°
# Sudut Pergelangan Tangan: 21.45°
# Sudut Fleksi/Ekstensi Bahu: 8.78°
#
# Gambar: 20250317_152346_frame_0245_preproc
# Sudut Siku: 67.20°
# Sudut Leher: 42.50°
# Sudut Trunk: 8.33°
# Sudut Pergelangan Tangan: 9.74°
# Sudut Fleksi/Ekstensi Bahu: 5.80°
#
# Gambar: 20250317_152346_frame_0246_preproc
# Sudut Siku: 66.27°
# Sudut Leher: 46.94°
# Sudut Trunk: 9.16°
# Sudut Pergelangan Tangan: 8.65°
# Sudut Fleksi/Ekstensi Bahu: 8.78°
#
# Gambar: 20250317_152346_frame_0247_preproc
# Sudut Siku: 69.22°
# Sudut Leher: 38.94°
# Sudut Trunk: 8.04°
# Sudut Pergelangan Tangan: 9.95°
# Sudut Fleksi/Ekstensi Bahu: 6.65°
#
# Gambar: 20250317_152346_frame_0248_preproc
# Sudut Siku: 66.62°
# Sudut Leher: 42.46°
# Sudut Trunk: 9.41°
# Sudut Pergelangan Tangan: 10.74°
# Sudut Fleksi/Ekstensi Bahu: 9.48°
#
# Gambar: 20250317_152346_frame_0249_preproc
# Sudut Siku: 67.90°
# Sudut Leher: 36.90°
# Sudut Trunk: 5.72°
# Sudut Pergelangan Tangan: 59.14°
# Sudut Fleksi/Ekstensi Bahu: 5.59°
#
# Gambar: 20250317_152346_frame_0250_preproc
# Sudut Siku: 68.29°
# Sudut Leher: 52.13°
# Sudut Trunk: 9.38°
# Sudut Pergelangan Tangan: 36.41°
# Sudut Fleksi/Ekstensi Bahu: 9.43°
#
# Gambar: 20250317_152346_frame_0251_preproc
# Sudut Siku: 66.68°
# Sudut Leher: 44.00°
# Sudut Trunk: 9.63°
# Sudut Pergelangan Tangan: 5.80°
# Sudut Fleksi/Ekstensi Bahu: 2.59°
#
# Gambar: 20250317_152346_frame_0252_preproc
# Sudut Siku: 68.13°
# Sudut Leher: 41.12°
# Sudut Trunk: 8.42°
# Sudut Pergelangan Tangan: 5.27°
# Sudut Fleksi/Ekstensi Bahu: 8.36°
#
# Gambar: 20250317_152346_frame_0253_preproc
# Sudut Siku: 65.18°
# Sudut Leher: 46.58°
# Sudut Trunk: 7.81°
# Sudut Pergelangan Tangan: 5.78°
# Sudut Fleksi/Ekstensi Bahu: 8.55°
#
# Gambar: 20250317_152346_frame_0254_preproc
# Sudut Siku: 68.74°
# Sudut Leher: 41.96°
# Sudut Trunk: 7.25°
# Sudut Pergelangan Tangan: 1.35°
# Sudut Fleksi/Ekstensi Bahu: 6.79°
#
# Gambar: 20250317_152346_frame_0255_preproc
# Sudut Siku: 68.15°
# Sudut Leher: 48.19°
# Sudut Trunk: 10.47°
# Sudut Pergelangan Tangan: 24.87°
# Sudut Fleksi/Ekstensi Bahu: 9.17°
#
# Gambar: 20250317_152346_frame_0256_preproc
# Sudut Siku: 68.45°
# Sudut Leher: 52.89°
# Sudut Trunk: 10.19°
# Sudut Pergelangan Tangan: 2.25°
# Sudut Fleksi/Ekstensi Bahu: 7.69°
#
# Gambar: 20250317_152346_frame_0257_preproc
# Sudut Siku: 68.59°
# Sudut Leher: 41.19°
# Sudut Trunk: 8.85°
# Sudut Pergelangan Tangan: 16.52°
# Sudut Fleksi/Ekstensi Bahu: 9.44°
#
# Gambar: 20250317_152346_frame_0258_preproc
# Sudut Siku: 66.19°
# Sudut Leher: 44.14°
# Sudut Trunk: 8.77°
# Sudut Pergelangan Tangan: 4.44°
# Sudut Fleksi/Ekstensi Bahu: 8.38°
#
# Gambar: 20250317_152346_frame_0259_preproc
# Sudut Siku: 66.83°
# Sudut Leher: 48.33°
# Sudut Trunk: 10.28°
# Sudut Pergelangan Tangan: 5.49°
# Sudut Fleksi/Ekstensi Bahu: 9.18°
#
# Gambar: 20250317_152346_frame_0260_preproc
# Sudut Siku: 69.62°
# Sudut Leher: 37.24°
# Sudut Trunk: 8.70°
# Sudut Pergelangan Tangan: 8.82°
# Sudut Fleksi/Ekstensi Bahu: 8.91°
#
# Gambar: 20250317_152346_frame_0261_preproc
# Sudut Siku: 67.20°
# Sudut Leher: 44.72°
# Sudut Trunk: 9.47°
# Sudut Pergelangan Tangan: 6.13°
# Sudut Fleksi/Ekstensi Bahu: 7.91°
#
# Gambar: 20250317_152346_frame_0262_preproc
# Sudut Siku: 69.51°
# Sudut Leher: 39.43°
# Sudut Trunk: 9.30°
# Sudut Pergelangan Tangan: 21.70°
# Sudut Fleksi/Ekstensi Bahu: 5.75°
#
# Gambar: 20250317_152346_frame_0263_preproc
# Sudut Siku: 68.71°
# Sudut Leher: 46.39°
# Sudut Trunk: 8.54°
# Sudut Pergelangan Tangan: 0.23°
# Sudut Fleksi/Ekstensi Bahu: 10.80°
#
# Gambar: 20250317_152346_frame_0264_preproc
# Sudut Siku: 66.70°
# Sudut Leher: 45.82°
# Sudut Trunk: 8.13°
# Sudut Pergelangan Tangan: 15.04°
# Sudut Fleksi/Ekstensi Bahu: 8.07°
#
# Gambar: 20250317_152346_frame_0265_preproc
# Sudut Siku: 67.53°
# Sudut Leher: 39.36°
# Sudut Trunk: 4.82°
# Sudut Pergelangan Tangan: 19.19°
# Sudut Fleksi/Ekstensi Bahu: 4.05°
#
# Gambar: 20250317_152346_frame_0266_preproc
# Sudut Siku: 67.63°
# Sudut Leher: 42.65°
# Sudut Trunk: 7.62°
# Sudut Pergelangan Tangan: 14.95°
# Sudut Fleksi/Ekstensi Bahu: 5.85°
#
# ...
# Sudut Siku: 100.97°
# Sudut Leher: 16.42°
# Sudut Trunk: 5.24°
# Sudut Pergelangan Tangan: 10.74°
# Sudut Fleksi/Ekstensi Bahu: 10.66°
#
# Gambar: VID_20241001_225148_00_038_frame_1092_preproc
# Sudut Lutut: 105.50°
# Sudut Siku: 101.53°
# Sudut Leher: 18.59°
# Sudut Trunk: 4.40°
# Sudut Pergelangan Tangan: 11.58°
# Sudut Fleksi/Ekstensi Bahu: 8.94°
#
# Gambar: VID_20241001_225148_00_038_frame_1093_preproc
# Sudut Lutut: 104.56°
# Sudut Siku: 101.81°
# Sudut Leher: 18.21°
# Sudut Trunk: 4.34°
# Sudut Pergelangan Tangan: 10.96°
# Sudut Fleksi/Ekstensi Bahu: 9.13°
#
# Gambar: VID_20241001_225148_00_038_frame_1094_preproc
# Sudut Lutut: 104.29°
# Sudut Siku: 101.64°
# Sudut Leher: 17.50°
# Sudut Trunk: 5.15°
# Sudut Pergelangan Tangan: 10.55°
# Sudut Fleksi/Ekstensi Bahu: 10.73°
#
# Gambar: VID_20241001_225148_00_038_frame_1095_preproc
# Sudut Lutut: 103.93°
# Sudut Siku: 99.89°
# Sudut Leher: 19.09°
# Sudut Trunk: 4.49°
# Sudut Pergelangan Tangan: 4.10°
# Sudut Fleksi/Ekstensi Bahu: 9.36°
#
# Gambar: VID_20241001_225148_00_038_frame_1096_preproc
# Sudut Lutut: 102.49°
# Sudut Siku: 99.75°
# Sudut Leher: 21.93°
# Sudut Trunk: 1.57°
# Sudut Pergelangan Tangan: 9.47°
# Sudut Fleksi/Ekstensi Bahu: 8.99°
#
# Gambar: VID_20241001_225148_00_038_frame_1097_preproc
# Sudut Lutut: 106.53°
# Sudut Siku: 100.51°
# Sudut Leher: 18.37°
# Sudut Trunk: 5.63°
# Sudut Pergelangan Tangan: 11.55°
# Sudut Fleksi/Ekstensi Bahu: 9.89°
#
# Gambar: VID_20241001_225148_00_038_frame_1098_preproc
# Sudut Lutut: 105.85°
# Sudut Siku: 100.47°
# Sudut Leher: 26.51°
# Sudut Trunk: 2.38°
# Sudut Pergelangan Tangan: 11.93°
# Sudut Fleksi/Ekstensi Bahu: 7.56°
#
# Gambar: VID_20241001_225148_00_038_frame_1099_preproc
# Sudut Lutut: 104.34°
# Sudut Siku: 99.84°
# Sudut Leher: 18.77°
# Sudut Trunk: 2.76°
# Sudut Pergelangan Tangan: 7.69°
# Sudut Fleksi/Ekstensi Bahu: 8.75°
#
# Gambar: VID_20241001_225148_00_038_frame_1100_preproc
# Sudut Lutut: 105.19°
# Sudut Siku: 98.61°
# Sudut Leher: 22.70°
# Sudut Trunk: 1.99°
# Sudut Pergelangan Tangan: 11.26°
# Sudut Fleksi/Ekstensi Bahu: 13.13°
#
# Gambar: VID_20241001_225148_00_038_frame_1101_preproc
# Sudut Lutut: 103.51°
# Sudut Siku: 95.52°
# Sudut Leher: 23.45°
# Sudut Trunk: 2.40°
# Sudut Pergelangan Tangan: 11.45°
# Sudut Fleksi/Ekstensi Bahu: 13.73°
#
# Gambar: VID_20241001_225148_00_038_frame_1102_preproc
# Sudut Lutut: 108.12°
# Sudut Siku: 98.45°
# Sudut Leher: 15.68°
# Sudut Trunk: 4.52°
# Sudut Pergelangan Tangan: 10.71°
# Sudut Fleksi/Ekstensi Bahu: 13.72°
#
# Gambar: VID_20241001_225148_00_038_frame_1103_preproc
# Sudut Lutut: 103.33°
# Sudut Siku: 97.69°
# Sudut Leher: 20.98°
# Sudut Trunk: 2.01°
# Sudut Pergelangan Tangan: 7.12°
# Sudut Fleksi/Ekstensi Bahu: 13.78°
#
# Gambar: VID_20241001_225148_00_038_frame_1104_preproc
# Sudut Lutut: 105.67°
# Sudut Siku: 94.10°
# Sudut Leher: 21.84°
# Sudut Trunk: 1.60°
# Sudut Pergelangan Tangan: 8.94°
# Sudut Fleksi/Ekstensi Bahu: 14.43°
#
# Gambar: VID_20241001_225148_00_038_frame_1105_preproc
# Sudut Lutut: 103.49°
# Sudut Siku: 98.39°
# Sudut Leher: 18.66°
# Sudut Trunk: 3.18°
# Sudut Pergelangan Tangan: 8.13°
# Sudut Fleksi/Ekstensi Bahu: 10.50°
#
# Gambar: VID_20241001_225148_00_038_frame_1106_preproc
# Sudut Lutut: 106.73°
# Sudut Siku: 99.40°
# Sudut Leher: 14.15°
# Sudut Trunk: 6.70°
# Sudut Pergelangan Tangan: 10.11°
# Sudut Fleksi/Ekstensi Bahu: 11.90°
#
# Gambar: VID_20241001_225148_00_038_frame_1107_preproc
# Sudut Lutut: 105.19°
# Sudut Siku: 98.68°
# Sudut Leher: 15.03°
# Sudut Trunk: 4.08°
# Sudut Pergelangan Tangan: 7.71°
# Sudut Fleksi/Ekstensi Bahu: 10.12°
#
# Gambar: VID_20241001_225148_00_038_frame_1108_preproc
# Sudut Lutut: 105.32°
# Sudut Siku: 99.12°
# Sudut Leher: 16.75°
# Sudut Trunk: 4.60°
# Sudut Pergelangan Tangan: 10.51°
# Sudut Fleksi/Ekstensi Bahu: 9.28°
#
# Gambar: VID_20241001_225148_00_038_frame_1109_preproc
# Sudut Lutut: 106.04°
# Sudut Siku: 97.62°
# Sudut Leher: 16.97°
# Sudut Trunk: 4.39°
# Sudut Pergelangan Tangan: 6.84°
# Sudut Fleksi/Ekstensi Bahu: 10.58°
#
# Gambar: VID_20241001_225148_00_038_frame_1110_preproc
# Sudut Lutut: 105.30°
# Sudut Siku: 98.29°
# Sudut Leher: 18.31°
# Sudut Trunk: 3.24°
# Sudut Pergelangan Tangan: 15.98°
# Sudut Fleksi/Ekstensi Bahu: 9.17°
#
# Gambar: VID_20241001_225148_00_038_frame_1111_preproc
# Sudut Lutut: 101.72°
# Sudut Siku: 99.22°
# Sudut Leher: 16.58°
# Sudut Trunk: 3.20°
# Sudut Pergelangan Tangan: 7.76°
# Sudut Fleksi/Ekstensi Bahu: 10.25°
#
# Gambar: VID_20241001_225148_00_038_frame_1112_preproc
# Sudut Lutut: 102.49°
# Sudut Siku: 98.66°
# Sudut Leher: 23.58°
# Sudut Trunk: 2.78°
# Sudut Pergelangan Tangan: 9.13°
# Sudut Fleksi/Ekstensi Bahu: 9.95°
#
# Gambar: VID_20241001_225148_00_038_frame_1113_preproc
# Sudut Lutut: 102.67°
# Sudut Siku: 92.40°
# Sudut Leher: 25.98°
# Sudut Trunk: 2.34°
# Sudut Pergelangan Tangan: 8.19°
# Sudut Fleksi/Ekstensi Bahu: 14.52°
#
# Gambar: VID_20241001_225148_00_038_frame_1114_preproc
# Sudut Lutut: 103.31°
# Sudut Siku: 93.02°
# Sudut Leher: 22.89°
# Sudut Trunk: 0.01°
# Sudut Pergelangan Tangan: 0.64°
# Sudut Fleksi/Ekstensi Bahu: 40.79°
#
# Gambar: VID_20241001_225148_00_038_frame_1115_preproc
# Sudut Lutut: 104.12°
# Sudut Siku: 93.59°
# Sudut Leher: 17.73°
# Sudut Trunk: 2.39°
# Sudut Pergelangan Tangan: 6.25°
# Sudut Fleksi/Ekstensi Bahu: 10.46°
#
# Gambar: VID_20241001_225148_00_038_frame_1116_preproc
# Sudut Lutut: 104.62°
# Sudut Siku: 96.30°
# Sudut Leher: 15.32°
# Sudut Trunk: 4.50°
# Sudut Pergelangan Tangan: 2.61°
# Sudut Fleksi/Ekstensi Bahu: 9.93°
#
# Gambar: VID_20241001_225148_00_038_frame_1117_preproc
# Sudut Lutut: 105.13°
# Sudut Siku: 98.56°
# Sudut Leher: 22.30°
# Sudut Trunk: 4.52°
# Sudut Pergelangan Tangan: 3.90°
# Sudut Fleksi/Ekstensi Bahu: 9.43°
#
# Gambar: VID_20241001_225148_00_038_frame_1118_preproc
# Sudut Lutut: 104.79°
# Sudut Siku: 100.16°
# Sudut Leher: 26.27°
# Sudut Trunk: 5.62°
# Sudut Pergelangan Tangan: 6.50°
# Sudut Fleksi/Ekstensi Bahu: 8.48°
#
# Gambar: VID_20241001_225148_00_038_frame_1119_preproc
# Sudut Lutut: 104.70°
# Sudut Siku: 99.86°
# Sudut Leher: 31.41°
# Sudut Trunk: 3.95°
# Sudut Pergelangan Tangan: 4.83°
# Sudut Fleksi/Ekstensi Bahu: 7.88°
#
# Gambar: VID_20241001_225148_00_038_frame_1120_preproc
# Sudut Lutut: 104.57°
# Sudut Siku: 99.79°
# Sudut Leher: 28.59°
# Sudut Trunk: 3.92°
# Sudut Pergelangan Tangan: 9.00°
# Sudut Fleksi/Ekstensi Bahu: 8.69°
#
# Gambar: VID_20241001_225148_00_038_frame_1121_preproc
# Sudut Lutut: 101.76°
# Sudut Siku: 99.91°
# Sudut Leher: 29.24°
# Sudut Trunk: 3.92°
# Sudut Pergelangan Tangan: 9.27°
# Sudut Fleksi/Ekstensi Bahu: 7.58°
#
# Gambar: VID_20241001_225148_00_038_frame_1122_preproc
# Sudut Lutut: 103.63°
# Sudut Siku: 100.40°
# Sudut Leher: 34.35°
# Sudut Trunk: 2.38°
# Sudut Pergelangan Tangan: 7.16°
# Sudut Fleksi/Ekstensi Bahu: 5.87°
#
# Gambar: VID_20241001_225148_00_038_frame_1123_preproc
# Sudut Lutut: 105.20°
# Sudut Siku: 99.37°
# Sudut Leher: 30.93°
# Sudut Trunk: 4.00°
# Sudut Pergelangan Tangan: 5.13°
# Sudut Fleksi/Ekstensi Bahu: 8.53°
#
# Gambar: VID_20241001_225148_00_038_frame_1124_preproc
# Sudut Lutut: 105.92°
# Sudut Siku: 99.60°
# Sudut Leher: 28.70°
# Sudut Trunk: 4.33°
# Sudut Pergelangan Tangan: 5.38°
# Sudut Fleksi/Ekstensi Bahu: 7.45°
#
# Gambar: VID_20241001_225148_00_038_frame_1125_preproc
# Sudut Lutut: 103.49°
# Sudut Siku: 100.14°
# Sudut Leher: 25.54°
# Sudut Trunk: 3.94°
# Sudut Pergelangan Tangan: 4.90°
# Sudut Fleksi/Ekstensi Bahu: 8.28°
#
# Gambar: VID_20241001_225148_00_038_frame_1126_preproc
# Sudut Lutut: 105.03°
# Sudut Siku: 100.15°
# Sudut Leher: 24.57°
# Sudut Trunk: 5.63°
# Sudut Pergelangan Tangan: 6.16°
# Sudut Fleksi/Ekstensi Bahu: 8.19°
#
# Gambar: VID_20241001_225148_00_038_frame_1127_preproc
# Sudut Lutut: 103.60°
# Sudut Siku: 98.75°
# Sudut Leher: 23.95°
# Sudut Trunk: 4.40°
# Sudut Pergelangan Tangan: 5.64°
# Sudut Fleksi/Ekstensi Bahu: 6.47°
#
# Gambar: VID_20241001_225148_00_038_frame_1128_preproc
# Sudut Lutut: 103.64°
# Sudut Siku: 99.30°
# Sudut Leher: 23.57°
# Sudut Trunk: 5.15°
# Sudut Pergelangan Tangan: 6.30°
# Sudut Fleksi/Ekstensi Bahu: 7.34°
#
# Gambar: VID_20241001_225148_00_038_frame_1129_preproc
# Sudut Lutut: 103.95°
# Sudut Siku: 96.09°
# Sudut Leher: 17.63°
# Sudut Trunk: 1.59°
# Sudut Pergelangan Tangan: 7.31°
# Sudut Fleksi/Ekstensi Bahu: 11.90°
#
# Gambar: VID_20241001_225148_00_038_frame_1130_preproc
# Sudut Lutut: 105.44°
# Sudut Siku: 96.18°
# Sudut Leher: 17.91°
# Sudut Trunk: 1.23°
# Sudut Pergelangan Tangan: 5.14°
# Sudut Fleksi/Ekstensi Bahu: 10.04°
#
# Gambar: VID_20241001_225148_00_038_frame_1131_preproc
# Sudut Lutut: 102.48°
# Sudut Siku: 95.61°
# Sudut Leher: 17.59°
# Sudut Trunk: 2.39°
# Sudut Pergelangan Tangan: 9.85°
# Sudut Fleksi/Ekstensi Bahu: 9.32°
#
# Gambar: VID_20241001_225148_00_038_frame_1132_preproc
# Sudut Lutut: 104.48°
# Sudut Siku: 98.14°
# Sudut Leher: 16.71°
# Sudut Trunk: 2.47°
# Sudut Pergelangan Tangan: 9.12°
# Sudut Fleksi/Ekstensi Bahu: 6.70°
#
# Gambar: VID_20241001_225148_00_038_frame_1133_preproc
# Sudut Lutut: 105.95°
# Sudut Siku: 94.91°
# Sudut Leher: 23.51°
# Sudut Trunk: 1.66°
# Sudut Pergelangan Tangan: 7.63°
# Sudut Fleksi/Ekstensi Bahu: 11.11°
#
# Gambar: VID_20241001_225148_00_038_frame_1134_preproc
# Sudut Lutut: 105.42°
# Sudut Siku: 95.37°
# Sudut Leher: 23.03°
# Sudut Trunk: 2.46°
# Sudut Pergelangan Tangan: 1.61°
# Sudut Fleksi/Ekstensi Bahu: 13.72°
#
# Gambar: VID_20241001_225148_00_038_frame_1135_preproc
# Sudut Lutut: 103.80°
# Sudut Siku: 93.60°
# Sudut Leher: 18.75°
# Sudut Trunk: 1.99°
# Sudut Pergelangan Tangan: 4.77°
# Sudut Fleksi/Ekstensi Bahu: 11.05°
#
# Gambar: VID_20241001_225148_00_038_frame_1136_preproc
# Sudut Lutut: 102.36°
# Sudut Siku: 94.52°
# Sudut Leher: 19.73°
# Sudut Trunk: 0.41°
# Sudut Pergelangan Tangan: 4.49°
# Sudut Fleksi/Ekstensi Bahu: 11.11°
#
# Gambar: VID_20241001_225148_00_038_frame_1137_preproc
# Sudut Lutut: 105.24°
# Sudut Siku: 92.51°
# Sudut Leher: 27.30°
# Sudut Trunk: 0.83°
# Sudut Pergelangan Tangan: 10.12°
# Sudut Fleksi/Ekstensi Bahu: 9.91°
#
# Gambar: VID_20241001_225148_00_038_frame_1138_preproc
# Sudut Lutut: 103.53°
# Sudut Siku: 70.30°
# Sudut Leher: 30.06°
# Sudut Trunk: 11.85°
# Sudut Pergelangan Tangan: 150.98°
# Sudut Fleksi/Ekstensi Bahu: 26.57°
#
# Gambar: VID_20241001_225148_00_038_frame_1139_preproc
# Sudut Lutut: 100.92°
# Sudut Siku: 115.21°
# Sudut Leher: 30.68°
# Sudut Trunk: 9.08°
# Sudut Pergelangan Tangan: 75.92°
# Sudut Fleksi/Ekstensi Bahu: 3.08°
#
# Gambar: VID_20241001_225148_00_038_frame_1140_preproc
# Sudut Lutut: 101.44°
# Sudut Siku: 82.84°
# Sudut Leher: 26.38°
# Sudut Trunk: 5.64°
# Sudut Pergelangan Tangan: 10.52°
# Sudut Fleksi/Ekstensi Bahu: 7.88°
#
# Gambar: VID_20241001_225148_00_038_frame_1141_preproc
# Sudut Lutut: 70.51°
# Sudut Siku: 82.28°
# Sudut Leher: 32.35°
# Sudut Trunk: 11.39°
# Sudut Pergelangan Tangan: 11.22°
# Sudut Fleksi/Ekstensi Bahu: 7.77°
#
# Gambar: VID_20241001_225148_00_038_frame_1142_preproc
# Sudut Lutut: 57.59°
# Sudut Siku: 66.86°
# Sudut Leher: 23.86°
# Sudut Trunk: 6.21°
# Sudut Pergelangan Tangan: 2.84°
# Sudut Fleksi/Ekstensi Bahu: 2.67°
#
# Gambar: VID_20241001_225148_00_038_frame_1143_preproc
# Sudut Lutut: 54.06°
# Sudut Siku: 72.30°
# Sudut Leher: 28.05°
# Sudut Trunk: 2.61°
# Sudut Pergelangan Tangan: 1.39°
# Sudut Fleksi/Ekstensi Bahu: 2.14°
#
# Gambar: VID_20241001_225148_00_038_frame_1144_preproc
# Sudut Lutut: 54.58°
# Sudut Siku: 75.90°
# Sudut Leher: 30.40°
# Sudut Trunk: 3.63°
# Sudut Pergelangan Tangan: 4.61°
# Sudut Fleksi/Ekstensi Bahu: 0.52°
#
# Gambar: VID_20241001_225148_00_038_frame_1145_preproc
# Sudut Lutut: 54.39°
# Sudut Siku: 74.06°
# Sudut Leher: 33.46°
# Sudut Trunk: 5.84°
# Sudut Pergelangan Tangan: 167.97°
# Sudut Fleksi/Ekstensi Bahu: 1.69°
#
# Gambar: VID_20241001_225148_00_038_frame_1146_preproc
# Sudut Lutut: 54.27°
# Sudut Siku: 72.47°
# Sudut Leher: 31.56°
# Sudut Trunk: 5.35°
# Sudut Pergelangan Tangan: 66.78°
# Sudut Fleksi/Ekstensi Bahu: 0.12°
#
# Gambar: VID_20241001_225148_00_038_frame_1147_preproc
# Sudut Lutut: 54.40°
# Sudut Siku: 76.12°
# Sudut Leher: 35.52°
# Sudut Trunk: 6.29°
# Sudut Pergelangan Tangan: 87.78°
# Sudut Fleksi/Ekstensi Bahu: 0.22°
#
# Gambar: VID_20241001_225148_00_038_frame_1148_preproc
# Sudut Lutut: 54.16°
# Sudut Siku: 74.34°
# Sudut Leher: 28.31°
# Sudut Trunk: 4.88°
# Sudut Pergelangan Tangan: 1.61°
# Sudut Fleksi/Ekstensi Bahu: 0.22°
#
# Gambar: VID_20241018_164338_00_032_frame_0000_preproc
# Sudut Lutut: 80.11°
# Sudut Siku: 66.17°
# Sudut Leher: 19.55°
# Sudut Trunk: 0.95°
# Sudut Pergelangan Tangan: 12.05°
# Sudut Fleksi/Ekstensi Bahu: 24.12°
#
# Gambar: VID_20241018_164338_00_032_frame_0001_preproc
# Sudut Lutut: 81.15°
# Sudut Siku: 76.45°
# Sudut Leher: 22.21°
# Sudut Trunk: 1.83°
# Sudut Pergelangan Tangan: 9.69°
# Sudut Fleksi/Ekstensi Bahu: 22.08°
#
# Gambar: VID_20241018_164338_00_032_frame_0002_preproc
# Sudut Lutut: 83.25°
# Sudut Siku: 72.89°
# Sudut Leher: 29.52°
# Sudut Trunk: 0.46°
# Sudut Pergelangan Tangan: 5.21°
# Sudut Fleksi/Ekstensi Bahu: 22.51°
#
# Gambar: VID_20241018_164338_00_032_frame_0003_preproc
# Sudut Lutut: 82.72°
# Sudut Siku: 74.41°
# Sudut Leher: 28.92°
# Sudut Trunk: 0.47°
# Sudut Pergelangan Tangan: 9.79°
# Sudut Fleksi/Ekstensi Bahu: 23.96°
#
# Gambar: VID_20241018_164338_00_032_frame_0004_preproc
# Sudut Lutut: 83.00°
# Sudut Siku: 73.37°
# Sudut Leher: 28.04°
# Sudut Trunk: 2.78°
# Sudut Pergelangan Tangan: 0.89°
# Sudut Fleksi/Ekstensi Bahu: 22.28°
#
# Gambar: VID_20241018_164338_00_032_frame_0005_preproc
# Sudut Lutut: 80.39°
# Sudut Siku: 74.49°
# Sudut Leher: 27.56°
# Sudut Trunk: 1.86°
# Sudut Pergelangan Tangan: 15.42°
# Sudut Fleksi/Ekstensi Bahu: 23.50°
#
# Gambar: VID_20241018_164338_00_032_frame_0006_preproc
# Sudut Lutut: 83.49°
# Sudut Siku: 76.03°
# Sudut Leher: 29.01°
# Sudut Trunk: 1.86°
# Sudut Pergelangan Tangan: 20.77°
# Sudut Fleksi/Ekstensi Bahu: 22.96°
#
# Gambar: VID_20241018_164338_00_032_frame_0007_preproc
# Sudut Lutut: 81.99°
# Sudut Siku: 74.14°
# Sudut Leher: 28.09°
# Sudut Trunk: 1.83°
# Sudut Pergelangan Tangan: 3.23°
# Sudut Fleksi/Ekstensi Bahu: 21.36°
#
# Gambar: VID_20241018_164338_00_032_frame_0008_preproc
# Sudut Lutut: 81.99°
# Sudut Siku: 74.11°
# Sudut Leher: 27.59°
# Sudut Trunk: 0.94°
# Sudut Pergelangan Tangan: 12.24°
# Sudut Fleksi/Ekstensi Bahu: 25.14°
#
# Gambar: VID_20241018_164338_00_032_frame_0009_preproc
# Sudut Lutut: 84.29°
# Sudut Siku: 75.59°
# Sudut Leher: 28.02°
# Sudut Trunk: 0.95°
# Sudut Pergelangan Tangan: 9.72°
# Sudut Fleksi/Ekstensi Bahu: 20.92°
#
# Gambar: VID_20241018_164338_00_032_frame_0010_preproc
# Sudut Lutut: 83.14°
# Sudut Siku: 77.51°
# Sudut Leher: 24.66°
# Sudut Trunk: 1.45°
# Sudut Pergelangan Tangan: 17.97°
# Sudut Fleksi/Ekstensi Bahu: 22.50°
#
# Gambar: VID_20241018_164338_00_032_frame_0011_preproc
# Sudut Lutut: 80.14°
# Sudut Siku: 72.52°
# Sudut Leher: 25.37°
# Sudut Trunk: 4.64°
# Sudut Pergelangan Tangan: 10.53°
# Sudut Fleksi/Ekstensi Bahu: 20.74°
#
# Gambar: VID_20241018_164338_00_032_frame_0012_preproc
# Sudut Lutut: 79.63°
# Sudut Siku: 75.60°
# Sudut Leher: 25.52°
# Sudut Trunk: 3.26°
# Sudut Pergelangan Tangan: 12.40°
# Sudut Fleksi/Ekstensi Bahu: 21.57°
#
# Gambar: VID_20241018_164338_00_032_frame_0013_preproc
# Sudut Lutut: 84.44°
# Sudut Siku: 71.85°
# Sudut Leher: 32.04°
# Sudut Trunk: 0.95°
# Sudut Pergelangan Tangan: 10.23°
# Sudut Fleksi/Ekstensi Bahu: 19.85°
#
# Gambar: VID_20241018_164338_00_032_frame_0014_preproc
# Sudut Lutut: 76.45°
# Sudut Siku: 72.87°
# Sudut Leher: 28.98°
# Sudut Trunk: 0.93°
# Sudut Pergelangan Tangan: 9.59°
# Sudut Fleksi/Ekstensi Bahu: 22.23°
#
# Gambar: VID_20241018_164338_00_032_frame_0015_preproc
# Sudut Lutut: 75.82°
# Sudut Siku: 77.95°
# Sudut Leher: 31.67°
# Sudut Trunk: 1.42°
# Sudut Pergelangan Tangan: 15.91°
# Sudut Fleksi/Ekstensi Bahu: 15.43°
#
# Gambar: VID_20241018_164338_00_032_frame_0016_preproc
# Sudut Lutut: 83.32°
# Sudut Siku: 73.04°
# Sudut Leher: 22.03°
# Sudut Trunk: 4.23°
# Sudut Pergelangan Tangan: 9.27°
# Sudut Fleksi/Ekstensi Bahu: 23.31°
#
# Gambar: VID_20241018_164338_00_032_frame_0017_preproc
# Sudut Lutut: 83.15°
# Sudut Siku: 77.40°
# Sudut Leher: 23.27°
# Sudut Trunk: 1.42°
# Sudut Pergelangan Tangan: 9.43°
# Sudut Fleksi/Ekstensi Bahu: 22.77°
#
# Gambar: VID_20241018_164338_00_032_frame_0018_preproc
# Sudut Lutut: 80.88°
# Sudut Siku: 96.20°
# Sudut Leher: 22.75°
# Sudut Trunk: 2.34°
# Sudut Pergelangan Tangan: 1.72°
# Sudut Fleksi/Ekstensi Bahu: 8.30°
#
# Gambar: VID_20241018_164338_00_032_frame_0019_preproc
# Sudut Lutut: 82.46°
# Sudut Siku: 93.72°
# Sudut Leher: 24.65°
# Sudut Trunk: 2.78°
# Sudut Pergelangan Tangan: 4.66°
# Sudut Fleksi/Ekstensi Bahu: 7.86°
#
# Gambar: VID_20241018_164338_00_032_frame_0020_preproc
# Sudut Lutut: 83.87°
# Sudut Siku: 82.82°
# Sudut Leher: 23.24°
# Sudut Trunk: 0.95°
# Sudut Pergelangan Tangan: 15.10°
# Sudut Fleksi/Ekstensi Bahu: 22.31°
#
# Gambar: VID_20241018_164338_00_032_frame_0021_preproc
# Sudut Lutut: 82.25°
# Sudut Siku: 83.68°
# Sudut Leher: 24.58°
# Sudut Trunk: 1.85°
# Sudut Pergelangan Tangan: 21.92°
# Sudut Fleksi/Ekstensi Bahu: 21.29°

# %% [markdown]
# ## Preprocessing Data

# %% [markdown]
# ### Import File

# %%
# Load file hasil mentah
df = pd.read_csv("/output_csv/output_angles.csv")
df.head()
# Out:
#                           nama_gambar  sudut_lutut  sudut_siku  sudut_leher  \
# 0  20250317_152346_frame_0000_preproc    82.343020   32.819685     7.157090
# 1  20250317_152346_frame_0001_preproc    80.413598   31.063688    16.957043
# 2  20250317_152346_frame_0002_preproc    81.086473   28.142230    26.685976
# 3  20250317_152346_frame_0003_preproc    79.473027   24.640675     8.444868
# 4  20250317_152346_frame_0004_preproc    80.638978   27.237626     4.527877
#
#    sudut_punggung  sudut_pergelangan  sudut_bahu  conf_hip  conf_knee  \
# 0        2.759003          36.182153   31.711609  0.330333   0.638367
# 1        2.149798           5.899618   31.186015  0.304208   0.668057
# 2        0.011532         134.113121   34.580102  0.316732   0.663823
# 3        2.769748         115.847109   31.580247  0.338053   0.714458
# 4        1.779873           3.583243   27.205172  0.344573   0.680110
#
#    conf_ankle  ...  conf_neck  conf_head  conf_back  conf_hand_middle  \
# 0    0.515560  ...   0.654634   0.802631   0.309171          0.000781
# 1    0.511834  ...   0.641461   0.811721   0.268024          0.004583
# 2    0.470857  ...   0.633463   0.857472   0.240373          0.005632
# 3    0.473630  ...   0.686783   0.831166   0.296611          0.009816
# 4    0.464147  ...   0.666943   0.837150   0.324353          0.008473
#
#    adjust_shoulder_raised  adjust_arm_supported  adjust_wrist_twist  \
# 0                       0                    -1                   1
# 1                       0                    -1                   1
# 2                       1                    -1                   1
# 3                       0                    -1                   1
# 4                       0                    -1                   1
#
#    adjust_neck_twist  adjust_trunk_twist  adjust_legs_feet
# 0                  0                   0                 1
# 1                  0                   0                 1
# 2                  0                   0                 1
# 3                  0                   0                 1
# 4                  0                   1                 1
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Cek Missing Value & Baris Rusak

# %%
# Cek kolom dengan NaN
print("Jumlah nilai kosong per kolom:")
print(df.isnull().sum())

# Tampilkan baris yang punya NaN
df[df.isnull().any(axis=1)]
# Out:
# Jumlah nilai kosong per kolom:
# nama_gambar                  0
# sudut_lutut               1624
# sudut_siku                 322
# sudut_leher                579
# sudut_punggung             750
# sudut_pergelangan          325
# sudut_bahu                 559
# conf_hip                     0
# conf_knee                    0
# conf_ankle                   0
# conf_shoulder                0
# conf_shoulder_left           0
# conf_elbow                   0
# conf_elbow_left              0
# conf_wrist                   0
# conf_neck                    0
# conf_head                    0
# conf_back                    0
# conf_hand_middle             0
# adjust_shoulder_raised       0
# adjust_arm_supported         0
# adjust_wrist_twist           0
# adjust_neck_twist            0
# adjust_trunk_twist           0
# adjust_legs_feet             0
# dtype: int64
#                                          nama_gambar  sudut_lutut  sudut_siku  \
# 21                20250317_152346_frame_0021_preproc    85.334426         NaN
# 22                20250317_152346_frame_0022_preproc    82.468986         NaN
# 23                20250317_152346_frame_0023_preproc    83.874602         NaN
# 24                20250317_152346_frame_0024_preproc    85.986121         NaN
# 25                20250317_152346_frame_0025_preproc    88.136310         NaN
# ...                                              ...          ...         ...
# 10303  VID_20241001_225148_00_038_frame_0512_preproc          NaN   56.693754
# 10304  VID_20241001_225148_00_038_frame_0513_preproc          NaN   56.086953
# 10305  VID_20241001_225148_00_038_frame_0514_preproc          NaN   54.194084
# 10306  VID_20241001_225148_00_038_frame_0515_preproc          NaN   52.394250
# 10307  VID_20241001_225148_00_038_frame_0516_preproc          NaN   94.324004
#
#        sudut_leher  sudut_punggung  sudut_pergelangan  sudut_bahu  conf_hip  \
# 21        2.023661       32.941399                NaN   28.229847  0.295128
# 22        4.049572       36.390753                NaN   26.824231  0.285246
# 23        0.155121       37.929327                NaN   28.240995  0.214014
# 24        1.333821       37.715020                NaN   31.722816  0.267177
# 25        0.444216       35.022816                NaN   32.723288  0.287373
# ...            ...             ...                ...         ...       ...
# 10303          NaN        0.524756          18.835308   44.795743  0.464063
# 10304          NaN        2.750491          27.995532   46.273099  0.453613
# 10305          NaN        1.502188          25.070857   47.048789  0.456402
# 10306          NaN        0.480853          19.126909   48.111545  0.448896
# 10307    10.141180        0.008442          51.661920   49.570002  0.410485
#
#        conf_knee  conf_ankle  ...  conf_neck  conf_head  conf_back  \
# 21      0.702970    0.425109  ...   0.590402   0.887486   0.243636
# 22      0.682515    0.504397  ...   0.526904   0.868034   0.196293
# 23      0.643853    0.237459  ...   0.481371   0.823691   0.148606
# 24      0.654795    0.528636  ...   0.486584   0.862739   0.186943
# 25      0.723102    0.490771  ...   0.529729   0.833902   0.214317
# ...          ...         ...  ...        ...        ...        ...
# 10303   0.599620    0.000000  ...   0.711578   0.000000   0.543496
# 10304   0.592239    0.000000  ...   0.659489   0.000000   0.512398
# 10305   0.612846    0.000000  ...   0.693917   0.000000   0.527907
# 10306   0.623074    0.000000  ...   0.706743   0.000000   0.514941
# 10307   0.642603    0.000000  ...   0.781696   0.893386   0.467495
#
#        conf_hand_middle  adjust_shoulder_raised  adjust_arm_supported  \
# 21             0.000000                       1                    -1
# 22             0.000000                       0                    -1
# 23             0.000000                       1                    -1
# 24             0.000000                       1                    -1
# 25             0.000000                       0                    -1
# ...                 ...                     ...                   ...
# 10303          0.430973                       0                    -1
# 10304          0.100799                       0                    -1
# 10305          0.119596                       0                    -1
# 10306          0.116590                       0                    -1
# 10307          0.251134                       0                    -1
#
#        adjust_wrist_twist  adjust_neck_twist  adjust_trunk_twist  \
# 21                      1                  0                   1
# 22                      1                  0                   0
# 23                      1                  0                   0
# 24                      1                  0                   0
# 25                      1                  0                   0
# ...                   ...                ...                 ...
# 10303                   1                  1                   1
# 10304                   1                  1                   1
# 10305                   1                  1                   1
# 10306                   1                  1                   1
# 10307                   1                  0                   1
#
#        adjust_legs_feet
# 21                    1
# 22                    1
# 23                    1
# 24                    1
# 25                    1
# ...                 ...
# 10303                 1
# 10304                 1
# 10305                 1
# 10306                 1
# 10307                 1
#
# [1822 rows x 25 columns]

# %% [markdown]
# ### Melakukan perubahan NaN ke 0 karena dianggap sudut tidak terbentuk

# %%
angle_cols = [col for col in df.columns if col.startswith("sudut_")]
df[angle_cols] = df[angle_cols].fillna(0)

# %% [markdown]
# ### Simpan Hasil Cleansing

# %%
df.to_csv("/output_csv/output_angles_cleaned.csv", index=False)
print("File cleaned disimpan sebagai: output_angles_cleaned.csv")
# Out:
# File cleaned disimpan sebagai: output_angles_cleaned.csv

# %% [markdown]
# ## Augmentasi Data

# %%
import pandas as pd
import numpy as np

# Load dataset
df = pd.read_csv("/output_csv/output_angles_cleaned.csv")  # Ganti path jika perlu

# Kolom sudut yang akan diaugmentasi
sudut_cols = [
    'sudut_lutut', 'sudut_siku', 'sudut_leher',
    'sudut_punggung', 'sudut_pergelangan', 'sudut_bahu'
]

# Fungsi augmentasi
def augment_sudut(data, n_aug=2, noise_range=3):
    augmented_rows = []
    for i in range(n_aug):
        aug_data = data.copy()
        for col in sudut_cols:
            noise = np.random.uniform(-noise_range, noise_range, size=len(data))
            aug_data[col] = np.clip(aug_data[col] + noise, 0, 180)  # batasi ke 0–180
        aug_data["nama_gambar"] += f"_aug{i+1}"
        augmented_rows.append(aug_data)
    return pd.concat(augmented_rows, ignore_index=True)

df_augmented = augment_sudut(df, n_aug=2)
df_combined = pd.concat([df, df_augmented], ignore_index=True)
df_combined.to_csv("/output_csv/output_angles_augmented.csv", index=False)
print("Dataset augmentasi berbasis data asli berhasil dibuat.")
# Out:
# Dataset augmentasi berbasis data asli berhasil dibuat.

# %% [markdown]
# ## Scoring RULA

# %%
df = pd.read_csv("/output_csv/output_angles_augmented.csv")

def calculate_upper_arm_score(sudut_bahu, shoulder_raised, arm_supported):
    # Step 1: Skor dasar berdasarkan sudut bahu
    if sudut_bahu < 20:
        base_score = 1
    elif 20 <= sudut_bahu < 45:
        base_score = 2
    elif 45 <= sudut_bahu < 90:
        base_score = 3
    else:  # sudut_bahu >= 90
        base_score = 4

    # Step 1a: Penyesuaian
    base_score += shoulder_raised       # +1 jika bahu terangkat
    base_score += arm_supported         # -1 jika disangga

    return base_score

# Terapkan fungsi ke setiap baris DataFrame
df["rula_upper_arm_score"] = df.apply(
    lambda row: calculate_upper_arm_score(
        row["sudut_bahu"],
        row["adjust_shoulder_raised"],
        row["adjust_arm_supported"]
    ),
    axis=1
)

# Fungsi untuk menghitung skor Lower Arm (RULA Step 2)
def calculate_lower_arm_score(sudut_siku):
    if 60 <= sudut_siku <= 100:
        return 1
    elif 0 <= sudut_siku < 60:
        return 2
    else:  # sudut_siku > 100
        return 2

# Terapkan fungsi ke setiap baris
df["rula_lower_arm_score"] = df["sudut_siku"].apply(calculate_lower_arm_score)

# Fungsi untuk menghitung skor Wrist Position (RULA Step 3)
def calculate_wrist_score(sudut_pergelangan):
    if sudut_pergelangan == 0:
        return 1
    elif 0 < sudut_pergelangan <= 15:
        return 2
    else:  # sudut_pergelangan > 15
        return 3

# Terapkan fungsi ke setiap baris
df["rula_wrist_score"] = df["sudut_pergelangan"].apply(calculate_wrist_score)

# Fungsi untuk lookup skor di Table A (Step 5)
def lookup_table_a(upper_arm, lower_arm, wrist, wrist_twist):
    # Batasi rentang ke maksimal sesuai tabel (1–6 untuk upper, 1–3 untuk lower, 1–4 untuk wrist, 1–2 untuk twist)
    upper = max(1, min(6, upper_arm))
    lower = max(1, min(3, lower_arm))
    wrist_score = max(1, min(4, wrist))
    twist = max(1, min(2, wrist_twist))
    
    # Tabel A versi nested dictionary [upper][lower][wrist][twist]
    table_a = {
        1: {1: {1: {1: 1, 2: 2}, 2: {1: 2, 2: 2}, 3: {1: 2, 2: 3}, 4: {1: 3, 2: 3}},
            2: {1: {1: 2, 2: 2}, 2: {1: 2, 2: 2}, 3: {1: 3, 2: 3}, 4: {1: 3, 2: 3}},
            3: {1: {1: 2, 2: 3}, 2: {1: 3, 2: 3}, 3: {1: 3, 2: 3}, 4: {1: 4, 2: 4}}},
        2: {1: {1: {1: 2, 2: 3}, 2: {1: 3, 2: 3}, 3: {1: 3, 2: 4}, 4: {1: 4, 2: 4}},
            2: {1: {1: 3, 2: 3}, 2: {1: 3, 2: 3}, 3: {1: 3, 2: 4}, 4: {1: 4, 2: 4}},
            3: {1: {1: 3, 2: 4}, 2: {1: 4, 2: 4}, 3: {1: 4, 2: 4}, 4: {1: 5, 2: 5}}},
        3: {1: {1: {1: 3, 2: 3}, 2: {1: 4, 2: 4}, 3: {1: 4, 2: 4}, 4: {1: 5, 2: 5}},
            2: {1: {1: 3, 2: 4}, 2: {1: 4, 2: 4}, 3: {1: 4, 2: 4}, 4: {1: 5, 2: 5}},
            3: {1: {1: 4, 2: 4}, 2: {1: 4, 2: 4}, 3: {1: 4, 2: 5}, 4: {1: 5, 2: 5}}},
        4: {1: {1: {1: 4, 2: 4}, 2: {1: 4, 2: 4}, 3: {1: 4, 2: 5}, 4: {1: 5, 2: 5}},
            2: {1: {1: 4, 2: 4}, 2: {1: 4, 2: 4}, 3: {1: 4, 2: 5}, 4: {1: 5, 2: 5}},
            3: {1: {1: 4, 2: 4}, 2: {1: 4, 2: 5}, 3: {1: 5, 2: 5}, 4: {1: 6, 2: 6}}},
        5: {1: {1: {1: 5, 2: 5}, 2: {1: 5, 2: 5}, 3: {1: 5, 2: 6}, 4: {1: 6, 2: 7}},
            2: {1: {1: 5, 2: 6}, 2: {1: 6, 2: 6}, 3: {1: 6, 2: 7}, 4: {1: 7, 2: 7}},
            3: {1: {1: 6, 2: 6}, 2: {1: 6, 2: 7}, 3: {1: 7, 2: 7}, 4: {1: 7, 2: 8}}},
        6: {1: {1: {1: 7, 2: 7}, 2: {1: 7, 2: 7}, 3: {1: 7, 2: 8}, 4: {1: 8, 2: 9}},
            2: {1: {1: 8, 2: 8}, 2: {1: 8, 2: 8}, 3: {1: 8, 2: 9}, 4: {1: 9, 2: 9}},
            3: {1: {1: 9, 2: 9}, 2: {1: 9, 2: 9}, 3: {1: 9, 2: 9}, 4: {1: 9, 2: 9}}},
    }

    return table_a[upper][lower][wrist_score][twist]

# Terapkan fungsi ke setiap baris
df["rula_posture_score_a"] = df.apply(lambda row: lookup_table_a(
    row["rula_upper_arm_score"],
    row["rula_lower_arm_score"],
    row["rula_wrist_score"],
    row["adjust_wrist_twist"]
), axis=1)

# Step 6 dan 7 untuk A diasumsikan 0
df["rula_muscle_score_a"] = 0
df["rula_force_score_a"] = 0

# Step 8: Total Wrist & Arm Score (Table A total)
df["rula_score_a_total"] = (
    df["rula_posture_score_a"] +
    df["rula_muscle_score_a"] +
    df["rula_force_score_a"]
)

# Fungsi untuk menghitung skor Neck Position (RULA Step 9)
def calculate_neck_score(sudut_leher, neck_twist):
    # Skor dasar berdasarkan sudut
    if sudut_leher <= 10:
        base_score = 1
    elif sudut_leher <= 20:
        base_score = 2
    elif sudut_leher > 20:
        base_score = 3
    else:  # kebelakang
        base_score = 4

    # Penyesuaian jika leher twisted
    base_score += neck_twist  # +1 jika twisted (sudah 0 atau 1)

    return base_score

# Terapkan ke setiap baris
df["rula_neck_score"] = df.apply(lambda row: calculate_neck_score(
    row["sudut_leher"],
    row["adjust_neck_twist"]
), axis=1)

# Fungsi untuk menghitung skor Trunk Position (RULA Step 10)
def calculate_trunk_score(sudut_punggung, trunk_twist):
    if sudut_punggung <= 0:
        base_score = 1
    elif sudut_punggung <= 20:
        base_score = 2
    elif sudut_punggung <= 60:
        base_score = 3
    else:  # sudut_punggung > 60
        base_score = 4

    # Penyesuaian jika trunk twisted
    base_score += trunk_twist  # +1 jika twisted (sudah 0 atau 1)

    return base_score

# Terapkan ke setiap baris
df["rula_trunk_score"] = df.apply(lambda row: calculate_trunk_score(
    row["sudut_punggung"],
    row["adjust_trunk_twist"]
), axis=1)

# Step 11: Hitung skor kaki
def calculate_leg_score(adjust_legs_feet):
    return 1 if adjust_legs_feet == 1 else 2

df["rula_leg_score"] = df["adjust_legs_feet"].apply(calculate_leg_score)

# Mapping akurat Table B [neck][trunk][legs]
table_b = {
    1: {
        1: {1: 1, 2: 3},
        2: {1: 2, 2: 3},
        3: {1: 3, 2: 4},
        4: {1: 5, 2: 5},
        5: {1: 6, 2: 6},
        6: {1: 7, 2: 7},
    },
    2: {
        1: {1: 2, 2: 3},
        2: {1: 2, 2: 3},
        3: {1: 4, 2: 5},
        4: {1: 5, 2: 5},
        5: {1: 6, 2: 7},
        6: {1: 7, 2: 7},
    },
    3: {
        1: {1: 3, 2: 3},
        2: {1: 3, 2: 4},
        3: {1: 4, 2: 5},
        4: {1: 5, 2: 6},
        5: {1: 6, 2: 7},
        6: {1: 7, 2: 7},
    },
    4: {
        1: {1: 5, 2: 5},
        2: {1: 5, 2: 6},
        3: {1: 6, 2: 7},
        4: {1: 7, 2: 7},
        5: {1: 7, 2: 7},
        6: {1: 8, 2: 8},
    },
    5: {
        1: {1: 7, 2: 7},
        2: {1: 7, 2: 7},
        3: {1: 7, 2: 8},
        4: {1: 8, 2: 8},
        5: {1: 8, 2: 8},
        6: {1: 8, 2: 8},
    },
    6: {
        1: {1: 8, 2: 8},
        2: {1: 8, 2: 8},
        3: {1: 8, 2: 8},
        4: {1: 8, 2: 9},
        5: {1: 9, 2: 9},
        6: {1: 9, 2: 9},
    },
}

# Fungsi untuk lookup Table B yang sudah diperbaiki
def lookup_table_b(neck_score, trunk_score, leg_score):
    neck = max(1, min(6, neck_score))
    trunk = max(1, min(6, trunk_score))
    legs = max(1, min(2, leg_score))
    return table_b[neck][trunk][legs]

# Terapkan
df["rula_posture_score_b"] = df.apply(lambda row: lookup_table_b(
    row["rula_neck_score"],
    row["rula_trunk_score"],
    row["rula_leg_score"]
), axis=1)

# Step 13 dan 14: Muscle Use dan Force/Load diasumsikan 0
df["rula_muscle_score_b"] = 0
df["rula_force_score_b"] = 0

# Step 15: Jumlahkan nilai dari step 12–14
df["rula_score_b_total"] = (
    df["rula_posture_score_b"] +
    df["rula_muscle_score_b"] +
    df["rula_force_score_b"]
)

# Mapping tabel C [A_total][B_total]
table_c = {
    1: {1: 1, 2: 2, 3: 3, 4: 3, 5: 4, 6: 5, 7: 5},
    2: {1: 2, 2: 2, 3: 3, 4: 4, 5: 4, 6: 5, 7: 5},
    3: {1: 3, 2: 3, 3: 3, 4: 4, 5: 4, 6: 5, 7: 6},
    4: {1: 3, 2: 3, 3: 3, 4: 4, 5: 5, 6: 6, 7: 6},
    5: {1: 4, 2: 4, 3: 4, 4: 5, 5: 6, 6: 7, 7: 7},
    6: {1: 4, 2: 4, 3: 5, 4: 6, 5: 6, 6: 7, 7: 7},
    7: {1: 5, 2: 5, 3: 6, 4: 6, 5: 7, 6: 7, 7: 7},
    8: {1: 5, 2: 5, 3: 6, 4: 7, 5: 7, 6: 7, 7: 7},
    9: {1: 5, 2: 5, 3: 6, 4: 7, 5: 7, 6: 7, 7: 7},
}

# Fungsi untuk lookup Table C
def lookup_table_c(score_a, score_b):
    a = max(1, min(9, score_a))
    b = min(7, max(1, score_b))  # B_total di atas 7 dipetakan ke 7+
    return table_c[a][b]

# Tambahkan final RULA score ke kolom baru
df["rula_final_score"] = df.apply(lambda row: lookup_table_c(
    row["rula_score_a_total"],
    row["rula_score_b_total"]
), axis=1)

# Simpan ke file baru
df.to_csv("/output_csv/output_angles_with_rula.csv", index=False)

# %% [markdown]
# ## Scoring REBA

# %%
df = pd.read_csv("/output_csv/output_angles_with_rula.csv")

# Fungsi skor leher untuk REBA Step 1
def calculate_reba_neck_score(sudut_leher, neck_twist):
    if sudut_leher <= 20:
        base_score = 1
    elif sudut_leher > 20:
        base_score = 2
    else:  # kebelakang
        base_score = 2

    base_score += neck_twist  # +1 jika twisted
    return base_score

# Terapkan
df["reba_neck_score"] = df.apply(lambda row: calculate_reba_neck_score(
    float(row["sudut_leher"]),
    int(row["adjust_neck_twist"])
), axis=1)

# Fungsi skor trunk untuk REBA Step 2
def calculate_reba_trunk_score(sudut_punggung, trunk_twist):
    if sudut_punggung <= 0:
        base_score = 1
    elif sudut_punggung <= 20:
        base_score = 2
    elif sudut_punggung <= 60:
        base_score = 3
    else:  # sudut_punggung > 60
        base_score = 4

    base_score += trunk_twist  # +1 jika twisted
    return base_score

# Terapkan
df["reba_trunk_score"] = df.apply(lambda row: calculate_reba_trunk_score(
    float(row["sudut_punggung"]),
    int(row["adjust_trunk_twist"])
), axis=1)

# Step 3 REBA: Semua leg score di-set ke 1
df["reba_leg_score"] = 1

# Mapping REBA Table A [trunk][neck][leg]
reba_table_a = {
    1: {
        1: {1: 1, 2: 2, 3: 3, 4: 4},
        2: {1: 1, 2: 2, 3: 3, 4: 4},
        3: {1: 3, 2: 3, 3: 5, 4: 6},
    },
    2: {
        1: {1: 2, 2: 3, 3: 4, 4: 5},
        2: {1: 3, 2: 4, 3: 5, 4: 6},
        3: {1: 4, 2: 5, 3: 6, 4: 7},
    },
    3: {
        1: {1: 2, 2: 4, 3: 5, 4: 6},
        2: {1: 4, 2: 5, 3: 6, 4: 7},
        3: {1: 5, 2: 6, 3: 7, 4: 8},
    },
    4: {
        1: {1: 3, 2: 5, 3: 6, 4: 7},
        2: {1: 5, 2: 6, 3: 7, 4: 8},
        3: {1: 6, 2: 7, 3: 8, 4: 9},
    },
    5: {
        1: {1: 4, 2: 6, 3: 7, 4: 8},
        2: {1: 6, 2: 7, 3: 8, 4: 9},
        3: {1: 7, 2: 8, 3: 9, 4: 9},
    },
}

def lookup_reba_table_a(trunk, neck, leg):
    trunk = max(1, min(5, trunk))
    neck = max(1, min(3, neck))
    leg = max(1, min(4, leg))
    return reba_table_a[trunk][neck][leg]

# Terapkan ke DataFrame
df["reba_posture_score_a"] = df.apply(lambda row: lookup_reba_table_a(
    int(row["reba_trunk_score"]),
    int(row["reba_neck_score"]),
    int(row["reba_leg_score"])  # nanti bisa kamu upgrade ke 1–4 sesuai deteksi
), axis=1)

# Set semua force/load score ke 0 (karena diasumsikan ringan)
df["reba_force_score"] = 0

# Step 6: Hitung Score A
df["reba_score_a"] = df["reba_posture_score_a"] + df["reba_force_score"]

# Step 7: Upper Arm
def calculate_reba_upper_arm_score(sudut_bahu, shoulder_raised, arm_supported):
    if sudut_bahu < 20:
        base_score = 1
    elif 20 <= sudut_bahu < 45:
        base_score = 2
    elif 45 <= sudut_bahu < 90:
        base_score = 3
    else:  # sudut_bahu >= 90
        base_score = 4

    # Penyesuaian
    base_score += shoulder_raised      # +1 jika bahu terangkat
    base_score += arm_supported        # -1 jika lengan disangga (sudah bernilai -1)

    return base_score

# Terapkan ke DataFrame
df["reba_upper_arm_score"] = df.apply(lambda row: calculate_reba_upper_arm_score(
    float(row["sudut_bahu"]),
    int(row["adjust_shoulder_raised"]),
    int(row["adjust_arm_supported"])
), axis=1)

def calculate_reba_lower_arm_score(sudut_siku):
    if 60 <= sudut_siku <= 100:
        return 1
    elif 0 <= sudut_siku < 60:
        return 2
    else:  # sudut_siku > 100
        return 2

# Terapkan
df["reba_lower_arm_score"] = df["sudut_siku"].astype(float).apply(calculate_reba_lower_arm_score)

def calculate_reba_wrist_score(sudut_pergelangan):
    if sudut_pergelangan <= 15:
        return 1
    else:
        return 2

# Terapkan
df["reba_wrist_score"] = df["sudut_pergelangan"].astype(float).apply(calculate_reba_wrist_score)

# Mapping Table B: [upper_arm][lower_arm][wrist]
reba_table_b = {
    1: {1: {1: 1, 2: 2, 3: 2}, 2: {1: 1, 2: 2, 3: 3}},
    2: {1: {1: 1, 2: 2, 3: 3}, 2: {1: 2, 2: 3, 3: 4}},
    3: {1: {1: 3, 2: 4, 3: 5}, 2: {1: 4, 2: 5, 3: 5}},
    4: {1: {1: 4, 2: 5, 3: 5}, 2: {1: 5, 2: 6, 3: 7}},
    5: {1: {1: 6, 2: 7, 3: 8}, 2: {1: 7, 2: 8, 3: 8}},
    6: {1: {1: 7, 2: 8, 3: 8}, 2: {1: 8, 2: 9, 3: 9}},
}

def lookup_reba_table_b(upper, lower, wrist):
    upper = max(1, min(6, upper))
    lower = max(1, min(2, lower))
    wrist = max(1, min(3, wrist))  # kita treat skor wrist max 3
    return reba_table_b[upper][lower][wrist]

# Terapkan ke DataFrame
df["reba_posture_score_b"] = df.apply(lambda row: lookup_reba_table_b(
    int(row["reba_upper_arm_score"]),
    int(row["reba_lower_arm_score"]),
    int(row["reba_wrist_score"])
), axis=1)

# Set coupling score ke 0
df["reba_coupling_score"] = 0

# Step 12
df["reba_score_b"] = df["reba_posture_score_b"] + df["reba_coupling_score"]

# Mapping Table C REBA
reba_table_c = {
    1:  {1:1, 2:1, 3:1, 4:2, 5:3, 6:3, 7:4, 8:5, 9:6, 10:7, 11:7, 12:7},
    2:  {1:1, 2:2, 3:2, 4:3, 5:4, 6:4, 7:5, 8:6, 9:6, 10:7, 11:7, 12:8},
    3:  {1:2, 2:3, 3:3, 4:3, 5:4, 6:5, 7:6, 8:7, 9:7, 10:8, 11:8, 12:8},
    4:  {1:3, 2:4, 3:4, 4:4, 5:5, 6:6, 7:7, 8:8, 9:8, 10:9, 11:9, 12:9},
    5:  {1:4, 2:4, 3:4, 4:5, 5:6, 6:7, 7:8, 8:8, 9:9, 10:9, 11:9, 12:9},
    6:  {1:6, 2:6, 3:6, 4:7, 5:8, 6:8, 7:9, 8:9, 9:10, 10:10, 11:10, 12:10},
    7:  {1:7, 2:7, 3:7, 4:8, 5:9, 6:9, 7:9, 8:10, 9:10, 10:11, 11:11, 12:11},
    8:  {1:8, 2:8, 3:8, 4:9, 5:10, 6:10, 7:10, 8:10, 9:10, 10:11, 11:11, 12:11},
    9:  {1:9, 2:9, 3:9, 4:10, 5:10, 6:10, 7:11, 8:11, 9:11, 10:12, 11:12, 12:12},
    10: {1:10, 2:10, 3:10, 4:11, 5:11, 6:11, 7:11, 8:12, 9:12, 10:12, 11:12, 12:12},
    11: {1:11, 2:11, 3:11, 4:11, 5:12, 6:12, 7:12, 8:12, 9:12, 10:12, 11:12, 12:12},
    12: {1:12, 2:12, 3:12, 4:12, 5:12, 6:12, 7:12, 8:12, 9:12, 10:12, 11:12, 12:12},
}

def lookup_reba_final_score(score_a, score_b):
    a = max(1, min(12, int(score_a)))
    b = max(1, min(12, int(score_b)))
    return reba_table_c[a][b]

# Terapkan
df["reba_final_score"] = df.apply(lambda row: lookup_reba_final_score(
    row["reba_score_a"],
    row["reba_score_b"]
), axis=1)

# Simpan semua hasil REBA ke file baru
df.to_csv("/output_csv/output_angles_reba_rula.csv", index=False)

# %%
df["reba_final_score"].value_counts().sort_index()
# Out:
# reba_final_score
# 1     5752
# 2    11971
# 3     9179
# 4     4762
# 5      319
# 6      142
# Name: count, dtype: int64

# %%
df["rula_final_score"].value_counts().sort_index()
# Out:
# rula_final_score
# 2     4093
# 3    20957
# 4     6157
# 5      789
# 6      129
# Name: count, dtype: int64

# %%
df = pd.read_csv("/output_csv/output_angles_reba_rula.csv")

reba_counts = df['reba_final_score'].value_counts()
rula_counts = df['rula_final_score'].value_counts()

valid_reba = reba_counts[reba_counts >= 50].index
valid_rula = rula_counts[rula_counts >= 50].index

df_filtered = df[
    df['reba_final_score'].isin(valid_reba) &
    df['rula_final_score'].isin(valid_rula)
]

df_filtered.to_csv("/output_csv/dataset_rula_reba.csv", index=False)

print("Data dengan label kurang dari 10 berhasil dihapus.")
# Out:
# Data dengan label kurang dari 10 berhasil dihapus.

# %%
(df == 0).sum()
# Out:
# nama_gambar                   0
# sudut_lutut                3203
# sudut_siku                  661
# sudut_leher                1264
# sudut_punggung             2573
# sudut_pergelangan          1472
# sudut_bahu                 1366
# conf_hip                   2250
# conf_knee                  3321
# conf_ankle                 4872
# conf_shoulder                27
# conf_shoulder_left          183
# conf_elbow                  129
# conf_elbow_left            5058
# conf_wrist                  966
# conf_neck                     9
# conf_head                   159
# conf_back                  1581
# conf_hand_middle            966
# adjust_shoulder_raised    17586
# adjust_arm_supported          0
# adjust_wrist_twist            0
# adjust_neck_twist         29826
# adjust_trunk_twist        28473
# adjust_legs_feet              0
# rula_upper_arm_score      11961
# rula_lower_arm_score          0
# rula_wrist_score              0
# rula_posture_score_a          0
# rula_muscle_score_a       32139
# rula_force_score_a        32139
# rula_score_a_total            0
# rula_neck_score               0
# rula_trunk_score              0
# rula_leg_score                0
# rula_posture_score_b          0
# rula_muscle_score_b       32139
# rula_force_score_b        32139
# rula_score_b_total            0
# rula_final_score              0
# reba_neck_score               0
# reba_trunk_score              0
# reba_leg_score                0
# reba_posture_score_a          0
# reba_force_score          32139
# reba_score_a                  0
# reba_upper_arm_score      11961
# reba_lower_arm_score          0
# reba_wrist_score              0
# reba_posture_score_b          0
# reba_coupling_score       32139
# reba_score_b                  0
# reba_final_score              0
# dtype: int64

# %%
df["reba_final_score"].value_counts(normalize=True).sort_index() * 100
# Out:
# reba_final_score
# 1    17.905058
# 2    37.263813
# 3    28.572763
# 4    14.823346
# 5     0.992996
# 6     0.442023
# Name: proportion, dtype: float64

# %%
df["rula_final_score"].value_counts(normalize=True).sort_index() * 100
# Out:
# rula_final_score
# 2    12.740856
# 3    65.235798
# 4    19.165759
# 5     2.456031
# 6     0.401556
# Name: proportion, dtype: float64

# %% [markdown]
# ## Training

# %%
import pandas as pd
import cloudpickle
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/output_csv/dataset_rula_reba.csv")

# %%
features_reba = [
    'sudut_bahu', 'sudut_siku', 'sudut_pergelangan',
    'sudut_leher', 'sudut_punggung', 'sudut_lutut',
    
    'conf_back', 'conf_shoulder', 'conf_elbow', 'conf_wrist',
    'conf_hand_middle', 'conf_neck', 'conf_head',
    'conf_hip', 'conf_knee', 'conf_ankle',
    'conf_shoulder_left', 'conf_elbow_left',
    
    'adjust_shoulder_raised', 'adjust_arm_supported',
    'adjust_neck_twist', 'adjust_trunk_twist', 'adjust_legs_feet'
]

features_rula = [
    'sudut_bahu', 'sudut_siku', 'sudut_pergelangan',
    'sudut_leher', 'sudut_punggung', 'sudut_lutut',
    
    'conf_back', 'conf_shoulder', 'conf_elbow', 'conf_wrist',
    'conf_hand_middle', 'conf_neck', 'conf_head',
    'conf_hip', 'conf_knee', 'conf_ankle',
    'conf_shoulder_left', 'conf_elbow_left',
    
    'adjust_shoulder_raised', 'adjust_arm_supported',
    'adjust_neck_twist', 'adjust_trunk_twist', 'adjust_legs_feet', 'adjust_wrist_twist'
]

# %%
all_features = list(set(features_reba + features_rula))
df = df.dropna(subset=all_features + ['reba_final_score', 'rula_final_score'])

X_reba = df[features_reba]
X_rula = df[features_rula]
y_reba = df['reba_final_score']
y_rula = df['rula_final_score']

# %%
X_train_reba, X_test_reba, y_train_reba, y_test_reba = train_test_split(
    X_reba, y_reba, test_size=0.2, stratify=y_reba, random_state=42
)

X_train_rula, X_test_rula, y_train_rula, y_test_rula = train_test_split(
    X_rula, y_rula, test_size=0.2, stratify=y_rula, random_state=42
)

# %%
print("=== Distribusi Label REBA ===")
print("Train:")
print(y_train_reba.value_counts().sort_index())
print("\nTest:")
print(y_test_reba.value_counts().sort_index())
print("=== Distribusi Label RULA ===")
print("Train:")
print(y_train_rula.value_counts().sort_index())
print("\nTest:")
print(y_test_rula.value_counts().sort_index())
# Out:
# === Distribusi Label REBA ===
# Train:
# reba_final_score
# 1    4602
# 2    9577
# 3    7343
# 4    3809
# 5     255
# 6     114
# Name: count, dtype: int64
#
# Test:
# reba_final_score
# 1    1150
# 2    2394
# 3    1836
# 4     953
# 5      64
# 6      28
# Name: count, dtype: int64
# === Distribusi Label RULA ===
# Train:
# rula_final_score
# 2     3274
# 3    16766
# 4     4926
# 5      631
# 6      103
# Name: count, dtype: int64
#
# Test:
# rula_final_score
# 2     819
# 3    4191
# 4    1231
# 5     158
# 6      26
# Name: count, dtype: int64

# %%
pipeline_reba = Pipeline([
    ('scaler', MinMaxScaler()),
    ('svc', SVC(kernel='rbf', C=100, gamma=1, class_weight='balanced'))
])
pipeline_rula = Pipeline([
    ('scaler', MinMaxScaler()),
    ('svc', SVC(kernel='rbf', C=100, gamma=1, class_weight='balanced'))
])

# %%
pipeline_reba.fit(X_train_reba, y_train_reba)
pipeline_rula.fit(X_train_rula, y_train_rula)
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()),
#                 ('svc', SVC(C=100, class_weight='balanced', gamma=1))])

# %%
y_pred_reba = pipeline_reba.predict(X_test_reba)
y_pred_rula = pipeline_rula.predict(X_test_rula)

# %%
# REBA
y_train_pred_reba = pipeline_reba.predict(X_train_reba)
print("=== TRAIN - REBA ===")
print(classification_report(y_train_reba, y_train_pred_reba))

# RULA
y_train_pred_rula = pipeline_rula.predict(X_train_rula)
print("=== TRAIN - RULA ===")
print(classification_report(y_train_rula, y_train_pred_rula))
# Out:
# === TRAIN - REBA ===
#               precision    recall  f1-score   support
#
#            1       0.81      0.94      0.87      4602
#            2       0.94      0.86      0.90      9577
#            3       0.93      0.92      0.93      7343
#            4       0.92      0.97      0.95      3809
#            5       0.83      1.00      0.91       255
#            6       0.97      1.00      0.98       114
#
#     accuracy                           0.91     25700
#    macro avg       0.90      0.95      0.92     25700
# weighted avg       0.91      0.91      0.91     25700
#
# === TRAIN - RULA ===
#               precision    recall  f1-score   support
#
#            2       0.90      1.00      0.95      3274
#            3       1.00      0.97      0.98     16766
#            4       0.96      0.99      0.98      4926
#            5       0.96      1.00      0.98       631
#            6       0.98      1.00      0.99       103
#
#     accuracy                           0.98     25700
#    macro avg       0.96      0.99      0.97     25700
# weighted avg       0.98      0.98      0.98     25700

# %%
print("=== REBA Model Report ===")
print(classification_report(y_test_reba, y_pred_reba))
valid_labels_reba = sorted(set(y_test_reba) | set(y_pred_reba))
cm = confusion_matrix(y_test_reba, y_pred_reba, labels=valid_labels_reba)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=valid_labels_reba, yticklabels=valid_labels_reba)
plt.title(f"Confusion Matrix - REBA")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

print("=== RULA Model Report ===")
print(classification_report(y_test_rula, y_pred_rula))
valid_labels_rula = sorted(set(y_test_rula) | set(y_pred_rula))
cm = confusion_matrix(y_test_rula, y_pred_rula, labels=valid_labels_rula)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=valid_labels_rula, yticklabels=valid_labels_rula)
plt.title(f"Confusion Matrix - RULA")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()
# Out:
# === REBA Model Report ===
#               precision    recall  f1-score   support
#
#            1       0.78      0.90      0.83      1150
#            2       0.91      0.83      0.87      2394
#            3       0.89      0.88      0.88      1836
#            4       0.88      0.93      0.90       953
#            5       0.75      0.80      0.77        64
#            6       0.72      0.75      0.74        28
#
#     accuracy                           0.87      6425
#    macro avg       0.82      0.85      0.83      6425
# weighted avg       0.87      0.87      0.87      6425
# === RULA Model Report ===
#               precision    recall  f1-score   support
#
#            2       0.87      0.98      0.92       819
#            3       0.99      0.96      0.97      4191
#            4       0.94      0.97      0.95      1231
#            5       0.91      0.93      0.92       158
#            6       0.77      0.88      0.82        26
#
#     accuracy                           0.96      6425
#    macro avg       0.90      0.94      0.92      6425
# weighted avg       0.96      0.96      0.96      6425

# %%
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt
import numpy as np

train_sizes, train_scores, test_scores = learning_curve(
    pipeline_reba, X_reba, y_reba, cv=3, scoring='accuracy',
    train_sizes=np.linspace(0.1, 1.0, 5), random_state=42
)

train_scores_mean = train_scores.mean(axis=1)
test_scores_mean = test_scores.mean(axis=1)

plt.plot(train_sizes, train_scores_mean, label='Train')
plt.plot(train_sizes, test_scores_mean, label='Test')
plt.xlabel("Train Size")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Learning Curve - REBA")
plt.show()

# %%
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt
import numpy as np

# Learning curve untuk RULA
train_sizes, train_scores, test_scores = learning_curve(
    pipeline_rula, X_rula, y_rula, cv=3, scoring='accuracy',
    train_sizes=np.linspace(0.1, 1.0, 5), random_state=42
)

# Rata-rata skor
train_scores_mean = train_scores.mean(axis=1)
test_scores_mean = test_scores.mean(axis=1)

# Plot
plt.plot(train_sizes, train_scores_mean, label='Train')
plt.plot(train_sizes, test_scores_mean, label='Test')
plt.xlabel("Train Size")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Learning Curve - RULA")
plt.show()

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# ===== Fungsi Training SVM =====
def train_best_model(X_train, y_train, cv=3, n_iter=20):
    pipeline = Pipeline([
        ('scaler', MinMaxScaler()),
        ('svc', SVC(class_weight='balanced'))
    ])

    param_dist = {
        'svc__C': [0.1, 1, 10, 100],
        'svc__gamma': ['scale', 'auto', 0.01, 0.1, 1],
        'svc__kernel': ['rbf']
    }

    search = RandomizedSearchCV(
        pipeline,
        param_distributions=param_dist,
        n_iter=n_iter,
        cv=cv,
        scoring='accuracy',
        n_jobs=-1,
        return_train_score=True,
        random_state=42
    )
    search.fit(X_train, y_train)

    print("Best Parameters:", search.best_params_)
    print("Best CV Score:", search.best_score_)
    return search.best_estimator_, search  # return juga object search-nya untuk plotting

# ===== Fungsi Evaluasi Model =====
def evaluate_model(model, X_test, y_test, title="Model Evaluation"):
    y_pred = model.predict(X_test)

    print(f"\nClassification Report: {title}")
    print(classification_report(y_test, y_pred))

    valid_labels = sorted(set(y_test) | set(y_pred))
    cm = confusion_matrix(y_test, y_pred, labels=valid_labels)
    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=valid_labels, yticklabels=valid_labels)
    plt.title(f"Confusion Matrix - {title}")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.tight_layout()
    plt.show()

# ===== Fungsi Grafik Line Akurasi =====
def plot_search_results(search, title="Tuning Results"):
    results = pd.DataFrame(search.cv_results_)
    results = results.sort_values(by='mean_test_score', ascending=False)

    plt.figure(figsize=(10, 5))
    plt.plot(results['mean_test_score'].values, marker='o')
    plt.title(f"{title} - Akurasi per Kombinasi")
    plt.xlabel("Kombinasi ke- (urut skor tertinggi)")
    plt.ylabel("Mean CV Accuracy")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# ===== Fungsi Heatmap Akurasi (khusus kernel tunggal) =====
def plot_heatmap(search, kernel='rbf', title="Heatmap Akurasi"):
    df = pd.DataFrame(search.cv_results_)
    df = df[df['param_svc__kernel'] == kernel]
    df = df[df['param_svc__gamma'] != 'auto']
    df = df[df['param_svc__gamma'] != 'scale']

    pivot = df.pivot_table(
        index='param_svc__C',
        columns='param_svc__gamma',
        values='mean_test_score',
        aggfunc='mean'
    )

    plt.figure(figsize=(8, 6))
    sns.heatmap(pivot, annot=True, fmt=".3f", cmap='YlGnBu')
    plt.title(f"{title} ({kernel} kernel)")
    plt.xlabel("Gamma")
    plt.ylabel("C")
    plt.tight_layout()
    plt.show()

def plot_bar_linear_kernel(search, title="Linear Kernel Performance"):
    df = pd.DataFrame(search.cv_results_)
    df = df[df['param_svc__kernel'] == 'linear']

    if not df.empty:
        plt.figure(figsize=(8, 5))
        sns.barplot(data=df, x='param_svc__C', y='mean_test_score')
        plt.title(f"{title} (Linear Kernel)")
        plt.xlabel("C")
        plt.ylabel("Mean CV Accuracy")
        plt.tight_layout()
        plt.show()
    else:
        print("Tidak ada kombinasi linear kernel yang dicoba.")

def save_cv_results(search, filename):
    df = pd.DataFrame(search.cv_results_)
    df.to_csv(filename, index=False)
    print(f"Saved search results to {filename}")

# %%
# === REBA ===
print("Tuning Model REBA...")
best_model_reba, search_reba = train_best_model(X_train_reba, y_train_reba)
evaluate_model(best_model_reba, X_train_reba, y_train_reba, title="REBA - Train Set")
evaluate_model(best_model_reba, X_test_reba, y_test_reba, title="REBA - Test Set")
plot_search_results(search_reba, title="REBA")
plot_heatmap(search_reba, kernel='rbf', title="REBA")
plot_bar_linear_kernel(search_reba, title="REBA")
save_cv_results(search_reba, "reba_tuning_results.csv")

# === RULA ===
print("\nTuning Model RULA...")
best_model_rula, search_rula = train_best_model(X_train_rula, y_train_rula)
evaluate_model(best_model_rula, X_train_rula, y_train_rula, title="RULA - Train Set")
evaluate_model(best_model_rula, X_test_rula, y_test_rula, title="RULA - Test Set")
plot_search_results(search_rula, title="RULA")
plot_heatmap(search_rula, kernel='rbf', title="RULA")
plot_bar_linear_kernel(search_rula, title="RULA")
save_cv_results(search_rula, "rula_tuning_results.csv")
# Out:
# Tuning Model REBA...
# Best Parameters: {'svc__kernel': 'rbf', 'svc__gamma': 1, 'svc__C': 100}
# Best CV Score: 0.8522180891600594
#
# Classification Report: REBA - Train Set
#               precision    recall  f1-score   support
#
#            1       0.81      0.94      0.87      4602
#            2       0.94      0.86      0.90      9577
#            3       0.93      0.92      0.93      7343
#            4       0.92      0.97      0.95      3809
#            5       0.83      1.00      0.91       255
#            6       0.97      1.00      0.98       114
#
#     accuracy                           0.91     25700
#    macro avg       0.90      0.95      0.92     25700
# weighted avg       0.91      0.91      0.91     25700
# Classification Report: REBA - Test Set
#               precision    recall  f1-score   support
#
#            1       0.78      0.90      0.83      1150
#            2       0.91      0.83      0.87      2394
#            3       0.89      0.88      0.88      1836
#            4       0.88      0.93      0.90       953
#            5       0.75      0.80      0.77        64
#            6       0.72      0.75      0.74        28
#
#     accuracy                           0.87      6425
#    macro avg       0.82      0.85      0.83      6425
# weighted avg       0.87      0.87      0.87      6425
# Tidak ada kombinasi linear kernel yang dicoba.
# Saved search results to reba_tuning_results.csv
#
# Tuning Model RULA...
# Best Parameters: {'svc__kernel': 'rbf', 'svc__gamma': 1, 'svc__C': 100}
# Best CV Score: 0.9582491028152441
#
# Classification Report: RULA - Train Set
#               precision    recall  f1-score   support
#
#            2       0.90      1.00      0.95      3274
#            3       1.00      0.97      0.98     16766
#            4       0.96      0.99      0.98      4926
#            5       0.96      1.00      0.98       631
#            6       0.98      1.00      0.99       103
#
#     accuracy                           0.98     25700
#    macro avg       0.96      0.99      0.97     25700
# weighted avg       0.98      0.98      0.98     25700
# Classification Report: RULA - Test Set
#               precision    recall  f1-score   support
#
#            2       0.87      0.98      0.92       819
#            3       0.99      0.96      0.97      4191
#            4       0.94      0.97      0.95      1231
#            5       0.91      0.93      0.92       158
#            6       0.77      0.88      0.82        26
#
#     accuracy                           0.96      6425
#    macro avg       0.90      0.94      0.92      6425
# weighted avg       0.96      0.96      0.96      6425
# Tidak ada kombinasi linear kernel yang dicoba.
# Saved search results to rula_tuning_results.csv

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, f1_score

# === CROSS-VALIDATION REBA ===
print("Cross-Validation - REBA")
acc_scores_reba = cross_val_score(best_model_reba, X_reba, y_reba, cv=5, scoring='accuracy')
f1_scores_reba = cross_val_score(best_model_reba, X_reba, y_reba, cv=5, scoring=make_scorer(f1_score, average='macro'))

print("REBA Accuracy CV:", acc_scores_reba)
print("REBA Mean Accuracy:", acc_scores_reba.mean())
print("REBA Macro F1 CV:", f1_scores_reba)
print("REBA Mean Macro F1:", f1_scores_reba.mean())

print("\n")

# === CROSS-VALIDATION RULA ===
print("Cross-Validation - RULA")
acc_scores_rula = cross_val_score(best_model_rula, X_rula, y_rula, cv=5, scoring='accuracy')
f1_scores_rula = cross_val_score(best_model_rula, X_rula, y_rula, cv=5, scoring=make_scorer(f1_score, average='macro'))

print("RULA Accuracy CV:", acc_scores_rula)
print("RULA Mean Accuracy:", acc_scores_rula.mean())
print("RULA Macro F1 CV:", f1_scores_rula)
print("RULA Mean Macro F1:", f1_scores_rula.mean())
# Out:
# Cross-Validation - REBA
# REBA Accuracy CV: [0.88513619 0.83844358 0.86505837 0.85431907 0.86101167]
# REBA Mean Accuracy: 0.8607937743190661
# REBA Macro F1 CV: [0.85558945 0.83226964 0.82911916 0.85094003 0.83730316]
# REBA Mean Macro F1: 0.8410442874964211
#
#
# Cross-Validation - RULA
# RULA Accuracy CV: [0.96404669 0.95626459 0.96902724 0.96093385 0.96980545]
# RULA Mean Accuracy: 0.9640155642023347
# RULA Macro F1 CV: [0.94110951 0.91683661 0.92158232 0.93986911 0.93569434]
# RULA Mean Macro F1: 0.9310183784327009

# %% [markdown]
# ## Training Pipeline

# %% [markdown]
# # Input Keypoin predict

# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn.preprocessing import MinMaxScaler
from collections import OrderedDict
import cloudpickle

class PostureModel:
    def __init__(self):
        # Mapping fitur REBA/RULA
        self.feature_mapping = {
            # RULA per join
            'rula_upper_arm_score': ['sudut_bahu', 'conf_back', 'conf_shoulder', 'conf_elbow', 'adjust_shoulder_raised', 'adjust_arm_supported'],
            'rula_lower_arm_score': ['sudut_siku', 'conf_shoulder', 'conf_elbow', 'conf_wrist'],
            'rula_wrist_score': ['sudut_pergelangan', 'conf_elbow', 'conf_wrist', 'conf_hand_middle'],
            'rula_neck_score': ['sudut_leher', 'conf_neck', 'conf_head', 'conf_back', 'adjust_neck_twist'],
            'rula_trunk_score': ['sudut_punggung', 'conf_hip', 'conf_knee', 'adjust_trunk_twist', 'conf_shoulder', 'conf_shoulder_left', 'conf_elbow', 'conf_elbow_left'],
        
            # REBA per join
            'reba_upper_arm_score': ['sudut_bahu', 'conf_back', 'conf_shoulder', 'conf_elbow', 'adjust_shoulder_raised', 'adjust_arm_supported'],
            'reba_lower_arm_score': ['sudut_siku', 'conf_shoulder', 'conf_elbow', 'conf_wrist'],
            'reba_wrist_score': ['sudut_pergelangan', 'conf_elbow', 'conf_wrist', 'conf_hand_middle'],
            'reba_neck_score': ['sudut_leher', 'conf_neck', 'conf_head', 'conf_back', 'adjust_neck_twist'],
            'reba_trunk_score': ['sudut_punggung', 'conf_hip', 'conf_knee', 'adjust_trunk_twist', 'conf_shoulder', 'conf_shoulder_left', 'conf_elbow', 'conf_elbow_left'],
        
            # Final score rula
            'rula_final_score': ['sudut_bahu', 'sudut_siku', 'sudut_pergelangan',
                                 'sudut_leher', 'sudut_punggung', 'sudut_lutut',
            
                                 'conf_back', 'conf_shoulder', 'conf_elbow', 'conf_wrist',
                                 'conf_hand_middle', 'conf_neck', 'conf_head',
                                 'conf_hip', 'conf_knee', 'conf_ankle',
                                 'conf_shoulder_left', 'conf_elbow_left',
            
                                 'adjust_shoulder_raised', 'adjust_arm_supported',
                                 'adjust_neck_twist', 'adjust_trunk_twist', 'adjust_legs_feet', 'adjust_wrist_twist'],

            # Final score reba
            'reba_final_score': ['sudut_bahu', 'sudut_siku', 'sudut_pergelangan',
                                 'sudut_leher', 'sudut_punggung', 'sudut_lutut',
            
                                 'conf_back', 'conf_shoulder', 'conf_elbow', 'conf_wrist',
                                 'conf_hand_middle', 'conf_neck', 'conf_head',
                                 'conf_hip', 'conf_knee', 'conf_ankle',
                                 'conf_shoulder_left', 'conf_elbow_left',
            
                                 'adjust_shoulder_raised', 'adjust_arm_supported',
                                 'adjust_neck_twist', 'adjust_trunk_twist', 'adjust_legs_feet']
        }

        self.joint_models = {}       # model per sendi
        self.joint_scalers = {}      # scaler per sendi
        self.final_models = {}       # model akhir
        self.final_scalers = {}      # scaler akhir

    def fit(self, df):
        # Train joint models
        for target, features in self.feature_mapping.items():
            if "final_score" in target:
                continue
            X = df[features]
            y = df[target]

            if len(np.unique(y)) <= 1:
                print(f"Skipping {target} karena hanya ada 1 kelas.")
                continue

            scaler = MinMaxScaler()
            X_scaled = scaler.fit_transform(X)
            model = SVC(C=100, kernel='rbf', gamma=1, class_weight='balanced')
            model.fit(X_scaled, y)

            self.joint_models[target] = model
            self.joint_scalers[target] = scaler

        # Generate prediksi sendi ke df
        df_copy = df.copy()
        for target in self.joint_models:
            X = df[ self.feature_mapping[target] ]
            X_scaled = self.joint_scalers[target].transform(X)
            df_copy[target] = self.joint_models[target].predict(X_scaled)

        # Train final models
        for target in ['rula_final_score', 'reba_final_score']:
            features = self.feature_mapping[target]
            X = df_copy[features]
            y = df_copy[target]

            scaler = MinMaxScaler()
            X_scaled = scaler.fit_transform(X)

            model = SVC(C=100, kernel='rbf', gamma=1, class_weight='balanced')
            model.fit(X_scaled, y)

            self.final_models[target] = model
            self.final_scalers[target] = scaler

    def predict(self, df_row):
        result = OrderedDict()

        ordered_keys = [
            # RULA
            'rula_upper_arm_score',
            'rula_lower_arm_score',
            'rula_wrist_score',
            'rula_neck_score',
            'rula_trunk_score',
            'rula_leg_score',
            
            # REBA
            'reba_upper_arm_score',
            'reba_lower_arm_score',
            'reba_wrist_score',
            'reba_neck_score',
            'reba_trunk_score',
            'reba_leg_score',
            
            # Final
            'rula_final_score',
            'reba_final_score',
            
            # Feedback
            'feedback',
            'summary',
            'details'
        ]

        # Prediksi per sendi
        for target, model in self.joint_models.items():
            features = self.feature_mapping[target]
            X = df_row[features]
            X_scaled = self.joint_scalers[target].transform(X)
            pred = model.predict(X_scaled)
            result[target] = int(pred[0])

        # Prediksi final score
        for target, model in self.final_models.items():
            features = self.feature_mapping[target]
            input_data = {feat: result.get(feat, df_row.iloc[0][feat]) for feat in features}
            X_final = pd.DataFrame([input_data])
            X_scaled = self.final_scalers[target].transform(X_final)
            pred = model.predict(X_scaled)
            result[target] = int(pred[0])

        # Tambahkan manual untuk lutut (karena selalu 1 dan tidak diprediksi)
        result["rula_leg_score"] = 1
        result["reba_leg_score"] = 1

        result["feedback"] = self.generate_feedback(df_row)
        rula_score = result.get("rula_final_score", 0)
        reba_score = result.get("reba_final_score", 0)
        result["summary"] = self.final_score_feedback(rula_score, reba_score)
        result["details"] = {
            "sudut_lutut": df_row["sudut_lutut"].values[0],
            "sudut_siku": df_row["sudut_siku"].values[0],
            "sudut_leher": df_row["sudut_leher"].values[0],
            "sudut_punggung": df_row["sudut_punggung"].values[0],
            "sudut_pergelangan": df_row["sudut_pergelangan"].values[0],
            "sudut_bahu": df_row["sudut_bahu"].values[0],
        
            "adjust_shoulder_raised": df_row["adjust_shoulder_raised"].values[0],
            "adjust_arm_supported": df_row["adjust_arm_supported"].values[0],
            "adjust_neck_twist": df_row["adjust_neck_twist"].values[0],
            "adjust_trunk_twist": df_row["adjust_trunk_twist"].values[0],
            "adjust_legs_feet": df_row["adjust_legs_feet"].values[0],
            "adjust_wrist_twist": df_row["adjust_wrist_twist"].values[0],
        }
        result = OrderedDict((k, result[k]) for k in ordered_keys)
        return result

    def build_keypoints_dataframe(**kwargs):
        row = {}
        for key, val in kwargs.items():
            row[key] = [val]
        return pd.DataFrame(row)
        
    def predict_from_keypoints(self, keypoints_df):
        def calculate_angle(a, b, c):
            a = np.array(a)
            b = np.array(b)
            c = np.array(c)
            v1 = a - b
            v2 = c - b
            cosine_angle = np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))
            angle = np.arccos(np.clip(cosine_angle, -1.0, 1.0))
            return np.degrees(angle)
        
        def calculate_wrist_bending(elbow, wrist, hand_middle):
            # vektor lengan bawah
            forearm_vec = np.array(wrist) - np.array(elbow)
            # vektor arah tangan
            hand_vec = np.array(hand_middle) - np.array(wrist)
            # hitung sudut antar dua vektor
            cosine = np.dot(forearm_vec, hand_vec) / (np.linalg.norm(forearm_vec) * np.linalg.norm(hand_vec))
            angle = np.arccos(np.clip(cosine, -1, 1))
            return np.degrees(angle)
        
        def calculate_neck_angle(back, neck, head):
            back = np.array(back)
            neck = np.array(neck)
            head = np.array(head)
        
            vertical_vec = neck - back     # vektor tubuh (vertikal)
            neck_vec = head - neck         # vektor arah leher
        
            cosine = np.dot(vertical_vec, neck_vec) / (np.linalg.norm(vertical_vec) * np.linalg.norm(neck_vec))
            angle = np.arccos(np.clip(cosine, -1.0, 1.0))
            return np.degrees(angle)
        
        def calculate_trunk_deviation(hip, neck):
            """
            Mengukur deviasi trunk (badan) terhadap garis vertikal dari hip ke atas.
            hip: (x, y) titik mid-hip (BODY_25 keypoint 8)
            neck: (x, y) titik neck (BODY_25 keypoint 1)
            """
            hip = np.array(hip)
            neck = np.array(neck)
            
            # Buat garis (vertikal ke atas dari hip, sejajar sumbu Y)
            ideal_neck = np.array([hip[0], neck[1]])
        
            # Vektor ideal (vertikal lurus)
            vertical_vec = hip - ideal_neck
            # Vektor tubuh aktual
            trunk_vec = hip - neck
        
            # Sudut antara keduanya
            cosine = np.dot(vertical_vec, trunk_vec) / (np.linalg.norm(vertical_vec) * np.linalg.norm(trunk_vec))
            angle = np.arccos(np.clip(cosine, -1.0, 1.0))
            return np.degrees(angle)
        
        def shoulder_is_raised(shoulder, neck, conf_shoulder, conf_neck, threshold=0.2):
            """
            Mengembalikan True jika shoulder lebih tinggi dari back (Y lebih kecil),
            dan confidence keduanya memadai.
            """
            if conf_shoulder > threshold and conf_neck > threshold:
                return shoulder[1] < neck[1]
            return False
        
        def arm_is_supported():
            """
            Diasumsikan duduk di kursi/meja → arm selalu disupport.
            """
            return True
        
        def is_neck_twisted(neck, nose, conf_neck, conf_nose, threshold=0.2):
            """
            Mengembalikan True jika posisi nose(0) di kiri neck(1) leher sedang twist
            """
            if conf_neck > threshold and conf_nose > threshold:
                return nose[0] < neck[0]
            elif conf_nose < 0.1:
                return True
            return False
        
        def is_trunk_twisted_by_elbow_rule(
            elbow_r, elbow_l,
            shoulder_r, shoulder_l,
            conf_er, conf_el,
            conf_sr, conf_sl,
            threshold=0.2
        ):
            if conf_er > threshold and conf_el > threshold and conf_sr > threshold and conf_sl > threshold:
                twist_kiri = elbow_r[0] < shoulder_l[0]  # Twist ke kiri / frontal
                twist_kanan = elbow_l[0] < shoulder_r[0]  # Twist ke kanan berlebihan
                return twist_kiri or twist_kanan
            return False
            
        def get_point(name):
            if name in keypoints_df.columns:
                value = keypoints_df[name].values[0]
                if len(value) == 3:
                    x, y, conf = value
                    if x == -1 or y == -1 or conf == -1:
                        return None, 0.0
                    return (x, y), conf
            return None, 0.0
    
        # Ambil semua titik yang dibutuhkan
        hip, conf_hip = get_point('hip')
        knee, conf_knee = get_point('knee')
        ankle, conf_ankle = get_point('ankle')
        shoulder, conf_shoulder = get_point('shoulder')
        shoulder_left, conf_shoulder_left = get_point('shoulder_left')
        elbow, conf_elbow = get_point('elbow')
        elbow_left, conf_elbow_left = get_point('elbow_left')
        wrist, conf_wrist = get_point('wrist')
        hand_middle, conf_hand_middle = get_point('hand_middle')
        back, conf_back = get_point('back')
        neck, conf_neck = get_point('neck')
        head, conf_head = get_point('head')
        nose, conf_nose = get_point('nose')
    
        # Hitung sudut
        flags = {}

        if hip and knee and ankle:
            sudut_lutut = calculate_angle(hip, knee, ankle)
            flags['sudut_lutut'] = False
        else:
            sudut_lutut = 90
            flags['sudut_lutut'] = True
    
        if shoulder and elbow and wrist:
            sudut_siku = abs(180 - calculate_angle(shoulder, elbow, wrist))
            flags['sudut_siku'] = False
        else:
            sudut_siku = 70
            flags['sudut_siku'] = True
    
        if back and neck and head:
            sudut_leher = calculate_neck_angle(back, neck, head)
            flags['sudut_leher'] = False
        else:
            sudut_leher = 10
            flags['sudut_leher'] = True
    
        if hip and neck:
            sudut_punggung = calculate_trunk_deviation(hip, neck)
            flags['sudut_punggung'] = False
        else:
            sudut_punggung = 10
            flags['sudut_punggung'] = True
    
        if elbow and wrist and hand_middle:
            sudut_pergelangan = calculate_wrist_bending(elbow, wrist, hand_middle)
            flags['sudut_pergelangan'] = False
        else:
            sudut_pergelangan = 10
            flags['sudut_pergelangan'] = True
    
        if back and shoulder and elbow:
            sudut_bahu = calculate_angle(back, shoulder, elbow)
            flags['sudut_bahu'] = False
        else:
            sudut_bahu = 10
            flags['sudut_bahu'] = True
    
        # Adjustments
        adjust_shoulder_raised = 1 if shoulder_is_raised(shoulder, neck, conf_shoulder, conf_neck) else 0
        adjust_arm_supported = -1 if arm_is_supported() else 0
        adjust_wrist_twist = 1  # selalu diset 1
        adjust_neck_twist = 1 if is_neck_twisted(neck, nose, conf_neck, conf_nose) else 0
        adjust_trunk_twist = 1 if is_trunk_twisted_by_elbow_rule(
            elbow, elbow_left,
            shoulder, shoulder_left,
            conf_elbow, conf_elbow_left,
            conf_shoulder, conf_shoulder_left
        ) else 0
        adjust_legs_feet = 1  # asumsi umum
    
        # Susun ke dalam dataframe 1 baris
        row = pd.DataFrame([{
            "sudut_lutut": sudut_lutut,
            "sudut_siku": sudut_siku,
            "sudut_leher": sudut_leher,
            "sudut_punggung": sudut_punggung,
            "sudut_pergelangan": sudut_pergelangan,
            "sudut_bahu": sudut_bahu,
    
            "conf_back": conf_back,
            "conf_shoulder": conf_shoulder,
            "conf_elbow": conf_elbow,
            "conf_wrist": conf_wrist,
            "conf_hand_middle": conf_hand_middle,
            "conf_neck": conf_neck,
            "conf_head": conf_head,
            "conf_hip": conf_hip,
            "conf_knee": conf_knee,
            "conf_ankle": conf_ankle,
            "conf_shoulder_left": conf_shoulder_left,
            "conf_elbow_left": conf_elbow_left,
    
            "adjust_shoulder_raised": adjust_shoulder_raised,
            "adjust_arm_supported": adjust_arm_supported,
            "adjust_neck_twist": adjust_neck_twist,
            "adjust_trunk_twist": adjust_trunk_twist,
            "adjust_legs_feet": adjust_legs_feet,
            "adjust_wrist_twist": adjust_wrist_twist
        }])
    
        result = self.predict(row)

        result["default_value_flags"] = flags
        return result

    def generate_feedback(self, df_row):
        messages = []
    
        # --- Upper Arm (Siku/Bahu) ---
        if df_row['sudut_bahu'].values[0] > 90:
            messages.append("Turunkan lengan agar tidak terlalu naik.")
        elif df_row['sudut_bahu'].values[0] > 60:
            messages.append("Usahakan menurunkan lengan saat bekerja.")
    
        if df_row['adjust_shoulder_raised'].values[0] == 1:
            messages.append("Rilekskan posisi bahu, bahu tampak terangkat.")
    
        # --- Elbow (Lower Arm) ---
        if df_row['sudut_siku'].values[0] > 100:
            messages.append("Sudut siku jangan terlalu tertekuk. Sebaiknya lebih lurus.")
        elif df_row['sudut_siku'].values[0] < 60:
            messages.append("Sudut siku jangan terlalu lurus. Sebaiknya lebih rileks.")
    
        # --- Wrist ---
        if df_row['sudut_pergelangan'].values[0] > 15:
            messages.append("Jaga sudut pergelangan tangan agar tidak terlalu membengkok.")
    
        # --- Neck ---
        if df_row['sudut_leher'].values[0] > 20:
            messages.append("Jaga leher sejajar kedepan, leher terlalu menunduk.")
    
        if df_row['adjust_neck_twist'].values[0] == 1:
            messages.append("Sesuaikan agar tetap lurus dan menghadap ke depan, leher dalam posisi menoleh.")
    
        # --- Trunk (Punggung) ---
        if df_row['sudut_punggung'].values[0] > 20:
            messages.append("Duduklah dengan tegak dan bersandar.")
    
        if df_row['adjust_trunk_twist'].values[0] == 1:
            messages.append("Duduk dengan lurus menghadap ke depan, hindari memutar badan saat duduk, punggung terpuntir.")
    
        # --- Legs ---
        if df_row['sudut_lutut'].values[0] > 120 or df_row['sudut_lutut'].values[0] < 60:
            messages.append("Buat sudut kaki ideal lurus kebawah dan menapakkan kaki dengan baik.")
    
        return " ".join(messages) if messages else "Postur Anda sudah cukup baik. Pertahankan!"

    def final_score_feedback(self, rula_score, reba_score):
        def interpret_rula(score):
            if score <= 2:
                return "Postur dapat diterima (acceptable posture)."
            elif score <= 4:
                return "Perlu investigasi lebih lanjut, mungkin butuh penyesuaian postur tubuh."
            elif score <= 6:
                return "Perlu investigasi lebih lanjut, butuh perubahan postur segera."
            else:
                return "Lakukan evaluasi dan ubah postur kerja sekarang juga."

        def interpret_reba(score):
            if score == 1:
                return "Risiko postur dapat diabaikan (Negligible Risk)."
            elif score <= 3:
                return "Risiko rendah. Perubahan postur mungkin dibutuhkan (Low Risk)."
            elif score <= 7:
                return "Risiko sedang. Lakukan investigasi lebih lanjut. Perubahan postur segera diperlukan (Medium Risk)."
            elif score <= 10:
                return "Risiko tinggi. Segera investigasi dan lakukan perubahan postur (High Risk)."
            else:
                return "Risiko sangat tinggi! Segera ubah postur kerja (Very High Risk)."
    
        return {
            "rula_summary": interpret_rula(rula_score),
            "reba_summary": interpret_reba(reba_score)
        }
    
    def save(self, path):
        with open(path, "wb") as f:
            cloudpickle.dump(self, f)

    @staticmethod
    def load(path):
        with open(path, "rb") as f:
            return cloudpickle.load(f)

# %%
df = pd.read_csv("/output_csv/dataset_rula_reba.csv")
df = df.dropna()

model = PostureModel()

model.fit(df)

model.save("/models/posture_model.pkl")

# %%
# Import hanya cloudpickle (tidak perlu ulangi class PostureModel)
import cloudpickle
import pandas as pd

# Load model
with open("app/models/posture_model.pkl", "rb") as f:
    model = cloudpickle.load(f)

df = pd.read_csv("app/output_csv/dataset_rula_reba.csv")
sample = df.iloc[[12]]
output = model.predict(sample)

import json
def to_serializable(obj):
    if isinstance(obj, (np.integer, np.floating)):
        return obj.item()
    if isinstance(obj, np.ndarray):
        return obj.tolist()
    return str(obj)

print(json.dumps(output, indent=2, ensure_ascii=False, default=to_serializable))
# Out:
# c:\Users\Triska\ergonomicProject\Openpose-Backend\venv\lib\site-packages\sklearn\base.py:348: InconsistentVersionWarning: Trying to unpickle estimator SVC from version 1.3.0 when using version 1.3.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Triska\ergonomicProject\Openpose-Backend\venv\lib\site-packages\sklearn\base.py:348: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.3.0 when using version 1.3.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# {
#   "rula_upper_arm_score": 1,
#   "rula_lower_arm_score": 2,
#   "rula_wrist_score": 3,
#   "rula_neck_score": 3,
#   "rula_trunk_score": 2,
#   "rula_leg_score": 1,
#   "reba_upper_arm_score": 1,
#   "reba_lower_arm_score": 2,
#   "reba_wrist_score": 2,
#   "reba_neck_score": 2,
#   "reba_trunk_score": 2,
#   "reba_leg_score": 1,
#   "rula_final_score": 3,
#   "reba_final_score": 3,
#   "feedback": "Sudut siku jangan terlalu tertekuk. Sebaiknya lebih lurus. Jaga sudut pergelangan tangan agar tidak terlalu membengkok. Jaga leher sejajar kedepan, leher terlalu menunduk.",
#   "summary": {
#     "rula_summary": "Perlu investigasi lebih lanjut, mungkin butuh penyesuaian postur tubuh.",
#     "reba_summary": "Risiko rendah. Perubahan postur mungkin dibutuhkan (Low Risk)."
#   },
#   "details": {
#     "sudut_lutut": 81.1239688978174,
#     "sudut_siku": 108.61318690202344,
#     "sudut_leher": 21.788749902476965,
#     "sudut_punggung": 5.425250646059462,
#     "sudut_pergelangan": 103.11579179065043,
#     "sudut_bahu": 22.39518007547369,
#     "adjust_shoulder_raised": 0,
#     "adjust_arm_supported": -1,
#     "adjust_neck_twist": 0,
#     "adjust_trunk_twist": 0,
#     "adjust_legs_feet": 1,
#     "adjust_wrist_twist": 1
#   }
# }

# %%
# Import hanya cloudpickle (tidak perlu ulangi class PostureModel)
import cloudpickle
import pandas as pd

# Load model
with open("app/models/posture_model.pkl", "rb") as f:
    model = cloudpickle.load(f)

df = pd.read_csv("app/output_csv/output_angles_reba_rula.csv")
sample = pd.DataFrame([{'hip': (-1, -1, -1), 'knee': (311.208740234375, 574.1769409179688, 0.9299176931381226), 'ankle': (279.02398681640625, 718.97802734375, 0.9126120805740356), 'shoulder': (145.15843200683594, 386.3792419433594, 0.8624446392059326), 'shoulder_left': (145.0896453857422, 365.3149719238281, 0.7952179908752441), 'elbow': (193.41151428222656, 488.191650390625, 0.9639016389846802), 'elbow_left': (188.28793334960938, 461.57525634765625, 0.381327360868454), 'wrist': (279.5908508300781, 482.7468566894531, 0.8852013349533081), 'hand_middle': (319.60302734375, 454.9108581542969, 0.7592580914497375), 'back': (155.88572692871094, 547.2257080078125, 0.7590545415878296), 'neck': (145.12112426757812, 370.5735168457031, 0.7592269778251648), 'head': (161.32247924804688, 316.52593994140625, 0.9215034246444702), 'nose': (209.47634887695312, 321.9300231933594, 0.9212725758552551)}])
output = model.predict_from_keypoints(sample)

import json
def to_serializable(obj):
    if isinstance(obj, (np.integer, np.floating)):
        return obj.item()
    if isinstance(obj, np.ndarray):
        return obj.tolist()
    return str(obj)

print(json.dumps(output, indent=2, ensure_ascii=False, default=to_serializable))
# Out:
# {
#   "rula_upper_arm_score": 1,
#   "rula_lower_arm_score": 1,
#   "rula_wrist_score": 3,
#   "rula_neck_score": 3,
#   "rula_trunk_score": 2,
#   "rula_leg_score": 1,
#   "reba_upper_arm_score": 1,
#   "reba_lower_arm_score": 1,
#   "reba_wrist_score": 2,
#   "reba_neck_score": 1,
#   "reba_trunk_score": 2,
#   "reba_leg_score": 1,
#   "rula_final_score": 3,
#   "reba_final_score": 3,
#   "feedback": "Jaga sudut pergelangan tangan agar tidak terlalu membengkok. Jaga leher sejajar kedepan, leher terlalu menunduk.",
#   "summary": {
#     "rula_summary": "Perlu investigasi lebih lanjut, mungkin butuh penyesuaian postur tubuh.",
#     "reba_summary": "Risiko rendah. Perubahan postur mungkin dibutuhkan (Low Risk)."
#   },
#   "details": {
#     "sudut_lutut": 90,
#     "sudut_siku": 68.25693621342151,
#     "sudut_leher": 20.173783832059772,
#     "sudut_punggung": 10,
#     "sudut_pergelangan": 31.210748482089354,
#     "sudut_bahu": 21.542631617611576,
#     "adjust_shoulder_raised": 0,
#     "adjust_arm_supported": -1,
#     "adjust_neck_twist": 0,
#     "adjust_trunk_twist": 0,
#     "adjust_legs_feet": 1,
#     "adjust_wrist_twist": 1
#   },
#   "default_value_flags": {
#     "sudut_lutut": true,
#     "sudut_siku": false,
#     "sudut_leher": false,
#     "sudut_punggung": true,
#     "sudut_pergelangan": false,
#     "sudut_bahu": false
#   }
# }

# %%
{'hip': (150.88059997558594, 557.9376831054688, 0.8290873169898987), 'knee': (311.2087097167969, 574.1767578125, 0.9299174547195435), 'ankle': (279.02398681640625, 718.9781494140625, 0.9126119613647461), 'shoulder': (145.158447265625, 386.37921142578125, 0.8624442219734192), 'shoulder_left': (145.08966064453125, 365.3150634765625, 0.7952173352241516), 'elbow': (193.4114532470703, 488.1916198730469, 0.9639008045196533), 'elbow_left': (188.28793334960938, 461.5753173828125, 0.3813277781009674), 'wrist': (279.5908508300781, 482.74676513671875, 0.8852013945579529), 'hand_middle': (319.60302734375, 454.9107360839844, 0.7592132091522217), 'back': (155.88572692871094, 547.2257690429688, 0.7590542435646057), 'neck': (145.12112426757812, 370.5735168457031, 0.7592269778251648), 'head': (161.32247924804688, 316.52593994140625, 0.9215032458305359), 'nose': (209.4763946533203, 321.9300842285156, 0.9212728142738342)}

# %% [markdown]
# # LLM Implementation with RAG and Prompt Engineering

# %%
import cloudpickle
import pandas as pd
import numpy as np
import json
import os
from dotenv import load_dotenv
import fitz  # PyMuPDF for PDF processing
import requests
from bs4 import BeautifulSoup

from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_cohere import CohereEmbeddings
from langchain.schema import Document
from langchain.chains import RetrievalQA
from langchain_groq import ChatGroq
from langchain.prompts import PromptTemplate
import time


from groq import Groq
# Out:
# c:\Users\Triska\ergonomicProject\Openpose-Backend\venv\lib\site-packages\pydantic\_internal\_config.py:345: UserWarning: Valid config keys have changed in V2:
# * 'allow_population_by_field_name' has been renamed to 'populate_by_name'
# * 'smart_union' has been removed
#   warnings.warn(message, UserWarning)

# %% [markdown]
# ## Environment and ML setup

# %%
# ----------------------------
# Load environment
# ----------------------------

load_dotenv()

os.environ['GROQ_API_KEY'] = os.getenv('GROQ_API_KEY')  
os.environ['COHERE_API_KEY'] = os.getenv('COHERE_API_KEY')  # For embedding

# %%
# ----------------------------
# Generate user input from ML model
# ----------------------------

# Load Posture model
with open("app/models/posture_model.pkl", "rb") as f:
    model = cloudpickle.load(f)

# Load dataset for RULA and REBA scores from dataset_rula_reba.csv index 1
df = pd.read_csv("app/output_csv/dataset_rula_reba_classified.csv")
# df = pd.read_csv("app/output_csv/dataset_rula_reba.csv")
sample = df.iloc[[6]]
output = model.predict(sample)

# Serialize non-standard objects for JSON
def to_serializable(obj):
    if isinstance(obj, (np.integer, np.floating)):
        return obj.item()
    if isinstance(obj, np.ndarray):
        return obj.tolist()
    return str(obj)

print(json.dumps(output, indent=2, ensure_ascii=False, default=to_serializable))

# Remove unnecessary attributes like feedback and summary
if isinstance(output, dict):
    output.pop("feedback", None)
    output.pop("summary", None)

# Save output to JSON file
os.makedirs("app/output_json", exist_ok=True)
with open("app/output_json/input_llm.json", "w", encoding="utf-8") as f:
    json.dump(output, f, indent=2, ensure_ascii=False, default=to_serializable)

print("Output saved to app/output_json/input_llm.json")
# Out:
# {
#   "rula_upper_arm_score": 4,
#   "rula_lower_arm_score": 2,
#   "rula_wrist_score": 3,
#   "rula_neck_score": 4,
#   "rula_trunk_score": 4,
#   "rula_leg_score": 1,
#   "reba_upper_arm_score": 4,
#   "reba_lower_arm_score": 2,
#   "reba_wrist_score": 2,
#   "reba_neck_score": 3,
#   "reba_trunk_score": 4,
#   "reba_leg_score": 1,
#   "rula_final_score": 3,
#   "reba_final_score": 1,
#   "feedback": "Turunkan lengan agar tidak terlalu naik. Rilekskan posisi bahu, bahu tampak terangkat. Sudut siku jangan terlalu tertekuk. Sebaiknya lebih lurus. Jaga sudut pergelangan tangan agar tidak terlalu membengkok. Jaga leher sejajar kedepan, leher terlalu menunduk. Sesuaikan agar tetap lurus dan menghadap ke depan, leher dalam posisi menoleh. Duduklah dengan tegak dan bersandar. Duduk dengan lurus menghadap ke depan, hindari memutar badan saat duduk, punggung terpuntir.",
#   "summary": {
#     "rula_summary": "Perlu investigasi lebih lanjut, mungkin butuh penyesuaian postur tubuh.",
#     "reba_summary": "Risiko postur dapat diabaikan (Negligible Risk)."
#   },
#   "details": {
#     "sudut_lutut": 60,
#     "sudut_siku": 110,
#     "sudut_leher": 35,
#     "sudut_punggung": 48,
#     "sudut_pergelangan": 40,
#     "sudut_bahu": 120,
#     "adjust_shoulder_raised": 1,
#     "adjust_arm_supported": -1,
#     "adjust_neck_twist": 1,
#     "adjust_trunk_twist": 1,
#     "adjust_legs_feet": 2,
#     "adjust_wrist_twist": 1
#   }
# }
# Output saved to app/output_json/input_llm.json
# c:\Users\Triska\ergonomicProject\Openpose-Backend\venv\lib\site-packages\sklearn\base.py:348: InconsistentVersionWarning: Trying to unpickle estimator SVC from version 1.3.0 when using version 1.3.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Triska\ergonomicProject\Openpose-Backend\venv\lib\site-packages\sklearn\base.py:348: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.3.0 when using version 1.3.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
# ----------------------------
# Load the RULA and REBA scores from the generated JSON
# ----------------------------

with open(r"app/output_json/input_llm.json", "r", encoding="utf-8") as f:
    ml_output = json.load(f)
    
RULA_SCORE_KEY = "rula_final_score"  
REBA_SCORE_KEY = "reba_final_score"  

print(f"User input data is ready: RULA={ml_output.get(RULA_SCORE_KEY)}, REBA={ml_output.get(REBA_SCORE_KEY)}")
# Out:
# User input data is ready: RULA=6, REBA=6

# %% [markdown]
# ## Retrieval-Augmented Generation (RAG)

# %%
# ----------------------------
# Creating holistic retriever for CSV
# ----------------------------

print("Preparing and indexing the data...")
# Load the CSV
def create_posture_fingerprint(row, analysis_type):
    """Creates a descriptive sentence (fingerprint) from a single row of posture data."""
    if analysis_type == 'RULA':
        return (f"RULA posture profile with final score {row.get('rula_final_score', 'N/A')}: "
                f"neck score {row.get('neck_score', 'N/A')}, trunk score {row.get('trunk_score', 'N/A')}.")
    else: # REBA
        return (f"REBA posture profile with final score {row.get('reba_final_score', 'N/A')}: "
                f"neck score {row.get('neck_score', 'N/A')}, trunk score {row.get('trunk_score', 'N/A')}.")

def load_csv_for_rag(csv_path, analysis_type):
    """Loads a CSV and converts each row into an embeddable RAG Document."""
    docs = []
    df = pd.read_csv(csv_path)
    # Correct the column names based provided CSV data
    score_col = 'rula_final_score' if analysis_type == 'RULA' else 'reba_final_score'
    rec_col = 'kalimat_rekomendasi_expert'
    
    for index, row in df.iterrows():
        page_content = create_posture_fingerprint(row, analysis_type)
        metadata = {
            "source": os.path.basename(csv_path),
            "recommendation": row[rec_col],
            "final_score": row[score_col]
        }
        docs.append(Document(page_content=page_content, metadata=metadata))
    return docs

def load_pdf(file_path):
    """Loads and splits a PDF file into chunks."""
    doc = fitz.open(file_path)
    text = "".join(page.get_text() for page in doc)
    text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(chunk_size=500, chunk_overlap=100)
    chunks = text_splitter.split_text(text)
    return [Document(page_content=chunk, metadata={"source": os.path.basename(file_path)}) for chunk in chunks]

# --- Paths to resources ---
rula_csv_path = "ergo_reference/RULA_kalimat_rekomendasi_expert.csv"
reba_csv_path = "ergo_reference/REBA_kalimat_rekomendasi_expert.csv"
pdf_files = [
    "ergo_reference/RULA-A-Step-by-Step-Guide1.pdf", 
    "ergo_reference/REBA-A-Step-by-Step-Guide.pdf",
    "ergo_reference/7-ergonomic-tips-for-business-owners.pdf",
    "ergo_reference/10-tips-to-improve-posture-and-ergonomics.pdf",
    "ergo_reference/best-posture-for-sitting-at-a-desk-all-day.pdf",
    "ergo_reference/Working-in-a-Sitting-Position.pdf"
]

# --- Create or Load RULA Vector Store ---
rula_csv_docs = load_csv_for_rag(rula_csv_path, 'RULA')
FAISS_RULA_PATH = "faiss_rula_index"
embedding_model = CohereEmbeddings(model="embed-multilingual-v3.0")

if os.path.exists(FAISS_RULA_PATH):
    rula_vectorstore = FAISS.load_local(FAISS_RULA_PATH, embedding_model, allow_dangerous_deserialization=True)
else:
    rula_vectorstore = FAISS.from_documents(rula_csv_docs, embedding_model)
    rula_vectorstore.save_local(FAISS_RULA_PATH)

# --- Create or Load REBA Vector Store ---
reba_csv_docs = load_csv_for_rag(reba_csv_path, 'REBA')
FAISS_REBA_PATH = "faiss_reba_index"

if os.path.exists(FAISS_REBA_PATH):
    reba_vectorstore = FAISS.load_local(FAISS_REBA_PATH, embedding_model, allow_dangerous_deserialization=True)
else:
    reba_vectorstore = FAISS.from_documents(reba_csv_docs, embedding_model)
    reba_vectorstore.save_local(FAISS_REBA_PATH)

# --- Create or Load Vector Store for PDFs ---
all_pdf_docs = [doc for file in pdf_files for doc in load_pdf(file)]
FAISS_PDF_PATH = "faiss_pdf_index"

if os.path.exists(FAISS_PDF_PATH):
    pdf_vectorstore = FAISS.load_local(FAISS_PDF_PATH, embedding_model, allow_dangerous_deserialization=True)
    print("   - Existing PDF vector store loaded successfully.")
else:
    print("   - PDF vector store not found, creating a new one...")
    pdf_vectorstore = FAISS.from_documents(all_pdf_docs, embedding_model)
    pdf_vectorstore.save_local(FAISS_PDF_PATH)
    print(f"   - New PDF vector store saved to '{FAISS_PDF_PATH}'.")
    
print("   - All vector stores are ready.")
# Out:
# Preparing and indexing the data...
#    - Existing PDF vector store loaded successfully.
#    - All vector stores are ready.

# %%
# ----------------------------
# Hybrid RAG
# ----------------------------

print("Setting up retrievers from vector stores...")
rula_retriever = rula_vectorstore.as_retriever(k=1)
reba_retriever = reba_vectorstore.as_retriever(k=1)
pdf_retriever = pdf_vectorstore.as_retriever(k=2)

# Create two separate fingerprints
rula_fingerprint = create_posture_fingerprint(ml_output, 'RULA')
reba_fingerprint = create_posture_fingerprint(ml_output, 'REBA')

# Perform two independent searches
closest_rula_doc = rula_retriever.invoke(rula_fingerprint)[0]
closest_reba_doc = reba_retriever.invoke(reba_fingerprint)[0]

rula_rec = closest_rula_doc.metadata.get('recommendation')
reba_rec = closest_reba_doc.metadata.get('recommendation')

# Find supplementary information from PDFs
general_query = f"Ergonomic advice for high RULA score around {ml_output['rula_final_score']} and high REBA score around {ml_output['reba_final_score']}"
supplementary_pdf_docs = pdf_retriever.invoke(general_query)
pdf_context = "\n\n".join([doc.page_content for doc in supplementary_pdf_docs])
print("   - Supplementary information from PDFs found.")
# Out:
# Setting up retrievers from vector stores...
#    - Supplementary information from PDFs found.

# %% [markdown]
# ### Prompting

# %%
llm = ChatGroq(temperature=0.2, model_name="openai/gpt-oss-120b")

final_prompt = ""
source_documents = []

if rula_rec and reba_rec:
    print("Priority recommendation from CSV found.")
    source_documents = [closest_rula_doc, closest_reba_doc]
    supplementary_docs = pdf_retriever.invoke(general_query)
    source_documents.extend(supplementary_docs)
    
    pdf_context = "\n\n".join([doc.page_content for doc in supplementary_docs])
    
    prompt_template_csv = """
    Berperanlah sebagai konsultan ergonomi profesional. Tugasmu adalah menjelaskan hasil analisis postur kepada user awam agar mereka segera memperbaiki posisi kerjanya.

    Data Postur User: {json_details}
    Skor Akhir: RULA **{rula_score}** | REBA **{reba_score}**

    Referensi Utama (Wajib Digabungkan): "{rula_recommendation}" dan "{reba_recommendation}"
    Konteks Tambahan: "{pdf_context}"

    **INSTRUKSI PENULISAN LAPORAN:**

    1. **Analisis Risiko**:
    - Sebutkan skor RULA dan REBA user dan jelaskan tingkat risikonya secara singkat.

    2. **Analisis Postur Bermasalah (Wajib urut dari kepala hingga kaki)**:
    - Analisis hanya sudut-sudut postur yang bermasalah (di luar batas wajar) berdasarkan data sudut di JSON.
    - **PENTING:** Terjemahkan variabel teknis menjadi bahasa manusia. 
        (Contoh: JANGAN tulis "adjust_neck_twist=1", tapi tulis "Leher dalam posisi terpuntir").
    - Berikan penekanan (bold) pada postur yang sudutnya ekstrem atau berbahaya.

    3. **Solusi & Rekomendasi**:
    - Rangkum "Referensi Utama" di atas menjadi satu paragraf narasi yang padu dan mengalir (hindari pengulangan kalimat).
    - Berikan daftar poin langkah praktis yang bisa dilakukan user sekarang juga berdasarkan "Konteks Tambahan".

    **ATURAN:**
    - Gunakan Bahasa Indonesia yang sopan, empatik, namun tegas mengenai keselamatan.
    - Hindari istilah teknis coding/JSON.
    - Jangan berasumsi user selalu duduk (sesuaikan dengan sudut lutut/kaki).

    Jawaban Anda:
    """
    
    PROMPT = PromptTemplate.from_template(prompt_template_csv)
    final_prompt = PROMPT.format(
        rula_score=ml_output.get(RULA_SCORE_KEY),
        reba_score=ml_output.get(REBA_SCORE_KEY),
        json_details=json.dumps(ml_output, indent=2, ensure_ascii=False),
        rula_recommendation=rula_rec,
        reba_recommendation=reba_rec,
        pdf_context=pdf_context
    )
else:
    print("Could not find a match in one or both CSVs. Falling back to PDF Path.")
    general_query = f"Berikan rekomendasi postur yang baik."
    source_documents = pdf_retriever.invoke(general_query)
    pdf_context = "\n\n".join([doc.page_content for doc in source_documents])

    
    prompt_template_pdf = """
    Berperanlah sebagai konsultan ergonomi profesional. Tugasmu adalah menjelaskan hasil analisis postur kepada user awam agar mereka segera memperbaiki posisi kerjanya.

    Data Postur User: {json_details}
    Skor Akhir: RULA **{rula_score}** | REBA **{reba_score}**
    Konteks Tambahan: "{pdf_context}"

    **INSTRUKSI PENULISAN LAPORAN:**

    1. **Analisis Risiko**:
    - Jelaskan secara singkat apa arti skor RULA dan REBA tersebut bagi keselamatan user.

    2. **Analisis Postur Bermasalah (Wajib urut dari kepala hingga kaki)**:
    - Analisis hanya sudut-sudut postur yang bermasalah (di luar batas wajar) berdasarkan data sudut di JSON.
    - **PENTING:** Terjemahkan variabel teknis menjadi bahasa manusia.
        (Contoh: JANGAN tulis "adjust_neck_twist=1", tapi tulis "Leher dalam posisi terpuntir").
    - Berikan penekanan (bold) pada postur yang sudutnya ekstrem atau berbahaya.

    3. **Solusi & Rekomendasi**:
    - Berikan saran perbaikan postur berdasarkan "Konteks Tambahan".
    - Sampaikan dengan gaya bahasa yang mudah dipahami user awam.

    **ATURAN:**
    - Gunakan Bahasa Indonesia yang sopan.
    - Hindari istilah teknis coding/JSON.

    Jawaban Anda:
    """
    
    PROMPT = PromptTemplate.from_template(prompt_template_pdf)
    final_prompt = PROMPT.format(
        rula_score=ml_output.get(RULA_SCORE_KEY),
        reba_score=ml_output.get(REBA_SCORE_KEY),
        json_details=json.dumps(ml_output, indent=2, ensure_ascii=False),
        context=pdf_context
    )

response = llm.invoke(final_prompt)
final_answer = response.content
# Out:
# Priority recommendation from CSV found.

# %% [markdown]
# ### OPIK Evaluation

# %%
# ----------------------------
# EVALUASI OPIK (Relevance & Hallucination)
# ----------------------------
print("\n" + "="*50)
print("Evaluating with OPIK")
print("="*50)

from opik import Opik
from opik.evaluation.metrics import Hallucination, AnswerRelevance

# Context list dari retrieval
context_list = [doc.page_content for doc in source_documents]
if not context_list:
    context_list = ["Tidak ada dokumen referensi yang ditemukan."]

user_input_str = f"""
Data Postur User: {json.dumps(ml_output, indent=2)}
Skor RULA: {ml_output.get(RULA_SCORE_KEY)}
Skor REBA: {ml_output.get(REBA_SCORE_KEY)}
"""

JUDGE_MODEL = "groq/llama-3.3-70b-versatile" 

try:
    print(f"- Menginisialisasi juri menggunakan model: {JUDGE_MODEL} ...")
    
    hallucination_metric = Hallucination(model=JUDGE_MODEL)
    relevance_metric = AnswerRelevance(model=JUDGE_MODEL)

    print("- Menghitung Skor Halusinasi ...")
    hallucination_score = hallucination_metric.score(
        input=user_input_str,
        output=final_answer,
        context=context_list
    )
    
    print("- Menghitung Skor Relevansi ...")
    relevance_score = relevance_metric.score(
        input=user_input_str,
        output=final_answer,
        context=context_list
    )

    print("\nEvaluation Result:")
    print(f"   - Hallucination Score : {hallucination_score.value}")
    print(f"   - Relevance Score     : {relevance_score.value}")
    print(f"   - Reason (Hallucination): {hallucination_score.reason}") # Opik biasanya memberikan alasan

except Exception as e:
    print(f"   Gagal melakukan evaluasi Opik: {e}")
    print("      Pastikan nama model Groq benar dan API Key valid.")
# Out:
# ==================================================
# Evaluating with OPIK
# ==================================================
# - Menginisialisasi juri menggunakan model: groq/llama-3.3-70b-versatile ...
# - Menghitung Skor Halusinasi ...
# - Menghitung Skor Relevansi ...
#
# Evaluation Result:
#    - Hallucination Score : 0.2
#    - Relevance Score     : 0.95
#    - Reason (Hallucination): ['The OUTPUT is mostly faithful to the CONTEXT, providing accurate information about RULA and REBA scores and their implications for musculoskeletal risk.', 'However, some specific details regarding postures and suggested improvements are introduced without direct reference in the CONTEXT, which could be considered partial hallucinations.', 'The overall analysis and recommendations for improvements are generally in line with ergonomic principles and do not contradict the CONTEXT or well-established facts.', "The OUTPUT does not introduce new information beyond what's provided in the CONTEXT that would be considered significant hallucinations, but there are minor elements that could be seen as slightly unfaithful due to lack of direct mention in the CONTEXT."]

# %% [markdown]
# ### Display output and validation

# %%
# ----------------------------
# Display output
# ----------------------------

print(final_answer)

os.makedirs("app/output_llm", exist_ok=True)

## Saving the output as markdown
with open("app/output_llm/llm_output.md", "w", encoding="utf-8") as f:
    f.write(final_answer)

print("Final_answer saved to output_json/llm_output.md")
# Out:
# **1. Analisis Risiko**
# - **Skor RULA:** 6
# - **Skor REBA:** 6
#
# Kedua skor berada pada level **tinggi** (≥ 6). Ini menandakan adanya risiko cedera muskuloskeletal yang signifikan dan memerlukan perbaikan segera pada cara kerja serta penataan ulang stasiun kerja.
#
# ---
#
# **2. Analisis Postur Bermasalah**
# *(dari kepala ke kaki, hanya menyoroti sudut yang berada di luar batas wajar)*
#
# - **Leher:** sudut ≈ 25° fleksi. Leher berada dalam posisi **terlentang ke depan** lebih dari 20°, meningkatkan beban pada otot‑otot serviks.
# - **Punggung (trunk):** sudut ≈ 30° fleksi. Badan membungkuk **lebih dari 20°**, menambah tekanan pada tulang belakang lumbar.
# - **Bahu:** sudut ≈ 50° abduksi. Bahu terangkat ke samping **lebih dari 45°**, menimbulkan stres pada otot‑otot bahu dan bahu atas.
# - **Siku:** sudut ≈ 50° fleksi. Siku ditekuk **lebih dari 45°**, membuat lengan atas bekerja dalam posisi tidak ergonomis.
# - **Pergelangan tangan:** sudut ≈ 20° fleksi dan terdapat **twist** pada pergelangan. Posisi ini melampaui 15° fleksi dan menambah beban pada pergelangan.
# - **Lutut:** sudut ≈ 100° fleksi. Kaki berada dalam **posisi jongkok** (lebih dari 90°), yang memberi tekanan besar pada sendi lutut dan punggung bagian bawah.
# - **Kaki/Posisi kaki:** terdapat penyesuaian “feet/legs” yang menunjukkan kaki tidak berada pada posisi netral (misalnya menapak pada permukaan tidak rata atau menekuk berlebih).
#
# Semua postur di atas berada di luar rentang yang dianggap aman dan berpotensi menimbulkan nyeri atau cedera jangka panjang bila dipertahankan.
#
# ---
#
# **3. Solusi & Rekomendasi**
#
# Posisi kerja Anda tergolong berbahaya dan harus segera diperbaiki. Bila memungkinkan, ubah susunan stasiun kerja sehingga Anda tidak perlu berjongkok atau menundukkan leher. Untuk pekerjaan yang memang memaksa Anda berjongkok atau menunduk (misalnya ruang sempit), gunakan alas kerja atau kursi penyangga tubuh serta lakukan peregangan secara berkala. Hindari gerakan memutar pada punggung dan leher.
#
# **Langkah‑langkah praktis yang dapat Anda terapkan sekarang:**
#
# 1. **Sesuaikan tinggi permukaan kerja** sehingga siku dapat berada pada sudut ≈ 90° dan bahu tetap rileks (tidak terangkat).
# 2. **Gunakan kursi atau bangku dengan sandaran** yang memungkinkan punggung tetap lurus; jika harus berdiri, pakai step stool atau platform yang menurunkan sudut lutut menjadi sekitar 90°.
# 3. **Letakkan alat atau bahan kerja sejajar dengan mata** untuk mengurangi fleksi leher; gunakan monitor atau penyangga yang dapat diatur ketinggiannya.
# 4. **Jaga pergelangan tangan dalam posisi netral** (tidak lebih dari 15° fleksi atau ekstensi) dengan menggunakan penyangga pergelangan atau mouse ergonomis.
# 5. **Hindari twist pada pergelangan, leher, dan punggung**; atur barang‑barang yang sering diambil pada jarak yang dapat dijangkau tanpa memutar tubuh.
# 6. **Berikan jeda peregangan setiap 30‑45 menit**:
#    - Angkat bahu, putar leher ke kanan/kiri, dan regangkan punggung.
#    - Lakukan gerakan “cat‑cow” atau membungkuk ringan untuk mengurangi tekanan pada lutut dan punggung.
# 7. **Gunakan alas anti‑slip atau matras kerja** bila harus bekerja dalam posisi jongkok, sehingga kaki mendapat dukungan yang stabil.
# 8. **Periksa kembali posisi kaki**; pastikan kaki menapak rata di tanah atau pada platform yang stabil, hindari posisi terpuntir atau menekuk berlebih.
#
# Dengan menerapkan langkah‑langkah di atas, beban pada leher, punggung, bahu, siku, pergelangan tangan, dan lutut akan berkurang secara signifikan, sehingga risiko cedera muskuloskeletal dapat diminimalkan. Jangan menunda perbaikan—keselamatan dan kenyamanan kerja Anda sangat bergantung pada postur yang tepat.
# Final_answer saved to output_json/llm_output.md

# %%
# ----------------------------
# Ensure correct validation of output resources
# ----------------------------

print("\n" + "="*50)
print("VALIDATION: SOURCES USED BY THE LLM")
print("="*50)
for doc in source_documents:
    source_name = doc.metadata.get("source", "N/A")
    print(f"\nSource: {source_name}")
    print("-----------------------------------")
    if "recommendation" in doc.metadata:
        print(f"Content (Expert Recommendation): {doc.metadata['recommendation']}")
    else:
        print(f"Content (From PDF): {doc.page_content}")
print("="*50)
# Out:
# ==================================================
# VALIDATION: SOURCES USED BY THE LLM
# ==================================================
#
# Source: RULA_kalimat_rekomendasi_expert.csv
# -----------------------------------
# Content (Expert Recommendation): Posisi kerja berbahaya. Posisi kerja perlu segera diperbaiki. Bila memungkinkan ubah susunan stasiun kerja agar pekerja tidak perlu berjongkok dan mengadahkan leher. Untuk posisi kerja yang mengharuskan berjongkok dan mengadahkan leher (confined space), disarankan menggunakan alas kerja atau kursi untuk menyangga tubuh serta melakukan peregangan secara berkala.
#
# Source: REBA_kalimat_rekomendasi_expert.csv
# -----------------------------------
# Content (Expert Recommendation): Posisi kerja berbahaya. Posisi kerja perlu segera diperbaiki. Bila memungkinkan ubah susunan stasiun kerja agar pekerja tidak perlu berjongkok dan mengadahkan leher. Untuk posisi kerja yang mengharuskan berjongkok dan mengadahkan leher (confined space), disarankan menggunakan alas kerja atau kursi untuk menyangga tubuh serta melakukan peregangan secara berkala. Hindari gerakan twisting pada punggung dan leher.
#
# Source: RULA-A-Step-by-Step-Guide1.pdf
# -----------------------------------
# Content (From PDF): Score.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# www.ergo-plus.com
# PAGE 11
#    |
# RULA: A Step-by-Step Guide
# Determine Final RULA Score:
# Use Table C to determine the final RULA score as shown below.
#
# Final RULA Score = 7
# In this example, the final RULA score of 7 indicates high risk and calls for
# engineering and/or work method changes to reduce or eliminate MSD risk as
# outlined in the chart on page 1.
#
#
#
# www.ergo-plus.com
# PAGE 12
#    |
# RULA: A Step-by-Step Guide
# Implemented ergonomic improvements:
#
#
# The assembly process was changed to install the access plate prior to riveting the
# can together. A fixture was fabricated to hold the can open while the access plate is
# being installed.  A straight or “in-line” pneumatic screw driver (on a tool balancer) is
# now used to improve upper extremity work postures and eliminate the force
# required. A follow-up analysis using the RULA worksheet was performed upon
# completion of this ergonomic process and tool improvement. When using the new
# work process and tools, the RULA total score is reduced from 7 to 1.
#
# Source: RULA-A-Step-by-Step-Guide1.pdf
# -----------------------------------
# Content (From PDF): www.ergo-plus.com
# PAGE 2
#    |
# RULA: A Step-by-Step Guide
# Rapid Upper Limb Assessment (RULA)
# RULA was developed to evaluate the exposure of individual workers to ergonomic
# risk factors associated with upper extremity MSD. The RULA ergonomic assessment
# tool considers biomechanical and postural load requirements of job tasks/demands
# on the neck, trunk and upper extremities. A single page worksheet is used to
# evaluate required body posture, force, and repetition. Based on the evaluations,
# scores are entered for each body region in section A for the arm and wrist, and
# section B for the neck and trunk. After the data for each region is collected and
# scored, tables on the form are then used to compile the risk factor variables,
# generating a single score that represents the level of MSD risk.
#
#
# www.ergo-plus.com
# PAGE 3
#    |
# RULA: A Step-by-Step Guide
# The RULA was designed for easy use without need for an advanced degree in
# ergonomics or expensive equipment. Using the RULA worksheet, the evaluator will
# assign a score for each of the following body regions: upper arm, lower arm, wrist,
# neck, trunk, and legs. After the data for each region is collected and scored, tables
# on the form are then used to compile the risk factor variables, generating a single
# score that represents the level of MSD risk as outlined below:
#
#
#
# Getting Ready
# The evaluator should prepare for the assessment by interviewing the worker being
# evaluated to gain an understanding of the job tasks and demands, and observing
# the worker’s movements and postures during several work cycles. Selection of the
# postures to be evaluated should be based on: 1) the most difficult postures and
# work tasks (based on worker interview and initial observation), 2) the posture
#
# Source: RULA-A-Step-by-Step-Guide1.pdf
# -----------------------------------
# Content (From PDF): Getting Ready
# The evaluator should prepare for the assessment by interviewing the worker being
# evaluated to gain an understanding of the job tasks and demands, and observing
# the worker’s movements and postures during several work cycles. Selection of the
# postures to be evaluated should be based on: 1) the most difficult postures and
# work tasks (based on worker interview and initial observation), 2) the posture
# sustained for the longest period of time, or 3) the posture where the highest force
# loads occur. The RULA can be conducted quickly, so multiple positions and tasks
# within the work cycle can usually be evaluated without a significant time and effort.
# When using RULA, only the right or left side is assessed at a time. After interviewing
# and observing the worker, the evaluator can determine if only one arm should be
# evaluated or if an assessment is needed for both sides.
#
# www.ergo-plus.com
# PAGE 4
#    |
# RULA: A Step-by-Step Guide
# Using the RULA – Example
# The RULA worksheet is divided into two body segment sections on the labeled A
# and B. Section A (left side) covers the arm and wrist. Section B (right side) covers the
# neck, trunk and legs. This segmenting of the worksheet ensures that any awkward
# or constrained postures of the neck, trunk or legs which might influence the
# postures of the arms and wrist are included in the assessment.
# The evaluator should score Group A (Arm & Wrist) postures first, then score Group
# B (Neck, Trunk & Legs) postures for left and right. For each region, there is a
# posture scoring scale and additional adjustments outlined on the worksheet which
# need to be considered and accounted for in the score.
# Steps 1-4: Right Arm & Wrist Analysis
#
#
#
#
# www.ergo-plus.com
# PAGE 5
#    |
#
# Source: REBA-A-Step-by-Step-Guide.pdf
# -----------------------------------
# Content (From PDF): www.ergo-plus.com
# PAGE 2
#    |           REBA: A Step-by-Step Guide
# Rapid Entire Body Assessment (REBA)
# This ergonomic assessment tool uses a systematic process to evaluate whole body
# postural MSD and risks associated with job tasks. A single page worksheet is used to
# evaluate required or selected body posture, forceful exertions, type of movement or
# action, repetition, and coupling.
#
#
# The REBA was designed for easy use without need for an advanced degree in
# ergonomics or expensive equipment. You only need the worksheet and a pen. On
# second thought, you probably should finish reading and studying this guide, and I
# suppose a clipboard would help as well. Using the REBA worksheet, the evaluator will
# assign a score for each of the following body regions: wrists, forearms, elbows,
#
# www.ergo-plus.com
# PAGE 3
#    |           REBA: A Step-by-Step Guide
# shoulders, neck, trunk, back, legs and knees. After the data for each region is
# collected and scored, tables on the form are then used to compile the risk factor
# variables, generating a single score that represents the level of MSD risk:
#
#
#
#
# Getting Ready
# The evaluator should prepare for the assessment by interviewing the worker being
# evaluated to gain an understanding of the job tasks and demands, and observing the
# worker’s movements and postures during several work cycles. Selection of the
# postures to be evaluated should be based on: 1) the most difficult postures and work
# tasks (based on worker interview and initial observation), 2) the posture sustained
# for the longest period of time, or 3) the posture where the highest force loads occur.
# The REBA can be conducted quickly, so multiple positions and tasks within the work
# cycle can usually be evaluated without a significant time/effort cost. When using
# ==================================================
